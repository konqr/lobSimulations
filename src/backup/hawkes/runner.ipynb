# %%
import datetime as dt
import pickle
import pandas as pd
import numpy as np
import os
import time
import sys
sys.path.append(os.getcwd())
from hawkes import dataLoader, inference, simulate, simulate_optimized #not importing fit because some error with tick installation

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
np.random.seed(1)

# %% [markdown]
# # Generate Fake Data

# %% [markdown]
# ## Create Fake Params

# %%
mat = np.zeros((12,12))
for i in range(12):
    mat[i][i] = .6
for i in range(12):
    for j in range(12):
        if i == j: continue
        mat[i][j] = np.random.choice([1,-1])*mat[i][i]*np.exp(-.75*np.abs(j-i))
print(mat)
# Out:
# [[ 6.00000000e-01 -2.83419932e-01 -1.33878096e-01  6.32395347e-02
#    2.98722410e-02 -1.41106475e-02 -6.66539792e-03 -3.14851104e-03
#   -1.48725131e-03 -7.02527772e-04  3.31850622e-04  1.56755134e-04]
#  [-2.83419932e-01  6.00000000e-01  2.83419932e-01 -1.33878096e-01
#   -6.32395347e-02  2.98722410e-02  1.41106475e-02 -6.66539792e-03
#    3.14851104e-03  1.48725131e-03  7.02527772e-04 -3.31850622e-04]
#  [ 1.33878096e-01  2.83419932e-01  6.00000000e-01 -2.83419932e-01
#    1.33878096e-01  6.32395347e-02  2.98722410e-02 -1.41106475e-02
#    6.66539792e-03  3.14851104e-03  1.48725131e-03 -7.02527772e-04]
#  [-6.32395347e-02 -1.33878096e-01 -2.83419932e-01  6.00000000e-01
#   -2.83419932e-01  1.33878096e-01  6.32395347e-02  2.98722410e-02
#   -1.41106475e-02 -6.66539792e-03 -3.14851104e-03 -1.48725131e-03]
#  [-2.98722410e-02 -6.32395347e-02  1.33878096e-01 -2.83419932e-01
#    6.00000000e-01 -2.83419932e-01  1.33878096e-01  6.32395347e-02
#   -2.98722410e-02  1.41106475e-02  6.66539792e-03 -3.14851104e-03]
#  [-1.41106475e-02 -2.98722410e-02  6.32395347e-02 -1.33878096e-01
#    2.83419932e-01  6.00000000e-01  2.83419932e-01 -1.33878096e-01
#   -6.32395347e-02  2.98722410e-02 -1.41106475e-02 -6.66539792e-03]
#  [-6.66539792e-03 -1.41106475e-02  2.98722410e-02  6.32395347e-02
#   -1.33878096e-01 -2.83419932e-01  6.00000000e-01  2.83419932e-01
#    1.33878096e-01  6.32395347e-02  2.98722410e-02 -1.41106475e-02]
#  [-3.14851104e-03 -6.66539792e-03  1.41106475e-02 -2.98722410e-02
#    6.32395347e-02  1.33878096e-01 -2.83419932e-01  6.00000000e-01
#   -2.83419932e-01  1.33878096e-01 -6.32395347e-02 -2.98722410e-02]
#  [ 1.48725131e-03 -3.14851104e-03  6.66539792e-03  1.41106475e-02
#   -2.98722410e-02 -6.32395347e-02 -1.33878096e-01  2.83419932e-01
#    6.00000000e-01 -2.83419932e-01 -1.33878096e-01  6.32395347e-02]
#  [-7.02527772e-04 -1.48725131e-03 -3.14851104e-03 -6.66539792e-03
#    1.41106475e-02  2.98722410e-02  6.32395347e-02  1.33878096e-01
#    2.83419932e-01  6.00000000e-01 -2.83419932e-01 -1.33878096e-01]
#  [-3.31850622e-04 -7.02527772e-04 -1.48725131e-03 -3.14851104e-03
#   -6.66539792e-03  1.41106475e-02  2.98722410e-02  6.32395347e-02
#    1.33878096e-01  2.83419932e-01  6.00000000e-01  2.83419932e-01]
#  [-1.56755134e-04 -3.31850622e-04 -7.02527772e-04 -1.48725131e-03
#   -3.14851104e-03 -6.66539792e-03  1.41106475e-02  2.98722410e-02
#   -6.32395347e-02 -1.33878096e-01  2.83419932e-01  6.00000000e-01]]

# %%
cols = ["lo_deep_Ask", "co_deep_Ask", "lo_top_Ask","co_top_Ask", "mo_Ask", "lo_inspread_Ask" ,
            "lo_inspread_Bid" , "mo_Bid", "co_top_Bid", "lo_top_Bid", "co_deep_Bid","lo_deep_Bid" ]

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
fig, ax = plt.subplots()
divider = make_axes_locatable(ax)
cax = divider.append_axes('right', size='5%', pad=0.05)
im = ax.imshow(mat.transpose(), cmap='coolwarm')
fig.colorbar(im, cax=cax, orientation='vertical')
# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(len(cols)), labels=[c +"->" for c in cols])
ax.set_yticks(np.arange(len(cols)), labels=cols)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(cols)):
    for j in range(len(cols)):
        text = ax.text(i,j, np.round(mat[i][j], decimals=2),
                               ha="center", va="center")
# fig.savefig("heatmap.png")
# plt.show()

# %%
# norm should be less than 1
np.max(np.linalg.eig(mat)[0])
# Out:
# (1.1342550157055886+0j)

# %%
# create fake TOD params - 1.0 for now but can be changed to whatever you wish
faketod = {}
for k in cols:
    faketod[k] = {}
    for k1 in np.arange(13):
        faketod[k][k1] = 1.0
with open("fakeData_Params_sod_eod_dictTOD_constt", "wb") as f:
    pickle.dump(faketod, f)

# %%
# Create fake power law kernel params from the above norm matrix
paramsFake = {}
for i in range(12):
    paramsFake[cols[i]] = 0.1*np.random.choice([0.3,0.4,0.5,0.6,0.7])
    for j in range(12):
        maxTOD = np.max(list(faketod[cols[j]].values()))
        beta = np.random.choice([1.5,1.6,1.7,1.8,1.9])
        gamma = (1+np.random.rand())*5e3
        alpha = np.abs(mat[i][j])*gamma*(beta-1)/maxTOD
        paramsFake[cols[i]+"->"+cols[j]] = (np.sign(mat[i][j]), np.array([alpha, beta, gamma]))

# %%
mat = np.zeros((12,12))
for i in range(len(cols)):
    for j in range(len(cols)):
        kernelParams = paramsFake.get(cols[j]+"->"+cols[i], None)
        if kernelParams is None: continue
        mat[i][j] = kernelParams[0]*kernelParams[1][0]/((-1 + kernelParams[1][1])*kernelParams[1][2])

# %%
# norm matrix from this fake power law kernels - does it match the above figure? - YES.
fig, ax = plt.subplots()
divider = make_axes_locatable(ax)
cax = divider.append_axes('right', size='5%', pad=0.05)
im = ax.imshow(mat.transpose(), cmap='coolwarm')
fig.colorbar(im, cax=cax, orientation='vertical')
# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(len(cols)), labels=[c +"->" for c in cols])
ax.set_yticks(np.arange(len(cols)), labels=cols)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(cols)):
    for j in range(len(cols)):
        text = ax.text(i,j, np.round(mat[i][j], decimals=2),
                               ha="center", va="center")
# fig.savefig("heatmap.png")
plt.show()

# %%
with open("fake_ParamsInferredWCutoff_sod_eod_true", "wb") as f:
    pickle.dump(paramsFake, f)

# %% [markdown]
# ## Simulate Fake LOB Data

# %%
os.mkdir("./simulated_data")
faketod, fakeparams=simulate_optimized.preprocessdata(paramsPath="fake_ParamsInferredWCutoff_sod_eod_true_optimize", todPath="fakeData_Params_sod_eod_dictTOD_constt")
# Out:
# {'lo_deep_Ask': 0.06999999999999999, 'lo_deep_Ask->lo_deep_Ask': (1.0, array([4.08364899e+03, 1.70000000e+00, 9.72297378e+03])), 'lo_deep_Ask->co_deep_Ask': (-1.0, array([2.15784816e+03, 1.80000000e+00, 9.51700958e+03])), 'lo_deep_Ask->lo_top_Ask': (-1.0, array([4.84632075e+02, 1.50000000e+00, 7.23990091e+03])), 'lo_deep_Ask->co_top_Ask': (1.0, array([4.57194337e+02, 1.80000000e+00, 9.03695644e+03])), 'lo_deep_Ask->mo_Ask': (1.0, array([2.06802870e+02, 1.90000000e+00, 7.69212347e+03])), 'lo_deep_Ask->lo_inspread_Ask': (-1.0, array([8.64372349e+01, 1.90000000e+00, 6.80630510e+03])), 'lo_deep_Ask->lo_inspread_Bid': (-1.0, array([5.25143671e+01, 1.90000000e+00, 8.75406052e+03])), 'lo_deep_Ask->mo_Bid': (-1.0, array([2.07536351e+01, 1.70000000e+00, 9.41653046e+03])), 'lo_deep_Ask->co_top_Bid': (-1.0, array([7.35185234e+00, 1.60000000e+00, 8.23874700e+03])), 'lo_deep_Ask->lo_top_Bid': (-1.0, array([2.36909637e+00, 1.50000000e+00, 6.74449171e+03])), 'lo_deep_Ask->co_deep_Bid': (1.0, array([2.02574653e+00, 1.90000000e+00, 6.78265862e+03])), 'lo_deep_Ask->lo_deep_Bid': (1.0, array([6.71581879e-01, 1.60000000e+00, 7.14045595e+03])), 'co_deep_Ask': 0.04000000000000001, 'co_deep_Ask->lo_deep_Ask': (-1.0, array([1.17863119e+03, 1.50000000e+00, 8.31720749e+03])), 'co_deep_Ask->co_deep_Ask': (1.0, array([1.93282562e+03, 1.60000000e+00, 5.36896006e+03])), 'co_deep_Ask->lo_top_Ask': (1.0, array([2.48635851e+03, 1.90000000e+00, 9.74744629e+03])), 'co_deep_Ask->co_top_Ask': (-1.0, array([6.35062298e+02, 1.70000000e+00, 6.77655181e+03])), 'co_deep_Ask->mo_Ask': (-1.0, array([2.67149749e+02, 1.60000000e+00, 7.04068401e+03])), 'co_deep_Ask->lo_inspread_Ask': (1.0, array([1.99003741e+02, 1.70000000e+00, 9.51689760e+03])), 'co_deep_Ask->lo_inspread_Bid': (1.0, array([4.59075981e+01, 1.50000000e+00, 6.50680248e+03])), 'co_deep_Ask->mo_Bid': (-1.0, array([2.30542081e+01, 1.60000000e+00, 5.76464911e+03])), 'co_deep_Ask->co_top_Bid': (1.0, array([7.94218204e+00, 1.50000000e+00, 5.04503998e+03])), 'co_deep_Ask->lo_top_Bid': (1.0, array([6.56163739e+00, 1.60000000e+00, 7.35320404e+03])), 'co_deep_Ask->co_deep_Bid': (1.0, array([4.63897851e+00, 1.90000000e+00, 7.33696342e+03])), 'co_deep_Ask->lo_deep_Bid': (-1.0, array([1.40281298e+00, 1.50000000e+00, 8.45448459e+03])), 'lo_top_Ask': 0.03, 'lo_top_Ask->lo_deep_Ask': (1.0, array([5.91396464e+02, 1.60000000e+00, 7.36237519e+03])), 'lo_top_Ask->co_deep_Ask': (1.0, array([1.64320822e+03, 1.60000000e+00, 9.66297732e+03])), 'lo_top_Ask->lo_top_Ask': (1.0, array([3.95364106e+03, 1.90000000e+00, 7.32155752e+03])), 'lo_top_Ask->co_top_Ask': (-1.0, array([1.24270867e+03, 1.50000000e+00, 8.76938094e+03])), 'lo_top_Ask->mo_Ask': (1.0, array([3.51197136e+02, 1.50000000e+00, 5.24652122e+03])), 'lo_top_Ask->lo_inspread_Ask': (1.0, array([2.48844304e+02, 1.70000000e+00, 5.62135481e+03])), 'lo_top_Ask->lo_inspread_Bid': (1.0, array([1.37948499e+02, 1.90000000e+00, 5.13105493e+03])), 'lo_top_Ask->mo_Bid': (-1.0, array([4.39621128e+01, 1.50000000e+00, 6.23105534e+03])), 'lo_top_Ask->co_top_Bid': (1.0, array([2.57694515e+01, 1.60000000e+00, 6.44358916e+03])), 'lo_top_Ask->lo_top_Bid': (1.0, array([1.54880605e+01, 1.50000000e+00, 9.83833964e+03])), 'lo_top_Ask->co_deep_Bid': (1.0, array([4.58676677e+00, 1.50000000e+00, 6.16811262e+03])), 'lo_top_Ask->lo_deep_Bid': (-1.0, array([4.41206173e+00, 1.80000000e+00, 7.85033330e+03])), 'co_top_Ask': 0.03, 'co_top_Ask->lo_deep_Ask': (-1.0, array([3.26255290e+02, 1.80000000e+00, 6.44880001e+03])), 'co_top_Ask->co_deep_Ask': (-1.0, array([6.47815259e+02, 1.60000000e+00, 8.06474046e+03])), 'co_top_Ask->lo_top_Ask': (-1.0, array([2.11265962e+03, 1.80000000e+00, 9.31770927e+03])), 'co_top_Ask->co_top_Ask': (1.0, array([2.14171895e+03, 1.50000000e+00, 7.13906316e+03])), 'co_top_Ask->mo_Ask': (-1.0, array([1.35096802e+03, 1.70000000e+00, 6.80952221e+03])), 'co_top_Ask->lo_inspread_Ask': (1.0, array([9.07715733e+02, 1.70000000e+00, 9.68595162e+03])), 'co_top_Ask->lo_inspread_Bid': (1.0, array( ...

# %%
for i in range(10):
    T, lob, lobL3, timefraction=simulate_optimized.simulate_optimized(400, fakeparams, faketod, beta = 1., avgSpread = .01, spread0 = 5, price0 = 45)
    with open("./simulated_data/fake_simulated_sod_eod_"+ str(i) , "wb") as f:
        pickle.dump((T, lob, lobL3), f)
# Out:
# s candidate:  1.489586176654438  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  1.4896570721282787  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  1.4897687076874468  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  1.4899551644437508  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  1.4899833303978596  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  2 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  1.490019955292788  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  1.49013419405062  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  1.4901580826328815  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  2 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  1.4902103930842627  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  2 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  1.490253416004094  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  2 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  1.490368363965907  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  2 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  1.490565812236787  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  2 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  1.4912665060620782  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  2 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  1.491879399960625  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  2 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  1.4939392011102774  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  2 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  1.4990005342159776  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  2 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  1.501462076307876  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  2 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  1.5015967670345856  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  1.5028880999947407  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  1.5215651816410884  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  1.8532444519983897  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  5.303456954823268  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  5.303727724898616  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  5.304910767094385  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  5.326949701172333  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  7.107788927273989  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  7.107948656607565  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  7.108041098122989  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  7.108084723022307  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  2 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  7.108355716571751  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  7.110058266929467  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  7.1129926748979955  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  7.144995786427667  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  8.826441223709633  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# s candidate:  8.826490102565117  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# s candidate:  8.826895005865001  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# s candidate:  8.828252514129915  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# s candidate:  8.828648134271381  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  1 , idx:  0
# s candidate:  8.828730004250021  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  2 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  1 , idx:  0
# s candidate:  8.829161906476195  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  2 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  1 , idx:  0
# s candidate:  8.829195271134795  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  2 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  1 , idx:  0
# s candidate:  8.829321161390832  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  1 , idx:  0
# s candidate:  8.829742309121084  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  1 , idx:  0
# s candidate:  8.830335011718288  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  1 , idx:  0
# s candidate:  8.830847185582053  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  2 , idx:  0
# s candidate:  8.837205044878447  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  2 , idx:  0
# s candidate:  9.182878772531618  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  0
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  2 , idx:  0
# s candidate:  17.12033087104578  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  3 , idx:  1
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  2 , idx:  0
# s candidate:  17.120367216545507  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  3 , idx:  1
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  3 , idx:  0
# s candidate:  17.12088983803333  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  3 , idx:  1
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  3 , idx:  0
# s candidate:  17.128260333753442  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  3 , idx:  1
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  3 , idx:  0
# s candidate:  17.161620178285126  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  3 , idx:  1
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  3 , idx:  0
# s candidate:  17.599837460342023  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  3 , idx:  1
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  3 , idx:  0
# s candidate:  17.599837560342024  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  4 , idx:  1
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  3 , idx:  0
# s candidate:  17.59998528230676  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  5 , idx:  1
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  3 , idx:  0
# s candidate:  17.600210622939844  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  6 , idx:  1
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  3 , idx:  0
# s candidate:  17.60033111353596  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  6 , idx:  1
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  3 , idx:  0
# s candidate:  17.600332314798298  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  7 , idx:  1
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  3 , idx:  0
# s candidate:  17.600422752769614  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  8 , idx:  1
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  3 , idx:  0
# s candidate:  17.600631652389147  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  8 , idx:  1
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  3 , idx:  0
# s candidate:  17.601047903201593  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  8 , idx:  1
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  3 , idx:  0
# s candidate:  17.607211457833806  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  8 , idx:  1
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  3 , idx:  0
# s candidate:  17.613193450400296  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  8 , idx:  1
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  3 , idx:  0
# s candidate:  17.613406370109757  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  1 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  1
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  3 , idx:  0
# s candidate:  17.613943578713354  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  1 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  1
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  3 , idx:  0
# s candidate:  17.617463675836404  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  1 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  1
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  3 , idx:  0
# s candidate:  17.706676558078957  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  0 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  1 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  1
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  3 , idx:  0
# s candidate:  17.706902177837556  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  1 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  1
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  3 , idx:  0
# s candidate:  17.70696891694567  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  1 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  1
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  3 , idx:  0
# s candidate:  17.707032000278492  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  1 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  1
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  3 , idx:  0
# s candidate:  17.707040189362335  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  1 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  1
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  3 , idx:  0
# s candidate:  17.707110524180973  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  2 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  1
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  3 , idx:  0
# s candidate:  17.707176649568037  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  3 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  1
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  3 , idx:  0
# s candidate:  17.707259845318642  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  1
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  3 , idx:  0
# s candidate:  17.707922738810392  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  1
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  3 , idx:  0
# s candidate:  17.712703657939493  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  1
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  3 , idx:  0
# s candidate:  17.78240544977219  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  1
# length tau:  0 , idx:  0
# length tau:  1 , idx:  0
# length tau:  3 , idx:  0
# s candidate:  20.155105740363236  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  3
# length tau:  0 , idx:  0
# length tau:  1 , idx:  1
# length tau:  3 , idx:  2
# s candidate:  20.155212037141215  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  3
# length tau:  0 , idx:  0
# length tau:  1 , idx:  1
# length tau:  4 , idx:  2
# s candidate:  20.15521244801051  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  3
# length tau:  0 , idx:  0
# length tau:  1 , idx:  1
# length tau:  5 , idx:  2
# s candidate:  20.155214179743055  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  3
# length tau:  0 , idx:  0
# length tau:  1 , idx:  1
# length tau:  6 , idx:  2
# s candidate:  20.155387162013973  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  3
# length tau:  0 , idx:  0
# length tau:  1 , idx:  1
# length tau:  7 , idx:  2
# s candidate:  20.155467333883873  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  3
# length tau:  0 , idx:  0
# length tau:  1 , idx:  1
# length tau:  8 , idx:  2
# s candidate:  20.155632546625565  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  3
# length tau:  0 , idx:  0
# length tau:  1 , idx:  1
# length tau:  9 , idx:  2
# s candidate:  20.1557190709396  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  3
# length tau:  0 , idx:  0
# length tau:  1 , idx:  1
# length tau:  9 , idx:  2
# s candidate:  20.1559379308883  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  3
# length tau:  0 , idx:  0
# length tau:  1 , idx:  1
# length tau:  9 , idx:  2
# s candidate:  20.15663774812818  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  3
# length tau:  0 , idx:  0
# length tau:  1 , idx:  1
# length tau:  9 , idx:  2
# s candidate:  20.156678866144997  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  3
# length tau:  0 , idx:  0
# length tau:  2 , idx:  1
# length tau:  9 , idx:  2
# s candidate:  20.15675497078013  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  3
# length tau:  0 , idx:  0
# length tau:  3 , idx:  1
# length tau:  9 , idx:  2
# s candidate:  20.157161161639337  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  3
# length tau:  0 , idx:  0
# length tau:  3 , idx:  1
# length tau:  10 , idx:  2
# s candidate:  20.158062881306556  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  3
# length tau:  0 , idx:  0
# length tau:  3 , idx:  1
# length tau:  10 , idx:  2
# s candidate:  20.162903936704428  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  3
# length tau:  0 , idx:  0
# length tau:  3 , idx:  1
# length tau:  10 , idx:  2
# s candidate:  20.181095007476564  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  3
# length tau:  0 , idx:  0
# length tau:  3 , idx:  1
# length tau:  10 , idx:  2
# s candidate:  20.36227370158304  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  3
# length tau:  0 , idx:  0
# length tau:  3 , idx:  1
# length tau:  10 , idx:  2
# s candidate:  22.589703341313307  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  1 , idx:  0
# length tau:  8 , idx:  3
# length tau:  0 , idx:  0
# length tau:  3 , idx:  1
# length tau:  10 , idx:  2
# s candidate:  22.589747345084785  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  1 , idx:  0
# length tau:  9 , idx:  3
# length tau:  0 , idx:  0
# length tau:  3 , idx:  1
# length tau:  10 , idx:  2
# s candidate:  22.589829713360945  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  2 , idx:  0
# length tau:  9 , idx:  3
# length tau:  0 , idx:  0
# length tau:  3 , idx:  1
# length tau:  10 , idx:  2
# s candidate:  22.591542596633555  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  2 , idx:  0
# length tau:  9 , idx:  3
# length tau:  0 , idx:  0
# length tau:  3 , idx:  1
# length tau:  10 , idx:  2
# s candidate:  22.59793175406267  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  2 , idx:  0
# length tau:  9 , idx:  3
# length tau:  0 , idx:  0
# length tau:  3 , idx:  1
# length tau:  10 , idx:  2
# s candidate:  22.615524806419202  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  2 , idx:  0
# length tau:  9 , idx:  3
# length tau:  0 , idx:  0
# length tau:  3 , idx:  1
# length tau:  10 , idx:  2
# s candidate:  27.298998560204172  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  2 , idx:  0
# length tau:  9 , idx:  3
# length tau:  0 , idx:  0
# length tau:  3 , idx:  1
# length tau:  10 , idx:  3
# s candidate:  27.29902987176725  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  2 , idx:  0
# length tau:  10 , idx:  3
# length tau:  0 , idx:  0
# length tau:  3 , idx:  1
# length tau:  10 , idx:  3
# s candidate:  27.29913441844932  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  2 , idx:  0
# length tau:  10 , idx:  3
# length tau:  0 , idx:  0
# length tau:  3 , idx:  1
# length tau:  10 , idx:  3
# s candidate:  27.300056532894963  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  2 , idx:  0
# length tau:  10 , idx:  3
# length tau:  0 , idx:  0
# length tau:  3 , idx:  1
# length tau:  10 , idx:  3
# s candidate:  27.304474491975437  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  2 , idx:  0
# length tau:  10 , idx:  3
# length tau:  0 , idx:  0
# length tau:  3 , idx:  1
# length tau:  10 , idx:  3
# s candidate:  27.32947376574581  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  2 , idx:  0
# length tau:  10 , idx:  3
# length tau:  0 , idx:  0
# length tau:  3 , idx:  1
# length tau:  10 , idx:  3
# s candidate:  27.69927704751432  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  4 , idx:  1
# length tau:  2 , idx:  1
# length tau:  10 , idx:  8
# length tau:  0 , idx:  0
# length tau:  3 , idx:  1
# length tau:  10 , idx:  3
# s candidate:  27.699812919165954  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  0
# length tau:  0 , idx:  0
# length tau:  5 , idx:  3
# length tau:  4 , idx:  1
# length tau:  2 , idx:  1
# length tau:  10 , idx:  8
# length tau:  0 , idx:  0
# length tau:  3 , idx:  1
# length tau:  10 , idx:  3
# s candidate:  27.708576385450378  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  5 , idx:  4
# length tau:  4 , idx:  4
# length tau:  2 , idx:  1
# length tau:  10 , idx:  8
# length tau:  0 , idx:  0
# length tau:  3 , idx:  1
# length tau:  10 , idx:  3
# s candidate:  27.92462030456356  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  5 , idx:  4
# length tau:  4 , idx:  4
# length tau:  2 , idx:  1
# length tau:  10 , idx:  8
# length tau:  0 , idx:  0
# length tau:  3 , idx:  1
# length tau:  10 , idx:  3
# s candidate:  27.92509680136056  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  5 , idx:  4
# length tau:  4 , idx:  4
# length tau:  2 , idx:  1
# length tau:  10 , idx:  8
# length tau:  0 , idx:  0
# length tau:  4 , idx:  1
# length tau:  10 , idx:  3
# s candidate:  27.928782550290133  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  5 , idx:  4
# length tau:  4 , idx:  4
# length tau:  2 , idx:  1
# length tau:  10 , idx:  8
# length tau:  0 , idx:  0
# length tau:  4 , idx:  1
# length tau:  10 , idx:  3
# s candidate:  27.995671845913826  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  5 , idx:  4
# length tau:  4 , idx:  4
# length tau:  2 , idx:  1
# length tau:  10 , idx:  8
# length tau:  0 , idx:  0
# length tau:  4 , idx:  1
# length tau:  10 , idx:  3
# s candidate:  28.485105531495687  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  3 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  5 , idx:  4
# length tau:  4 , idx:  4
# length tau:  2 , idx:  1
# length tau:  10 , idx:  8
# length tau:  0 , idx:  0
# length tau:  4 , idx:  1
# length tau:  10 , idx:  3
# s candidate:  28.48517780095747  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  4 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  5 , idx:  4
# length tau:  4 , idx:  4
# length tau:  2 , idx:  1
# length tau:  10 , idx:  8
# length tau:  0 , idx:  0
# length tau:  4 , idx:  1
# length tau:  10 , idx:  3
# s candidate:  28.485857043227753  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  4 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  5 , idx:  4
# length tau:  4 , idx:  4
# length tau:  2 , idx:  1
# length tau:  10 , idx:  8
# length tau:  0 , idx:  0
# length tau:  4 , idx:  1
# length tau:  10 , idx:  3
# s candidate:  28.488354229742928  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  4 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  5 , idx:  4
# length tau:  4 , idx:  4
# length tau:  2 , idx:  1
# length tau:  10 , idx:  8
# length tau:  0 , idx:  0
# length tau:  4 , idx:  1
# length tau:  10 , idx:  3
# s candidate:  28.51988154798493  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  4 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  5 , idx:  4
# length tau:  4 , idx:  4
# length tau:  2 , idx:  1
# length tau:  10 , idx:  8
# length tau:  0 , idx:  0
# length tau:  4 , idx:  1
# length tau:  10 , idx:  3
# s candidate:  29.421539779759822  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  4 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  5 , idx:  4
# length tau:  4 , idx:  4
# length tau:  2 , idx:  1
# length tau:  10 , idx:  8
# length tau:  0 , idx:  0
# length tau:  4 , idx:  1
# length tau:  10 , idx:  3
# s candidate:  29.421911822704814  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  4 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  5 , idx:  4
# length tau:  4 , idx:  4
# length tau:  2 , idx:  1
# length tau:  10 , idx:  8
# length tau:  0 , idx:  0
# length tau:  4 , idx:  1
# length tau:  11 , idx:  3
# s candidate:  29.422060810131878  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  4 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  5 , idx:  4
# length tau:  4 , idx:  4
# length tau:  2 , idx:  1
# length tau:  10 , idx:  8
# length tau:  0 , idx:  0
# length tau:  4 , idx:  1
# length tau:  12 , idx:  3
# s candidate:  29.42266252876213  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  4 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  5 , idx:  4
# length tau:  4 , idx:  4
# length tau:  2 , idx:  1
# length tau:  10 , idx:  8
# length tau:  0 , idx:  0
# length tau:  4 , idx:  1
# length tau:  12 , idx:  3
# s candidate:  29.425680908510206  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  4 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  5 , idx:  4
# length tau:  4 , idx:  4
# length tau:  2 , idx:  1
# length tau:  10 , idx:  8
# length tau:  0 , idx:  0
# length tau:  4 , idx:  1
# length tau:  12 , idx:  3
# s candidate:  29.493608518365548  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  4 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  5 , idx:  4
# length tau:  4 , idx:  4
# length tau:  2 , idx:  1
# length tau:  10 , idx:  8
# length tau:  0 , idx:  0
# length tau:  4 , idx:  1
# length tau:  12 , idx:  3
# s candidate:  35.91541572106591  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  4 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  5 , idx:  4
# length tau:  4 , idx:  4
# length tau:  2 , idx:  2
# length tau:  10 , idx:  9
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  12 , idx:  10
# s candidate:  35.91545024531298  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  4 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  5 , idx:  4
# length tau:  4 , idx:  4
# length tau:  3 , idx:  2
# length tau:  10 , idx:  9
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  12 , idx:  10
# s candidate:  35.91546711240531  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  4 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  5 , idx:  4
# length tau:  4 , idx:  4
# length tau:  3 , idx:  2
# length tau:  10 , idx:  9
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  12 , idx:  10
# s candidate:  35.91601288014338  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  4 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  5 , idx:  4
# length tau:  4 , idx:  4
# length tau:  4 , idx:  2
# length tau:  10 , idx:  9
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  12 , idx:  10
# s candidate:  35.92207690318915  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  4 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  5 , idx:  4
# length tau:  4 , idx:  4
# length tau:  4 , idx:  2
# length tau:  10 , idx:  9
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  12 , idx:  10
# s candidate:  36.018890435125044  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  4 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  5 , idx:  4
# length tau:  4 , idx:  4
# length tau:  4 , idx:  2
# length tau:  10 , idx:  9
# length tau:  0 , idx:  0
# length tau:  4 , idx:  3
# length tau:  12 , idx:  10
# s candidate:  36.569590819819695  S_type:  <class 'numpy.float64'>
# length tau:  0 , idx:  0
# length tau:  3 , idx:  3
# length tau:  4 , idx:  3
# length tau:  1 , idx:  1
# length tau:  0 , idx:  0
# length tau:  5 , idx:  4
# length tau:  4 , idx:  4
# length tau:  4 , idx:  2
# ...
# length tau:  118 , idx:  116
# length tau:  37 , idx:  37
# length tau:  43 , idx:  43
# length tau:  216 , idx:  206
# length tau:  124 , idx:  120
# length tau:  129 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  594.6577096414208  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  87
# length tau:  97 , idx:  89
# length tau:  36 , idx:  36
# length tau:  118 , idx:  116
# length tau:  37 , idx:  37
# length tau:  43 , idx:  43
# length tau:  216 , idx:  206
# length tau:  125 , idx:  120
# length tau:  129 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  594.6577719795462  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  87
# length tau:  97 , idx:  89
# length tau:  36 , idx:  36
# length tau:  118 , idx:  116
# length tau:  37 , idx:  37
# length tau:  43 , idx:  43
# length tau:  217 , idx:  206
# length tau:  125 , idx:  120
# length tau:  129 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  594.657902677035  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  87
# length tau:  97 , idx:  89
# length tau:  36 , idx:  36
# length tau:  118 , idx:  116
# length tau:  37 , idx:  37
# length tau:  43 , idx:  43
# length tau:  217 , idx:  206
# length tau:  125 , idx:  120
# length tau:  130 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  594.6579352669884  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  87
# length tau:  97 , idx:  89
# length tau:  36 , idx:  36
# length tau:  118 , idx:  116
# length tau:  37 , idx:  37
# length tau:  43 , idx:  43
# length tau:  217 , idx:  206
# length tau:  125 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  594.6579592587228  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  87
# length tau:  97 , idx:  89
# length tau:  36 , idx:  36
# length tau:  118 , idx:  116
# length tau:  37 , idx:  37
# length tau:  43 , idx:  43
# length tau:  217 , idx:  206
# length tau:  126 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  594.6579735492751  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  87
# length tau:  97 , idx:  89
# length tau:  36 , idx:  36
# length tau:  118 , idx:  116
# length tau:  37 , idx:  37
# length tau:  43 , idx:  43
# length tau:  217 , idx:  206
# length tau:  127 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  594.6580066433663  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  87
# length tau:  97 , idx:  89
# length tau:  37 , idx:  36
# length tau:  118 , idx:  116
# length tau:  37 , idx:  37
# length tau:  43 , idx:  43
# length tau:  217 , idx:  206
# length tau:  127 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  594.658076123531  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  87
# length tau:  97 , idx:  89
# length tau:  38 , idx:  36
# length tau:  118 , idx:  116
# length tau:  37 , idx:  37
# length tau:  43 , idx:  43
# length tau:  217 , idx:  206
# length tau:  127 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  594.6582654922911  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  87
# length tau:  97 , idx:  89
# length tau:  38 , idx:  36
# length tau:  118 , idx:  116
# length tau:  37 , idx:  37
# length tau:  43 , idx:  43
# length tau:  217 , idx:  206
# length tau:  128 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  594.6583062061646  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  87
# length tau:  97 , idx:  89
# length tau:  38 , idx:  36
# length tau:  118 , idx:  116
# length tau:  37 , idx:  37
# length tau:  43 , idx:  43
# length tau:  217 , idx:  206
# length tau:  129 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  594.6583106286855  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  87
# length tau:  97 , idx:  89
# length tau:  38 , idx:  36
# length tau:  118 , idx:  116
# length tau:  37 , idx:  37
# length tau:  43 , idx:  43
# length tau:  218 , idx:  206
# length tau:  129 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  594.6583603699611  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  87
# length tau:  97 , idx:  89
# length tau:  38 , idx:  36
# length tau:  118 , idx:  116
# length tau:  37 , idx:  37
# length tau:  43 , idx:  43
# length tau:  218 , idx:  206
# length tau:  129 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  594.6585809751311  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  87
# length tau:  97 , idx:  89
# length tau:  38 , idx:  36
# length tau:  118 , idx:  116
# length tau:  37 , idx:  37
# length tau:  43 , idx:  43
# length tau:  218 , idx:  206
# length tau:  129 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  594.6602989165634  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  87
# length tau:  97 , idx:  89
# length tau:  38 , idx:  36
# length tau:  118 , idx:  116
# length tau:  37 , idx:  37
# length tau:  43 , idx:  43
# length tau:  218 , idx:  206
# length tau:  129 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  594.6654017604257  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  87
# length tau:  97 , idx:  89
# length tau:  38 , idx:  36
# length tau:  118 , idx:  116
# length tau:  37 , idx:  37
# length tau:  43 , idx:  43
# length tau:  218 , idx:  206
# length tau:  129 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  594.6654906626542  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  87
# length tau:  97 , idx:  89
# length tau:  38 , idx:  36
# length tau:  118 , idx:  116
# length tau:  37 , idx:  37
# length tau:  43 , idx:  43
# length tau:  218 , idx:  206
# length tau:  130 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  594.6666345555835  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  87
# length tau:  97 , idx:  89
# length tau:  38 , idx:  36
# length tau:  118 , idx:  116
# length tau:  37 , idx:  37
# length tau:  43 , idx:  43
# length tau:  218 , idx:  206
# length tau:  130 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  594.6678759788791  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  87
# length tau:  97 , idx:  89
# length tau:  38 , idx:  36
# length tau:  118 , idx:  116
# length tau:  37 , idx:  37
# length tau:  43 , idx:  43
# length tau:  218 , idx:  206
# length tau:  130 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  594.6680809972448  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  87
# length tau:  97 , idx:  89
# length tau:  38 , idx:  36
# length tau:  118 , idx:  116
# length tau:  37 , idx:  37
# length tau:  43 , idx:  43
# length tau:  218 , idx:  206
# length tau:  130 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  594.6682611636655  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  87
# length tau:  97 , idx:  89
# length tau:  38 , idx:  36
# length tau:  118 , idx:  116
# length tau:  37 , idx:  37
# length tau:  43 , idx:  43
# length tau:  219 , idx:  206
# length tau:  130 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  594.668491968755  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  87
# length tau:  97 , idx:  89
# length tau:  38 , idx:  36
# length tau:  118 , idx:  116
# length tau:  37 , idx:  37
# length tau:  43 , idx:  43
# length tau:  220 , idx:  206
# length tau:  130 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  594.6686312692264  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  87
# length tau:  97 , idx:  89
# length tau:  38 , idx:  36
# length tau:  118 , idx:  116
# length tau:  37 , idx:  37
# length tau:  43 , idx:  43
# length tau:  220 , idx:  206
# length tau:  130 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  594.6687703965474  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  87
# length tau:  97 , idx:  89
# length tau:  38 , idx:  36
# length tau:  118 , idx:  116
# length tau:  37 , idx:  37
# length tau:  43 , idx:  43
# length tau:  221 , idx:  206
# length tau:  130 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  594.6687907777656  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  87
# length tau:  97 , idx:  89
# length tau:  38 , idx:  36
# length tau:  118 , idx:  116
# length tau:  38 , idx:  37
# length tau:  43 , idx:  43
# length tau:  221 , idx:  206
# length tau:  130 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  594.6691134033633  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  87
# length tau:  97 , idx:  89
# length tau:  38 , idx:  36
# length tau:  118 , idx:  116
# length tau:  38 , idx:  37
# length tau:  44 , idx:  43
# length tau:  221 , idx:  206
# length tau:  130 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  594.6698446565356  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  87
# length tau:  97 , idx:  89
# length tau:  38 , idx:  36
# length tau:  118 , idx:  116
# length tau:  38 , idx:  37
# length tau:  44 , idx:  43
# length tau:  221 , idx:  206
# length tau:  130 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  594.6709325355466  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  87
# length tau:  97 , idx:  89
# length tau:  38 , idx:  36
# length tau:  118 , idx:  116
# length tau:  38 , idx:  37
# length tau:  44 , idx:  43
# length tau:  221 , idx:  206
# length tau:  130 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  594.6770974520969  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  87
# length tau:  97 , idx:  89
# length tau:  38 , idx:  36
# length tau:  118 , idx:  116
# length tau:  38 , idx:  37
# length tau:  44 , idx:  43
# length tau:  221 , idx:  206
# length tau:  130 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  594.7719630649715  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  87
# length tau:  97 , idx:  89
# length tau:  38 , idx:  36
# length tau:  118 , idx:  116
# length tau:  38 , idx:  37
# length tau:  44 , idx:  43
# length tau:  221 , idx:  206
# length tau:  130 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  596.1937302458975  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  117
# length tau:  97 , idx:  97
# length tau:  38 , idx:  36
# length tau:  118 , idx:  117
# length tau:  38 , idx:  37
# length tau:  44 , idx:  43
# length tau:  221 , idx:  206
# length tau:  130 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  597.2294055119582  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  118
# length tau:  97 , idx:  97
# length tau:  38 , idx:  36
# length tau:  118 , idx:  118
# length tau:  38 , idx:  37
# length tau:  44 , idx:  43
# length tau:  221 , idx:  206
# length tau:  130 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  597.2296330934628  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  118
# length tau:  97 , idx:  97
# length tau:  38 , idx:  36
# length tau:  118 , idx:  118
# length tau:  38 , idx:  37
# length tau:  44 , idx:  43
# length tau:  221 , idx:  206
# length tau:  131 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  597.2315567403051  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  118
# length tau:  97 , idx:  97
# length tau:  38 , idx:  36
# length tau:  118 , idx:  118
# length tau:  38 , idx:  37
# length tau:  44 , idx:  43
# length tau:  221 , idx:  206
# length tau:  131 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  597.2391841400951  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  118
# length tau:  97 , idx:  97
# length tau:  38 , idx:  36
# length tau:  118 , idx:  118
# length tau:  38 , idx:  37
# length tau:  44 , idx:  43
# length tau:  221 , idx:  206
# length tau:  131 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  136 , idx:  136
# s candidate:  597.2392986469283  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  118
# length tau:  97 , idx:  97
# length tau:  38 , idx:  36
# length tau:  118 , idx:  118
# length tau:  38 , idx:  37
# length tau:  44 , idx:  43
# length tau:  221 , idx:  206
# length tau:  131 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  137 , idx:  136
# s candidate:  597.2400374029512  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  118
# length tau:  97 , idx:  97
# length tau:  38 , idx:  36
# length tau:  118 , idx:  118
# length tau:  38 , idx:  37
# length tau:  44 , idx:  43
# length tau:  221 , idx:  206
# length tau:  131 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  137 , idx:  136
# s candidate:  597.2491787863001  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  118
# length tau:  97 , idx:  97
# length tau:  38 , idx:  36
# length tau:  118 , idx:  118
# length tau:  38 , idx:  37
# length tau:  44 , idx:  43
# length tau:  221 , idx:  206
# length tau:  131 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  137 , idx:  136
# s candidate:  597.711779730124  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  118
# length tau:  97 , idx:  97
# length tau:  38 , idx:  36
# length tau:  118 , idx:  118
# length tau:  38 , idx:  37
# length tau:  44 , idx:  43
# length tau:  221 , idx:  206
# length tau:  131 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  137 , idx:  136
# s candidate:  600.0587687359131  S_type:  <class 'numpy.float64'>
# length tau:  70 , idx:  70
# length tau:  118 , idx:  118
# length tau:  97 , idx:  97
# length tau:  38 , idx:  36
# length tau:  118 , idx:  118
# length tau:  38 , idx:  37
# length tau:  44 , idx:  43
# length tau:  221 , idx:  206
# length tau:  131 , idx:  120
# length tau:  131 , idx:  122
# length tau:  135 , idx:  129
# length tau:  137 , idx:  136
# Simulation, took  8.6799223 seconds.

# %%
# save as 12D 
paths = [i for i in os.listdir(os.getcwd()+"/simulated_data") if ("fake_simulated" in i)]
for p in paths:
    resPath = os.getcwd()+"/simulated_data//" + p
    with open(resPath, 'rb') as f:
        results = pickle.load(f)
    
    ask_t = []
    bid_t = []
    ask_d = []
    bid_d= []
    event = []
    time = []
    for r, j in zip(results[1][1:], results[0][1:]):
        ask_t.append(r['Ask_touch'][0])
        bid_t.append(r['Bid_touch'][0])
        ask_d.append(r['Ask_deep'][0])
        bid_d.append(r['Bid_deep'][0])
        event.append(j[0])
        time.append(j[1])
    df = pd.DataFrame({"Time" : time, "event" : event, "Ask Price 1" : ask_t, "Bid Price 1": bid_t, "Ask Price 2": ask_d, "Bid Price 2" : bid_d})
    df['BidDiff'] = df['Bid Price 1'].diff()
    df['AskDiff'] = df['Ask Price 1'].diff()
    df['BidDiff2']= df['Bid Price 2'].diff()
    df['AskDiff2']= df['Ask Price 2'].diff()
    id = (resPath.split("/")[-1]).split("_")[-1]
    df["Date"] = id
    df.to_csv("./simulated_data/fake_" + id +"_12D.csv")

# %%
paths

# %% [markdown]
# ## Bin to custom bins

# %%
#### WARNING: THIS PIECE OF CODE TAKES A LONG TIME ####
ric = "fake"
for d in range(10):
    l =  dataLoader.Loader(ric, d, d, dataPath = "./simulated_data/")
    df = pd.read_csv(l.dataPath+"fake_"+str(d)+"_12D.csv")
    data = {str(d) : list(df.groupby('event')['Time'].apply(np.array)[cols].values)}
    cls = fit.ConditionalLeastSquaresLogLin(data, loader = l) 
    cls.runTransformDate()

# %% [markdown]
# # Fit Fake Data

# %% [markdown]
# ## Hawkes Graph

# %%
# !git clone https://github.com/achab/nphc.git nphc2
# in line 1 of nphc2/nphc/cumulants.py, remove the autojit import and line 235 remove decorator

# %%
os.getcwd()+"/nphc2"

# %%
import sys
import os
sys.path.append(os.getcwd()+"/nphc2")
import matplotlib.pyplot as plt
from nphc.main import NPHC
import pandas as pd
import datetime as dt
import numpy as np

# %%
big_data = []
cols = ["lo_deep_Ask", "co_deep_Ask", "lo_top_Ask","co_top_Ask", "mo_Ask", "lo_inspread_Ask" ,
            "lo_inspread_Bid" , "mo_Bid", "co_top_Bid", "lo_top_Bid", "co_deep_Bid","lo_deep_Bid" ]
for d in range(10): #pd.date_range(dt.date(2019,1,2), dt.date(2019,1,4)):
    
    df = pd.read_csv("./simulated_data/fake_"+str(d)+"_12D.csv")
    
    timestamps = list(df.groupby('event')['Time'].apply(np.array)[cols].values)
    big_data.append(timestamps)

# %%
nphc = NPHC()
nphc.fit(big_data,half_width=1.,filtr="rectangular",method="parallel_by_day")
cumulants_list = [nphc.L, nphc.C, nphc.K_c]
from nphc.main import starting_point
start_point = starting_point(cumulants_list, random=True)
R_pred = nphc.solve(training_epochs=50000,display_step=500,learning_rate=1e-2,optimizer='adam')
d = len(nphc.L[0])
from scipy.linalg import inv
G_pred = np.eye(d) - inv(R_pred)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12,10)
plt.rcParams['xtick.labelsize'] = 26
plt.rcParams['ytick.labelsize'] = 26
dimensions = cols 
sns_plot = sns.heatmap(G_pred.T,cmap="RdBu_r",xticklabels=dimensions,yticklabels=dimensions)

# %%
boundsDict = {}
for i in range(12):
    for j in range(12):
        boundsDict[cols[i]+"->"+cols[j]] = np.sign(G_pred[i][j])
import pickle
with open(os.getcwd()+"/simulated_data/fake_2019-01-02_2019-03-31_graphDict", "wb") as f:
    pickle.dump(boundsDict, f)

# %% [markdown]
# ## 12D Hawkes Non-Parametric Fit:

# %%
ric = "fake"
dictIp = {}
d = 0
l =  dataLoader.Loader(ric, d, d, dataPath = "./simulated_data/")
for d in range(10):
    dictIp[str(d)] = []
cls = fit.ConditionalLeastSquaresLogLin(dictIp, loader = l, solver="osqp", path_dictTOD = "./fakeData_Params_sod_eod_dictTOD_constt")
thetas = cls.fitConditionalInSpread(spreadBeta = 1., avgSpread = 1.)
with open(l.dataPath + ric + "_Params_2019-01-02_2019-03-31_CLSLogLin_19" , "wb") as f:
    pickle.dump(thetas, f)

# %% [markdown]
# ## Infer power law params:

# %%
a, b = inference.run(dt.date(2019,1,2), dt.date(2019,3,31), ric = "fake" , avgSpread = 0.01, spreadBeta=1. , suffix = "_CLSLogLin_19")

# %% [markdown]
# # Simulate LOB from Fitted Fake Params

# %%
#### WARNING: THIS PIECE OF CODE TAKES A LONG TIME ####
for i in range(10):
    T, lob, lobL3=simulate.simulate(6.5*3600, "fake_ParamsInferredWCutoff_2019-01-02_2019-01-31_CLSLogLin_19", "fakeData_Params_sod_eod_dictTOD_constt", beta = 1., avgSpread = 0.01, spread0 = 5, price0 = 45)
    with open("./simulated_data/fake_simulated_CLSLogLinFit_sod_eod_"+ str(i) , "wb") as f:
        pickle.dump((T, lob, lobL3), f)
