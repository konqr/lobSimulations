# %%
import datetime as dt
import pickle
import pandas as pd
import numpy as np
import os
import time
import sys
sys.path.append(os.getcwd())
from hawkes import dataLoader, inference, simulate, simulate_optimized #not importing fit because some error with tick installation

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
np.random.seed(1)

# %% [markdown]
# # Generate Fake Data

# %% [markdown]
# ## Create Fake Params

# %%
mat = np.zeros((12,12))
for i in range(12):
    mat[i][i] = .6
for i in range(12):
    for j in range(12):
        if i == j: continue
        mat[i][j] = np.random.choice([1,-1])*mat[i][i]*np.exp(-.75*np.abs(j-i))
print(mat)
# Out:
# [[ 6.00000000e-01 -2.83419932e-01 -1.33878096e-01  6.32395347e-02
#    2.98722410e-02 -1.41106475e-02 -6.66539792e-03 -3.14851104e-03
#   -1.48725131e-03 -7.02527772e-04  3.31850622e-04  1.56755134e-04]
#  [-2.83419932e-01  6.00000000e-01  2.83419932e-01 -1.33878096e-01
#   -6.32395347e-02  2.98722410e-02  1.41106475e-02 -6.66539792e-03
#    3.14851104e-03  1.48725131e-03  7.02527772e-04 -3.31850622e-04]
#  [ 1.33878096e-01  2.83419932e-01  6.00000000e-01 -2.83419932e-01
#    1.33878096e-01  6.32395347e-02  2.98722410e-02 -1.41106475e-02
#    6.66539792e-03  3.14851104e-03  1.48725131e-03 -7.02527772e-04]
#  [-6.32395347e-02 -1.33878096e-01 -2.83419932e-01  6.00000000e-01
#   -2.83419932e-01  1.33878096e-01  6.32395347e-02  2.98722410e-02
#   -1.41106475e-02 -6.66539792e-03 -3.14851104e-03 -1.48725131e-03]
#  [-2.98722410e-02 -6.32395347e-02  1.33878096e-01 -2.83419932e-01
#    6.00000000e-01 -2.83419932e-01  1.33878096e-01  6.32395347e-02
#   -2.98722410e-02  1.41106475e-02  6.66539792e-03 -3.14851104e-03]
#  [-1.41106475e-02 -2.98722410e-02  6.32395347e-02 -1.33878096e-01
#    2.83419932e-01  6.00000000e-01  2.83419932e-01 -1.33878096e-01
#   -6.32395347e-02  2.98722410e-02 -1.41106475e-02 -6.66539792e-03]
#  [-6.66539792e-03 -1.41106475e-02  2.98722410e-02  6.32395347e-02
#   -1.33878096e-01 -2.83419932e-01  6.00000000e-01  2.83419932e-01
#    1.33878096e-01  6.32395347e-02  2.98722410e-02 -1.41106475e-02]
#  [-3.14851104e-03 -6.66539792e-03  1.41106475e-02 -2.98722410e-02
#    6.32395347e-02  1.33878096e-01 -2.83419932e-01  6.00000000e-01
#   -2.83419932e-01  1.33878096e-01 -6.32395347e-02 -2.98722410e-02]
#  [ 1.48725131e-03 -3.14851104e-03  6.66539792e-03  1.41106475e-02
#   -2.98722410e-02 -6.32395347e-02 -1.33878096e-01  2.83419932e-01
#    6.00000000e-01 -2.83419932e-01 -1.33878096e-01  6.32395347e-02]
#  [-7.02527772e-04 -1.48725131e-03 -3.14851104e-03 -6.66539792e-03
#    1.41106475e-02  2.98722410e-02  6.32395347e-02  1.33878096e-01
#    2.83419932e-01  6.00000000e-01 -2.83419932e-01 -1.33878096e-01]
#  [-3.31850622e-04 -7.02527772e-04 -1.48725131e-03 -3.14851104e-03
#   -6.66539792e-03  1.41106475e-02  2.98722410e-02  6.32395347e-02
#    1.33878096e-01  2.83419932e-01  6.00000000e-01  2.83419932e-01]
#  [-1.56755134e-04 -3.31850622e-04 -7.02527772e-04 -1.48725131e-03
#   -3.14851104e-03 -6.66539792e-03  1.41106475e-02  2.98722410e-02
#   -6.32395347e-02 -1.33878096e-01  2.83419932e-01  6.00000000e-01]]

# %%
cols = ["lo_deep_Ask", "co_deep_Ask", "lo_top_Ask","co_top_Ask", "mo_Ask", "lo_inspread_Ask" ,
            "lo_inspread_Bid" , "mo_Bid", "co_top_Bid", "lo_top_Bid", "co_deep_Bid","lo_deep_Bid" ]

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
fig, ax = plt.subplots()
divider = make_axes_locatable(ax)
cax = divider.append_axes('right', size='5%', pad=0.05)
im = ax.imshow(mat.transpose(), cmap='coolwarm')
fig.colorbar(im, cax=cax, orientation='vertical')
# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(len(cols)), labels=[c +"->" for c in cols])
ax.set_yticks(np.arange(len(cols)), labels=cols)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(cols)):
    for j in range(len(cols)):
        text = ax.text(i,j, np.round(mat[i][j], decimals=2),
                               ha="center", va="center")
# fig.savefig("heatmap.png")
# plt.show()

# %%
# norm should be less than 1
np.max(np.linalg.eig(mat)[0])
# Out:
# (1.1342550157055886+0j)

# %%
# create fake TOD params - 1.0 for now but can be changed to whatever you wish
faketod = {}
for k in cols:
    faketod[k] = {}
    for k1 in np.arange(13):
        faketod[k][k1] = 1.0
with open("fakeData_Params_sod_eod_dictTOD_constt", "wb") as f:
    pickle.dump(faketod, f)

# %%
# Create fake power law kernel params from the above norm matrix
paramsFake = {}
for i in range(12):
    paramsFake[cols[i]] = 0.1*np.random.choice([0.3,0.4,0.5,0.6,0.7])
    for j in range(12):
        maxTOD = np.max(list(faketod[cols[j]].values()))
        beta = np.random.choice([1.5,1.6,1.7,1.8,1.9])
        gamma = (1+np.random.rand())*5e3
        alpha = np.abs(mat[i][j])*gamma*(beta-1)/maxTOD
        paramsFake[cols[i]+"->"+cols[j]] = (np.sign(mat[i][j]), np.array([alpha, beta, gamma]))

# %%
mat = np.zeros((12,12))
for i in range(len(cols)):
    for j in range(len(cols)):
        kernelParams = paramsFake.get(cols[j]+"->"+cols[i], None)
        if kernelParams is None: continue
        mat[i][j] = kernelParams[0]*kernelParams[1][0]/((-1 + kernelParams[1][1])*kernelParams[1][2])

# %%
# norm matrix from this fake power law kernels - does it match the above figure? - YES.
fig, ax = plt.subplots()
divider = make_axes_locatable(ax)
cax = divider.append_axes('right', size='5%', pad=0.05)
im = ax.imshow(mat.transpose(), cmap='coolwarm')
fig.colorbar(im, cax=cax, orientation='vertical')
# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(len(cols)), labels=[c +"->" for c in cols])
ax.set_yticks(np.arange(len(cols)), labels=cols)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(cols)):
    for j in range(len(cols)):
        text = ax.text(i,j, np.round(mat[i][j], decimals=2),
                               ha="center", va="center")
# fig.savefig("heatmap.png")
plt.show()

# %%
with open("fake_ParamsInferredWCutoff_sod_eod_true", "wb") as f:
    pickle.dump(paramsFake, f)

# %% [markdown]
# ## Simulate Fake LOB Data

# %%
#os.mkdir("./simulated_data")
faketod, fakeparams=simulate_optimized.preprocessdata(paramsPath="fake_ParamsInferredWCutoff_sod_eod_true_optimize", todPath="fakeData_Params_sod_eod_dictTOD_constt")

# %%
for i in range(1):
    T, lob, lobL3, timefraction=simulate_optimized.simulate_optimized(1000, fakeparams, faketod, beta = 1., avgSpread = .01, spread0 = 5, price0 = 45)
    with open("./simulated_data/fake_simulated_sod_eod_"+ str(i) , "wb") as f:
        pickle.dump((T, lob, lobL3), f)
# Out:
# s:  3.006642768042941
# Timestamps_this:  [(), (), (), (), (), (3.006642768042941,), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 10), 'Bid_touch': (44.97, 72), 'Ask_deep': (45.02, 100), 'Bid_deep': (44.96, 771)}
#
# s:  3.0066607305032025
# Timestamps_this:  [(), (), (), (), (), (), (3.0066607305032025,), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 10), 'Bid_touch': (44.98, 100), 'Ask_deep': (45.02, 100), 'Bid_deep': (44.97, 72)}
#
# s:  3.0068508929959696
# Timestamps_this:  [(), (), (), (), (), (), (3.0068508929959696,), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 10), 'Bid_touch': (44.99, 10), 'Ask_deep': (45.02, 100), 'Bid_deep': (44.98, 100)}
#
# s:  3.0068754055695415
# Timestamps_this:  [(), (), (), (), (), (), (3.0068754055695415,), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 10), 'Bid_touch': (45.0, 100), 'Ask_deep': (45.02, 100), 'Bid_deep': (44.99, 10)}
#
# s:  3.386560796564519
# Timestamps_this:  [(3.386560796564519,), (), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 10), 'Bid_touch': (45.0, 100), 'Ask_deep': (45.02, 933), 'Bid_deep': (44.99, 10)}
#
# s:  3.386690831930315
# Timestamps_this:  [(3.386690831930315,), (), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 10), 'Bid_touch': (45.0, 100), 'Ask_deep': (45.02, 1033), 'Bid_deep': (44.99, 10)}
#
# s:  4.838829502270765
# Timestamps_this:  [(), (4.838829502270765,), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 10), 'Bid_touch': (45.0, 100), 'Ask_deep': (45.02, 1013.0), 'Bid_deep': (44.99, 10)}
#
# s:  6.109326416305628
# Timestamps_this:  [(), (), (), (6.109326416305628,), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 1013.0), 'Bid_touch': (45.0, 100), 'Ask_deep': (45.03, 68), 'Bid_deep': (44.99, 10)}
#
# s:  6.109495978364378
# Timestamps_this:  [(), (6.109495978364378,), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 1013.0), 'Bid_touch': (45.0, 100), 'Ask_deep': (45.03, 62.0), 'Bid_deep': (44.99, 10)}
#
# s:  8.775136239285043
# Timestamps_this:  [(), (), (), (), (), (), (), (8.775136239285043,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 1013.0), 'Bid_touch': (45.0, 31), 'Ask_deep': (45.03, 62.0), 'Bid_deep': (44.99, 10)}
#
# s:  8.775378816095216
# Timestamps_this:  [(), (), (), (), (), (), (8.775378816095216,), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 1013.0), 'Bid_touch': (45.01, 100), 'Ask_deep': (45.03, 62.0), 'Bid_deep': (45.0, 31)}
#
# s:  10.187719667494935
# Timestamps_this:  [(), (), (), (10.187719667494935,), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 993.0), 'Bid_touch': (45.01, 100), 'Ask_deep': (45.03, 62.0), 'Bid_deep': (45.0, 31)}
#
# s:  10.187848427696638
# Timestamps_this:  [(), (), (), (10.187848427696638,), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 160.0), 'Bid_touch': (45.01, 100), 'Ask_deep': (45.03, 62.0), 'Bid_deep': (45.0, 31)}
#
# s:  10.188703695122868
# Timestamps_this:  [(), (), (), (10.188703695122868,), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 140.0), 'Bid_touch': (45.01, 100), 'Ask_deep': (45.03, 62.0), 'Bid_deep': (45.0, 31)}
#
# s:  11.77425397362257
# Timestamps_this:  [(), (), (11.77425397362257,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 240.0), 'Bid_touch': (45.01, 100), 'Ask_deep': (45.03, 62.0), 'Bid_deep': (45.0, 31)}
#
# s:  15.732319074489231
# Timestamps_this:  [(15.732319074489231,), (), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 240.0), 'Bid_touch': (45.01, 100), 'Ask_deep': (45.03, 289.0), 'Bid_deep': (45.0, 31)}
#
# s:  15.910525964438003
# Timestamps_this:  [(15.910525964438003,), (), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 240.0), 'Bid_touch': (45.01, 100), 'Ask_deep': (45.03, 389.0), 'Bid_deep': (45.0, 31)}
#
# s:  17.583524807572314
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (17.583524807572314,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 240.0), 'Bid_touch': (45.01, 396), 'Ask_deep': (45.03, 389.0), 'Bid_deep': (45.0, 31)}
#
# s:  17.59514850995159
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (17.59514850995159,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 240.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 389.0), 'Bid_deep': (45.0, 31)}
#
# s:  18.329905112128927
# Timestamps_this:  [(), (), (18.329905112128927,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 263.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 389.0), 'Bid_deep': (45.0, 31)}
#
# s:  21.581920326463734
# Timestamps_this:  [(), (21.581920326463734,), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 263.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.0047322154466
# Timestamps_this:  [(), (), (23.0047322154466,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 824.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.00484465685199
# Timestamps_this:  [(), (), (23.00484465685199,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 1107.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.005061921821284
# Timestamps_this:  [(), (), (23.005061921821284,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 1207.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.005108056112668
# Timestamps_this:  [(), (), (23.005108056112668,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 1291.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.005135468968472
# Timestamps_this:  [(), (), (23.005135468968472,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 1391.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.005306410682575
# Timestamps_this:  [(), (), (), (), (23.005306410682575,), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 1209.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.005421564212188
# Timestamps_this:  [(), (), (23.005421564212188,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 1573.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.005768472276813
# Timestamps_this:  [(), (), (23.005768472276813,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 1673.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.005982605091244
# Timestamps_this:  [(), (), (23.005982605091244,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 1994.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.00609794753085
# Timestamps_this:  [(), (), (23.00609794753085,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 2094.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.00618932656051
# Timestamps_this:  [(), (), (23.00618932656051,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 2180.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.029900644692667
# Timestamps_this:  [(), (), (23.029900644692667,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 2280.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.02998447304529
# Timestamps_this:  [(), (), (23.02998447304529,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 2380.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.030002320369093
# Timestamps_this:  [(), (), (23.030002320369093,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 2624.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.03010429600159
# Timestamps_this:  [(), (), (23.03010429600159,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 2697.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.030155023823788
# Timestamps_this:  [(), (), (23.030155023823788,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 2775.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.030224786635564
# Timestamps_this:  [(), (), (23.030224786635564,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 2875.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.030255502338896
# Timestamps_this:  [(), (), (23.030255502338896,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 2975.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.03100496340162
# Timestamps_this:  [(), (), (23.03100496340162,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3471.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.03150811071543
# Timestamps_this:  [(), (), (23.03150811071543,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3571.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.03174982657292
# Timestamps_this:  [(), (), (), (), (23.03174982657292,), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3471.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.031810207192112
# Timestamps_this:  [(), (), (23.031810207192112,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4285.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.031932409383664
# Timestamps_this:  [(), (), (23.031932409383664,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4385.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.033558828645305
# Timestamps_this:  [(), (), (23.033558828645305,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4485.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.03436363888668
# Timestamps_this:  [(), (), (), (), (23.03436363888668,), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4385.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.037268820294205
# Timestamps_this:  [(), (), (23.037268820294205,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4446.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.104489395589237
# Timestamps_this:  [(), (), (), (), (23.104489395589237,), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4445.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.617202825501334
# Timestamps_this:  [(), (), (23.617202825501334,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4729.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.617231177654798
# Timestamps_this:  [(), (), (23.617231177654798,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4829.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.617249625676273
# Timestamps_this:  [(), (), (23.617249625676273,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5135.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.617672733515466
# Timestamps_this:  [(), (), (23.617672733515466,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5235.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.6178827142042
# Timestamps_this:  [(), (), (), (), (23.6178827142042,), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4981.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.617969044662306
# Timestamps_this:  [(), (), (), (), (23.617969044662306,), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4881.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.619467023403026
# Timestamps_this:  [(), (), (), (), (23.619467023403026,), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4875.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.61966074261018
# Timestamps_this:  [(), (), (), (), (23.61966074261018,), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4775.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.619840646396725
# Timestamps_this:  [(), (), (), (23.619840646396725,), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4689.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.62016647167877
# Timestamps_this:  [(), (), (), (), (23.62016647167877,), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4589.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.621702931172436
# Timestamps_this:  [(), (), (), (), (23.621702931172436,), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4489.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  23.74606833382524
# Timestamps_this:  [(), (), (), (), (23.74606833382524,), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4472.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  25.099004627029274
# Timestamps_this:  [(), (), (25.099004627029274,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5417.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  25.107388302117734
# Timestamps_this:  [(), (), (25.107388302117734,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5418.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  28.50279827526355
# Timestamps_this:  [(), (), (), (28.50279827526355,), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5134.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  28.502840072759103
# Timestamps_this:  [(), (), (), (28.502840072759103,), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5034.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  28.50285538549219
# Timestamps_this:  [(), (), (), (28.50285538549219,), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4987.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  28.502888028893327
# Timestamps_this:  [(), (), (28.502888028893327,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5041.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  28.518292170683534
# Timestamps_this:  [(), (), (28.518292170683534,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5141.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  28.52130855515101
# Timestamps_this:  [(), (), (28.52130855515101,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5241.0), 'Bid_touch': (45.01, 496), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  28.737191186950245
# Timestamps_this:  [(), (), (), (), (), (), (), (28.737191186950245,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5241.0), 'Bid_touch': (45.01, 479), 'Ask_deep': (45.03, 162.0), 'Bid_deep': (45.0, 31)}
#
# s:  31.181955763257633
# Timestamps_this:  [(31.181955763257633,), (), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5241.0), 'Bid_touch': (45.01, 479), 'Ask_deep': (45.03, 262.0), 'Bid_deep': (45.0, 31)}
#
# s:  31.182045555680645
# Timestamps_this:  [(31.182045555680645,), (), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5241.0), 'Bid_touch': (45.01, 479), 'Ask_deep': (45.03, 362.0), 'Bid_deep': (45.0, 31)}
#
# s:  31.182147967753885
# Timestamps_this:  [(), (31.182147967753885,), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5241.0), 'Bid_touch': (45.01, 479), 'Ask_deep': (45.03, 356.0), 'Bid_deep': (45.0, 31)}
#
# s:  31.182499286305333
# Timestamps_this:  [(31.182499286305333,), (), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5241.0), 'Bid_touch': (45.01, 479), 'Ask_deep': (45.03, 456.0), 'Bid_deep': (45.0, 31)}
#
# s:  31.44491215944874
# Timestamps_this:  [(), (), (), (), (31.44491215944874,), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5141.0), 'Bid_touch': (45.01, 479), 'Ask_deep': (45.03, 456.0), 'Bid_deep': (45.0, 31)}
#
# s:  33.80370191816059
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (33.80370191816059,)]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5141.0), 'Bid_touch': (45.01, 479), 'Ask_deep': (45.03, 456.0), 'Bid_deep': (45.0, 131)}
#
# s:  33.80380177158158
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (33.80380177158158,)]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5141.0), 'Bid_touch': (45.01, 479), 'Ask_deep': (45.03, 456.0), 'Bid_deep': (45.0, 415)}
#
# s:  33.803955583544564
# Timestamps_this:  [(), (), (), (), (), (), (), (33.803955583544564,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5141.0), 'Bid_touch': (45.01, 417), 'Ask_deep': (45.03, 456.0), 'Bid_deep': (45.0, 415)}
#
# s:  33.80781503324814
# Timestamps_this:  [(), (), (), (), (), (), (), (33.80781503324814,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5141.0), 'Bid_touch': (45.01, 355), 'Ask_deep': (45.03, 456.0), 'Bid_deep': (45.0, 415)}
#
# s:  33.80783348506997
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (33.80783348506997,), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5141.0), 'Bid_touch': (45.01, 355), 'Ask_deep': (45.03, 456.0), 'Bid_deep': (45.0, 384)}
#
# s:  33.808177904303925
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (33.808177904303925,), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5141.0), 'Bid_touch': (45.01, 355), 'Ask_deep': (45.03, 456.0), 'Bid_deep': (45.0, 100)}
#
# s:  33.80856269918572
# Timestamps_this:  [(), (), (), (), (), (), (), (33.80856269918572,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5141.0), 'Bid_touch': (45.01, 51), 'Ask_deep': (45.03, 456.0), 'Bid_deep': (45.0, 100)}
#
# s:  34.02080637758621
# Timestamps_this:  [(34.02080637758621,), (), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5141.0), 'Bid_touch': (45.01, 51), 'Ask_deep': (45.03, 556.0), 'Bid_deep': (45.0, 100)}
#
# s:  34.02108012919518
# Timestamps_this:  [(34.02108012919518,), (), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5141.0), 'Bid_touch': (45.01, 51), 'Ask_deep': (45.03, 1090.0), 'Bid_deep': (45.0, 100)}
#
# s:  34.02112919474075
# Timestamps_this:  [(34.02112919474075,), (), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5141.0), 'Bid_touch': (45.01, 51), 'Ask_deep': (45.03, 1425.0), 'Bid_deep': (45.0, 100)}
#
# s:  34.02127332663547
# Timestamps_this:  [(), (34.02127332663547,), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5141.0), 'Bid_touch': (45.01, 51), 'Ask_deep': (45.03, 1419.0), 'Bid_deep': (45.0, 100)}
#
# s:  34.02170725566222
# Timestamps_this:  [(), (34.02170725566222,), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5141.0), 'Bid_touch': (45.01, 51), 'Ask_deep': (45.03, 1413.0), 'Bid_deep': (45.0, 100)}
#
# s:  34.02191241713943
# Timestamps_this:  [(), (34.02191241713943,), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5141.0), 'Bid_touch': (45.01, 51), 'Ask_deep': (45.03, 1313.0), 'Bid_deep': (45.0, 100)}
#
# s:  34.021915829595294
# Timestamps_this:  [(), (34.021915829595294,), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5141.0), 'Bid_touch': (45.01, 51), 'Ask_deep': (45.03, 1213.0), 'Bid_deep': (45.0, 100)}
#
# s:  34.022814105571086
# Timestamps_this:  [(), (34.022814105571086,), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5141.0), 'Bid_touch': (45.01, 51), 'Ask_deep': (45.03, 1113.0), 'Bid_deep': (45.0, 100)}
#
# s:  34.02290463667011
# Timestamps_this:  [(), (34.02290463667011,), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5141.0), 'Bid_touch': (45.01, 51), 'Ask_deep': (45.03, 1107.0), 'Bid_deep': (45.0, 100)}
#
# s:  34.05197247869
# Timestamps_this:  [(), (34.05197247869,), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5141.0), 'Bid_touch': (45.01, 51), 'Ask_deep': (45.03, 1093.0), 'Bid_deep': (45.0, 100)}
#
# s:  34.11463547766161
# Timestamps_this:  [(), (), (), (), (), (), (), (34.11463547766161,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5141.0), 'Bid_touch': (45.0, 51), 'Ask_deep': (45.03, 1093.0), 'Bid_deep': (44.99, 100)}
#
# s:  34.37970248582343
# Timestamps_this:  [(), (), (), (), (), (34.37970248582343,), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 51), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 100)}
#
# s:  37.80583042381698
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (37.80583042381698,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 151), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 100)}
#
# s:  37.8058535533087
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (37.8058535533087,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 251), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 100)}
#
# s:  38.04135230135628
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (38.04135230135628,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 252), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 100)}
#
# s:  38.041474046257086
# Timestamps_this:  [(), (), (), (), (), (), (), (38.041474046257086,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 189), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 100)}
#
# s:  38.0415454045823
# Timestamps_this:  [(), (), (), (), (), (), (), (38.0415454045823,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 130), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 100)}
#
# s:  38.04161356806646
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (38.04161356806646,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 230), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 100)}
#
# s:  38.041870728689965
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (38.041870728689965,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 318), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 100)}
#
# s:  38.04187889798496
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (38.04187889798496,)]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 318), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 853)}
#
# s:  38.042064342469395
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (38.042064342469395,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 418), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 853)}
#
# s:  38.042132958102215
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (38.042132958102215,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 518), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 853)}
#
# s:  38.04273700872906
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (38.04273700872906,)]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 518), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 1835)}
#
# s:  38.04382711253005
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (38.04382711253005,)]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 518), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 1845)}
#
# s:  38.04429185518819
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (38.04429185518819,)]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 518), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 1945)}
#
# s:  38.044724018969376
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (38.044724018969376,)]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 518), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 2326)}
#
# s:  38.04513880779846
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (38.04513880779846,)]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 518), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 2372)}
#
# s:  38.04584634274196
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (38.04584634274196,)]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 518), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 2472)}
#
# s:  38.045982779295834
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (38.045982779295834,)]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 518), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 2478)}
#
# s:  38.046289753246754
# Timestamps_this:  [(), (), (), (), (), (), (), (38.046289753246754,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 418), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 2478)}
#
# s:  38.0463982773177
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (38.0463982773177,)]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 418), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 2785)}
#
# s:  38.04792931669961
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (38.04792931669961,)]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 418), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 2795)}
#
# s:  38.04797194441221
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (38.04797194441221,)]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 418), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 2975)}
#
# s:  38.04837768313508
# Timestamps_this:  [(), (), (), (), (), (), (), (38.04837768313508,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 318), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 2975)}
#
# s:  38.048664815234766
# Timestamps_this:  [(), (), (), (), (), (), (), (38.048664815234766,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 207), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 2975)}
#
# s:  38.04885988413266
# Timestamps_this:  [(), (), (), (), (), (), (), (38.04885988413266,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 107), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 2975)}
#
# s:  38.04910358710644
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (38.04910358710644,)]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 107), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 3370)}
#
# s:  38.04990363739742
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (38.04990363739742,)]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 107), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 4376)}
#
# s:  38.04998781629122
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (38.04998781629122,)]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 107), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 4476)}
#
# s:  38.04999716839536
# Timestamps_this:  [(), (), (), (), (), (), (), (38.04999716839536,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 99), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 4476)}
#
# s:  38.050050313679584
# Timestamps_this:  [(), (), (), (), (), (), (), (38.050050313679584,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (44.99, 4475), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.98, 648)}
#
# s:  38.050092692573216
# Timestamps_this:  [(), (), (), (), (), (), (38.050092692573216,), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 50), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 4475)}
#
# s:  38.05013578303262
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (38.05013578303262,)]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 50), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 4485)}
#
# s:  38.05099450052694
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (38.05099450052694,)]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 50), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 4739)}
#
# s:  38.05213804208612
# Timestamps_this:  [(), (), (), (), (), (), (), (38.05213804208612,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (44.99, 4689), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.98, 2192)}
#
# s:  38.30900405446647
# Timestamps_this:  [(), (), (), (), (), (), (38.30900405446647,), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 100), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 4689)}
#
# s:  40.32954267989348
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (40.32954267989348,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 100), 'Bid_touch': (45.0, 200), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 4689)}
#
# s:  41.776346917252546
# Timestamps_this:  [(), (), (41.776346917252546,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 200), 'Bid_touch': (45.0, 200), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 4689)}
#
# s:  41.77706821505268
# Timestamps_this:  [(), (), (41.77706821505268,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 577), 'Bid_touch': (45.0, 200), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 4689)}
#
# s:  41.778018972065425
# Timestamps_this:  [(), (), (41.778018972065425,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 677), 'Bid_touch': (45.0, 200), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 4689)}
#
# s:  41.778114647372554
# Timestamps_this:  [(), (), (41.778114647372554,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 777), 'Bid_touch': (45.0, 200), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 4689)}
#
# s:  41.78297513566383
# Timestamps_this:  [(), (), (41.78297513566383,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 877), 'Bid_touch': (45.0, 200), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 4689)}
#
# s:  42.15655536820613
# Timestamps_this:  [(), (), (), (), (), (), (), (42.15655536820613,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 877), 'Bid_touch': (44.99, 4672), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.98, 1020)}
#
# s:  42.15661854148546
# Timestamps_this:  [(), (), (), (), (), (), (42.15661854148546,), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 877), 'Bid_touch': (45.0, 222), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 4672)}
#
# s:  43.03335508339084
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (43.03335508339084,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 877), 'Bid_touch': (45.0, 272), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 4672)}
#
# s:  43.03404721220436
# Timestamps_this:  [(), (), (), (), (), (), (), (43.03404721220436,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 877), 'Bid_touch': (45.0, 222), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 4672)}
#
# s:  44.967199973232745
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (44.967199973232745,)]
# Snapshot LOB0:  {'Ask_touch': (45.01, 877), 'Bid_touch': (45.0, 222), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 4772)}
#
# s:  44.96722241886821
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (44.96722241886821,)]
# Snapshot LOB0:  {'Ask_touch': (45.01, 877), 'Bid_touch': (45.0, 222), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 6034)}
#
# s:  46.284807167009056
# Timestamps_this:  [(), (), (), (), (), (), (), (46.284807167009056,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 877), 'Bid_touch': (45.0, 112), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 6034)}
#
# s:  46.28495909738282
# Timestamps_this:  [(), (), (), (), (), (), (), (46.28495909738282,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 877), 'Bid_touch': (45.0, 12), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 6034)}
#
# s:  46.28533856367733
# Timestamps_this:  [(), (), (), (46.28533856367733,), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 777), 'Bid_touch': (45.0, 12), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 6034)}
#
# s:  46.2853505272748
# Timestamps_this:  [(), (), (), (46.2853505272748,), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 677), 'Bid_touch': (45.0, 12), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 6034)}
#
# s:  46.2874201223611
# Timestamps_this:  [(), (), (), (), (), (), (), (46.2874201223611,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 677), 'Bid_touch': (44.99, 5946), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.98, 787)}
#
# s:  46.28757652203632
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (46.28757652203632,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 677), 'Bid_touch': (44.99, 6046), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.98, 787)}
#
# s:  46.28761258315083
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (46.28761258315083,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 677), 'Bid_touch': (44.99, 6146), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.98, 787)}
#
# s:  46.28768687287438
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (46.28768687287438,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 677), 'Bid_touch': (44.99, 6246), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.98, 787)}
#
# s:  46.28768911087442
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (46.28768911087442,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 677), 'Bid_touch': (44.99, 6346), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.98, 787)}
#
# s:  46.2880942165135
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (46.2880942165135,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 677), 'Bid_touch': (44.99, 6446), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.98, 787)}
#
# s:  46.28816751574007
# Timestamps_this:  [(), (), (), (), (), (), (46.28816751574007,), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 677), 'Bid_touch': (45.0, 100), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 6446)}
#
# s:  46.288218554991936
# Timestamps_this:  [(), (), (), (), (), (), (), (46.288218554991936,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 677), 'Bid_touch': (44.99, 6446), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.98, 100)}
#
# s:  46.288443736664526
# Timestamps_this:  [(), (), (), (), (), (), (), (46.288443736664526,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 677), 'Bid_touch': (44.99, 6346), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.98, 100)}
#
# s:  46.28851685754579
# Timestamps_this:  [(), (), (), (), (), (), (46.28851685754579,), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 677), 'Bid_touch': (45.0, 7), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 6346)}
#
# s:  46.29711486774732
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (46.29711486774732,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 677), 'Bid_touch': (45.0, 107), 'Ask_deep': (45.02, 5141.0), 'Bid_deep': (44.99, 6346)}
#
# s:  51.13863048152761
# Timestamps_this:  [(), (51.13863048152761,), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 677), 'Bid_touch': (45.0, 107), 'Ask_deep': (45.02, 4196.0), 'Bid_deep': (44.99, 6346)}
#
# s:  53.983267162439915
# Timestamps_this:  [(), (), (), (53.983267162439915,), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 300), 'Bid_touch': (45.0, 107), 'Ask_deep': (45.02, 4196.0), 'Bid_deep': (44.99, 6346)}
#
# s:  53.98393264279414
# Timestamps_this:  [(), (), (), (53.98393264279414,), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 200), 'Bid_touch': (45.0, 107), 'Ask_deep': (45.02, 4196.0), 'Bid_deep': (44.99, 6346)}
#
# s:  53.98395003308278
# Timestamps_this:  [(), (), (53.98395003308278,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 332), 'Bid_touch': (45.0, 107), 'Ask_deep': (45.02, 4196.0), 'Bid_deep': (44.99, 6346)}
#
# s:  56.479740236396246
# Timestamps_this:  [(), (), (56.479740236396246,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 622), 'Bid_touch': (45.0, 107), 'Ask_deep': (45.02, 4196.0), 'Bid_deep': (44.99, 6346)}
#
# s:  56.49326864468872
# Timestamps_this:  [(), (), (), (), (56.49326864468872,), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 522), 'Bid_touch': (45.0, 107), 'Ask_deep': (45.02, 4196.0), 'Bid_deep': (44.99, 6346)}
#
# s:  56.493416413393064
# Timestamps_this:  [(), (), (), (56.493416413393064,), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 422), 'Bid_touch': (45.0, 107), 'Ask_deep': (45.02, 4196.0), 'Bid_deep': (44.99, 6346)}
#
# s:  61.1275917254493
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (61.1275917254493,)]
# Snapshot LOB0:  {'Ask_touch': (45.01, 422), 'Bid_touch': (45.0, 107), 'Ask_deep': (45.02, 4196.0), 'Bid_deep': (44.99, 6724)}
#
# s:  61.12782162618705
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (61.12782162618705,)]
# Snapshot LOB0:  {'Ask_touch': (45.01, 422), 'Bid_touch': (45.0, 107), 'Ask_deep': (45.02, 4196.0), 'Bid_deep': (44.99, 6774)}
#
# s:  61.12784380676472
# Timestamps_this:  [(), (), (), (), (), (), (), (61.12784380676472,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 422), 'Bid_touch': (45.0, 7), 'Ask_deep': (45.02, 4196.0), 'Bid_deep': (44.99, 6774)}
#
# s:  61.127908066179735
# Timestamps_this:  [(), (), (), (), (), (), (), (61.127908066179735,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 422), 'Bid_touch': (44.99, 6432), 'Ask_deep': (45.02, 4196.0), 'Bid_deep': (44.98, 129)}
#
# s:  61.127983248742744
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (61.127983248742744,)]
# Snapshot LOB0:  {'Ask_touch': (45.01, 422), 'Bid_touch': (44.99, 6432), 'Ask_deep': (45.02, 4196.0), 'Bid_deep': (44.98, 229)}
#
# s:  61.128065182878984
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (61.128065182878984,)]
# Snapshot LOB0:  {'Ask_touch': (45.01, 422), 'Bid_touch': (44.99, 6432), 'Ask_deep': (45.02, 4196.0), 'Bid_deep': (44.98, 516)}
#
# s:  61.12811916896322
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (61.12811916896322,)]
# Snapshot LOB0:  {'Ask_touch': (45.01, 422), 'Bid_touch': (44.99, 6432), 'Ask_deep': (45.02, 4196.0), 'Bid_deep': (44.98, 677)}
#
# s:  61.12820654473876
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (61.12820654473876,)]
# Snapshot LOB0:  {'Ask_touch': (45.01, 422), 'Bid_touch': (44.99, 6432), 'Ask_deep': (45.02, 4196.0), 'Bid_deep': (44.98, 830)}
#
# s:  61.129466727773995
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (61.129466727773995,)]
# Snapshot LOB0:  {'Ask_touch': (45.01, 422), 'Bid_touch': (44.99, 6432), 'Ask_deep': (45.02, 4196.0), 'Bid_deep': (44.98, 1060)}
#
# s:  61.129761703128516
# Timestamps_this:  [(), (), (), (), (), (), (), (61.129761703128516,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 422), 'Bid_touch': (44.99, 6316), 'Ask_deep': (45.02, 4196.0), 'Bid_deep': (44.98, 1060)}
#
# s:  61.129766008841756
# Timestamps_this:  [(), (), (61.129766008841756,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 522), 'Bid_touch': (44.99, 6316), 'Ask_deep': (45.02, 4196.0), 'Bid_deep': (44.98, 1060)}
#
# s:  61.57296550599011
# Timestamps_this:  [(), (), (), (), (), (), (), (61.57296550599011,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.01, 522), 'Bid_touch': (44.99, 6281), 'Ask_deep': (45.02, 4196.0), 'Bid_deep': (44.98, 1060)}
#
# s:  62.40619414370089
# Timestamps_this:  [(), (), (), (), (), (62.40619414370089,), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.0, 166), 'Bid_touch': (44.99, 6281), 'Ask_deep': (45.01, 522), 'Bid_deep': (44.98, 1060)}
#
# s:  62.41130429548688
# Timestamps_this:  [(), (), (), (), (), (), (), (), (62.41130429548688,), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.0, 166), 'Bid_touch': (44.99, 6101.0), 'Ask_deep': (45.01, 522), 'Bid_deep': (44.98, 1060)}
#
# s:  62.41132506726601
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (62.41132506726601,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.0, 166), 'Bid_touch': (44.99, 6201.0), 'Ask_deep': (45.01, 522), 'Bid_deep': (44.98, 1060)}
#
# s:  62.41188822609714
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (62.41188822609714,)]
# Snapshot LOB0:  {'Ask_touch': (45.0, 166), 'Bid_touch': (44.99, 6201.0), 'Ask_deep': (45.01, 522), 'Bid_deep': (44.98, 1160)}
#
# s:  62.412136368091346
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (62.412136368091346,)]
# Snapshot LOB0:  {'Ask_touch': (45.0, 166), 'Bid_touch': (44.99, 6201.0), 'Ask_deep': (45.01, 522), 'Bid_deep': (44.98, 1260)}
#
# s:  63.26380164356682
# Timestamps_this:  [(), (), (63.26380164356682,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.0, 266), 'Bid_touch': (44.99, 6201.0), 'Ask_deep': (45.01, 522), 'Bid_deep': (44.98, 1260)}
#
# s:  64.46265166022769
# Timestamps_this:  [(), (), (), (), (), (), (), (), (64.46265166022769,), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.0, 266), 'Bid_touch': (44.99, 6101.0), 'Ask_deep': (45.01, 522), 'Bid_deep': (44.98, 1260)}
#
# s:  64.46270039459215
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (64.46270039459215,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.0, 266), 'Bid_touch': (44.99, 6838.0), 'Ask_deep': (45.01, 522), 'Bid_deep': (44.98, 1260)}
#
# s:  68.67004607953331
# Timestamps_this:  [(), (), (68.67004607953331,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.0, 276), 'Bid_touch': (44.99, 6838.0), 'Ask_deep': (45.01, 522), 'Bid_deep': (44.98, 1260)}
#
# s:  68.82008384489225
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (68.82008384489225,)]
# Snapshot LOB0:  {'Ask_touch': (45.0, 276), 'Bid_touch': (44.99, 6838.0), 'Ask_deep': (45.01, 522), 'Bid_deep': (44.98, 1360)}
#
# s:  68.82017394244647
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (68.82017394244647,)]
# Snapshot LOB0:  {'Ask_touch': (45.0, 276), 'Bid_touch': (44.99, 6838.0), 'Ask_deep': (45.01, 522), 'Bid_deep': (44.98, 1460)}
#
# s:  69.4162799064648
# Timestamps_this:  [(69.4162799064648,), (), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.0, 276), 'Bid_touch': (44.99, 6838.0), 'Ask_deep': (45.01, 1328), 'Bid_deep': (44.98, 1460)}
#
# s:  69.42215189626451
# Timestamps_this:  [(69.42215189626451,), (), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.0, 276), 'Bid_touch': (44.99, 6838.0), 'Ask_deep': (45.01, 1428), 'Bid_deep': (44.98, 1460)}
#
# s:  74.78102045323685
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (74.78102045323685,)]
# Snapshot LOB0:  {'Ask_touch': (45.0, 276), 'Bid_touch': (44.99, 6838.0), 'Ask_deep': (45.01, 1428), 'Bid_deep': (44.98, 1639)}
#
# s:  77.57131558880985
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (77.57131558880985,), ()]
# Snapshot LOB0:  {'Ask_touch': (45.0, 276), 'Bid_touch': (44.99, 6838.0), 'Ask_deep': (45.01, 1428), 'Bid_deep': (44.98, 1627.0)}
#
# s:  77.57136926982487
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (77.57136926982487,), ()]
# Snapshot LOB0:  {'Ask_touch': (45.0, 276), 'Bid_touch': (44.99, 6838.0), 'Ask_deep': (45.01, 1428), 'Bid_deep': (44.98, 1527.0)}
#
# s:  77.5719942158568
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (77.5719942158568,), ()]
# Snapshot LOB0:  {'Ask_touch': (45.0, 276), 'Bid_touch': (44.99, 6838.0), 'Ask_deep': (45.01, 1428), 'Bid_deep': (44.98, 1515.0)}
#
# s:  77.90776067663221
# Timestamps_this:  [(), (), (), (), (), (), (), (), (77.90776067663221,), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.0, 276), 'Bid_touch': (44.99, 5832.0), 'Ask_deep': (45.01, 1428), 'Bid_deep': (44.98, 1515.0)}
#
# s:  77.90778524897391
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (77.90778524897391,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.0, 276), 'Bid_touch': (44.99, 5932.0), 'Ask_deep': (45.01, 1428), 'Bid_deep': (44.98, 1515.0)}
#
# s:  82.01477274127487
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (82.01477274127487,)]
# Snapshot LOB0:  {'Ask_touch': (45.0, 276), 'Bid_touch': (44.99, 5932.0), 'Ask_deep': (45.01, 1428), 'Bid_deep': (44.98, 1536.0)}
#
# s:  82.01526854881563
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (82.01526854881563,)]
# Snapshot LOB0:  {'Ask_touch': (45.0, 276), 'Bid_touch': (44.99, 5932.0), 'Ask_deep': (45.01, 1428), 'Bid_deep': (44.98, 1707.0)}
#
# s:  83.8319924571201
# Timestamps_this:  [(83.8319924571201,), (), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.0, 276), 'Bid_touch': (44.99, 5932.0), 'Ask_deep': (45.01, 1723), 'Bid_deep': (44.98, 1707.0)}
#
# s:  87.45950529334438
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (87.45950529334438,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.0, 276), 'Bid_touch': (44.99, 6032.0), 'Ask_deep': (45.01, 1723), 'Bid_deep': (44.98, 1707.0)}
#
# s:  87.45953405506103
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (87.45953405506103,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.0, 276), 'Bid_touch': (44.99, 6132.0), 'Ask_deep': (45.01, 1723), 'Bid_deep': (44.98, 1707.0)}
#
# s:  87.4596725674566
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (87.4596725674566,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.0, 276), 'Bid_touch': (44.99, 6232.0), 'Ask_deep': (45.01, 1723), 'Bid_deep': (44.98, 1707.0)}
#
# s:  87.45967468739009
# Timestamps_this:  [(), (), (), (), (), (), (), (87.45967468739009,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.0, 276), 'Bid_touch': (44.99, 6167.0), 'Ask_deep': (45.01, 1723), 'Bid_deep': (44.98, 1707.0)}
#
# s:  87.45969182805528
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (87.45969182805528,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.0, 276), 'Bid_touch': (44.99, 6267.0), 'Ask_deep': (45.01, 1723), 'Bid_deep': (44.98, 1707.0)}
#
# s:  87.45976289666262
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (87.45976289666262,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.0, 276), 'Bid_touch': (44.99, 6367.0), 'Ask_deep': (45.01, 1723), 'Bid_deep': (44.98, 1707.0)}
#
# s:  87.45981997674056
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (87.45981997674056,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.0, 276), 'Bid_touch': (44.99, 6847.0), 'Ask_deep': (45.01, 1723), 'Bid_deep': (44.98, 1707.0)}
#
# s:  87.45983703351015
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (87.45983703351015,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.0, 276), 'Bid_touch': (44.99, 6947.0), 'Ask_deep': (45.01, 1723), 'Bid_deep': (44.98, 1707.0)}
#
# s:  87.45984400252769
# Timestamps_this:  [(), (), (), (), (), (), (), (87.45984400252769,), (), (), (), ()]
# ...
#
# s:  945.0102472603037
# Timestamps_this:  [(), (), (945.0102472603037,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 2877), 'Bid_touch': (45.01, 1976), 'Ask_deep': (45.03, 287.0), 'Bid_deep': (45.0, 15083.0)}
#
# s:  945.0104309952815
# Timestamps_this:  [(), (), (945.0104309952815,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3614), 'Bid_touch': (45.01, 1976), 'Ask_deep': (45.03, 287.0), 'Bid_deep': (45.0, 15083.0)}
#
# s:  945.0107647531452
# Timestamps_this:  [(), (), (945.0107647531452,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3714), 'Bid_touch': (45.01, 1976), 'Ask_deep': (45.03, 287.0), 'Bid_deep': (45.0, 15083.0)}
#
# s:  945.0109310506969
# Timestamps_this:  [(), (), (945.0109310506969,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3814), 'Bid_touch': (45.01, 1976), 'Ask_deep': (45.03, 287.0), 'Bid_deep': (45.0, 15083.0)}
#
# s:  945.0109414715873
# Timestamps_this:  [(), (), (945.0109414715873,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3919), 'Bid_touch': (45.01, 1976), 'Ask_deep': (45.03, 287.0), 'Bid_deep': (45.0, 15083.0)}
#
# s:  945.0110136042848
# Timestamps_this:  [(), (), (945.0110136042848,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4019), 'Bid_touch': (45.01, 1976), 'Ask_deep': (45.03, 287.0), 'Bid_deep': (45.0, 15083.0)}
#
# s:  945.0112901379757
# Timestamps_this:  [(), (), (945.0112901379757,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4119), 'Bid_touch': (45.01, 1976), 'Ask_deep': (45.03, 287.0), 'Bid_deep': (45.0, 15083.0)}
#
# s:  945.0121386623828
# Timestamps_this:  [(), (), (945.0121386623828,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4310), 'Bid_touch': (45.01, 1976), 'Ask_deep': (45.03, 287.0), 'Bid_deep': (45.0, 15083.0)}
#
# s:  945.0123532139356
# Timestamps_this:  [(), (), (945.0123532139356,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4410), 'Bid_touch': (45.01, 1976), 'Ask_deep': (45.03, 287.0), 'Bid_deep': (45.0, 15083.0)}
#
# s:  945.4355061394036
# Timestamps_this:  [(), (), (945.4355061394036,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4510), 'Bid_touch': (45.01, 1976), 'Ask_deep': (45.03, 287.0), 'Bid_deep': (45.0, 15083.0)}
#
# s:  946.370743270451
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (946.370743270451,)]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4510), 'Bid_touch': (45.01, 1976), 'Ask_deep': (45.03, 287.0), 'Bid_deep': (45.0, 15183.0)}
#
# s:  946.371673470019
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (946.371673470019,)]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4510), 'Bid_touch': (45.01, 1976), 'Ask_deep': (45.03, 287.0), 'Bid_deep': (45.0, 15233.0)}
#
# s:  948.7561505771343
# Timestamps_this:  [(), (), (948.7561505771343,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4610), 'Bid_touch': (45.01, 1976), 'Ask_deep': (45.03, 287.0), 'Bid_deep': (45.0, 15233.0)}
#
# s:  950.5892196584032
# Timestamps_this:  [(), (), (), (), (), (), (), (950.5892196584032,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4610), 'Bid_touch': (45.01, 1970), 'Ask_deep': (45.03, 287.0), 'Bid_deep': (45.0, 15233.0)}
#
# s:  950.5892780148911
# Timestamps_this:  [(), (), (), (), (), (), (), (950.5892780148911,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4610), 'Bid_touch': (45.01, 1934), 'Ask_deep': (45.03, 287.0), 'Bid_deep': (45.0, 15233.0)}
#
# s:  950.5892987740427
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (950.5892987740427,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4610), 'Bid_touch': (45.01, 2124), 'Ask_deep': (45.03, 287.0), 'Bid_deep': (45.0, 15233.0)}
#
# s:  950.5893309539947
# Timestamps_this:  [(), (), (), (), (), (), (), (950.5893309539947,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4610), 'Bid_touch': (45.01, 2024), 'Ask_deep': (45.03, 287.0), 'Bid_deep': (45.0, 15233.0)}
#
# s:  950.5895374125797
# Timestamps_this:  [(), (), (), (), (), (), (), (950.5895374125797,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4610), 'Bid_touch': (45.01, 1924), 'Ask_deep': (45.03, 287.0), 'Bid_deep': (45.0, 15233.0)}
#
# s:  950.645965556929
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (950.645965556929,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4610), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.03, 287.0), 'Bid_deep': (45.0, 15233.0)}
#
# s:  951.3633613412218
# Timestamps_this:  [(), (), (), (951.3633613412218,), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4510), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.03, 287.0), 'Bid_deep': (45.0, 15233.0)}
#
# s:  954.0172029039115
# Timestamps_this:  [(), (), (954.0172029039115,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4610), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.03, 287.0), 'Bid_deep': (45.0, 15233.0)}
#
# s:  954.0174869400317
# Timestamps_this:  [(), (), (954.0174869400317,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5016), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.03, 287.0), 'Bid_deep': (45.0, 15233.0)}
#
# s:  954.0179306309639
# Timestamps_this:  [(), (), (), (), (954.0179306309639,), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4963), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.03, 287.0), 'Bid_deep': (45.0, 15233.0)}
#
# s:  954.0278833765879
# Timestamps_this:  [(), (), (954.0278833765879,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 5063), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.03, 287.0), 'Bid_deep': (45.0, 15233.0)}
#
# s:  954.0286157020867
# Timestamps_this:  [(), (), (), (), (954.0286157020867,), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4932), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.03, 287.0), 'Bid_deep': (45.0, 15233.0)}
#
# s:  954.0286578225646
# Timestamps_this:  [(), (), (), (954.0286578225646,), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4832), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.03, 287.0), 'Bid_deep': (45.0, 15233.0)}
#
# s:  954.0287527666798
# Timestamps_this:  [(), (), (), (954.0287527666798,), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4732), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.03, 287.0), 'Bid_deep': (45.0, 15233.0)}
#
# s:  954.1666777953609
# Timestamps_this:  [(), (), (), (), (954.1666777953609,), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4632), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.03, 287.0), 'Bid_deep': (45.0, 15233.0)}
#
# s:  954.1740699877967
# Timestamps_this:  [(), (), (), (954.1740699877967,), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4532), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.03, 287.0), 'Bid_deep': (45.0, 15233.0)}
#
# s:  954.1740991890427
# Timestamps_this:  [(), (), (), (954.1740991890427,), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4433), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.03, 287.0), 'Bid_deep': (45.0, 15233.0)}
#
# s:  954.1790458797551
# Timestamps_this:  [(), (), (), (954.1790458797551,), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4333), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.03, 287.0), 'Bid_deep': (45.0, 15233.0)}
#
# s:  954.8908171956949
# Timestamps_this:  [(), (954.8908171956949,), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4333), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.03, 228.0), 'Bid_deep': (45.0, 15233.0)}
#
# s:  954.8911536557415
# Timestamps_this:  [(), (954.8911536557415,), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4333), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.03, 128.0), 'Bid_deep': (45.0, 15233.0)}
#
# s:  958.2509744888547
# Timestamps_this:  [(958.2509744888547,), (), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4333), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.03, 178.0), 'Bid_deep': (45.0, 15233.0)}
#
# s:  958.2511777427349
# Timestamps_this:  [(958.2511777427349,), (), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4333), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.03, 201.0), 'Bid_deep': (45.0, 15233.0)}
#
# s:  958.2514134487433
# Timestamps_this:  [(), (958.2514134487433,), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4333), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.03, 173.0), 'Bid_deep': (45.0, 15233.0)}
#
# s:  958.252718598655
# Timestamps_this:  [(), (958.252718598655,), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4333), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.03, 73.0), 'Bid_deep': (45.0, 15233.0)}
#
# s:  958.2527760929237
# Timestamps_this:  [(), (958.2527760929237,), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4333), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.03, 50.0), 'Bid_deep': (45.0, 15233.0)}
#
# s:  958.2528260749425
# Timestamps_this:  [(), (958.2528260749425,), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4333), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.04, 990), 'Bid_deep': (45.0, 15233.0)}
#
# s:  959.4834165813975
# Timestamps_this:  [(), (), (), (959.4834165813975,), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4191), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.04, 990), 'Bid_deep': (45.0, 15233.0)}
#
# s:  959.4838137158904
# Timestamps_this:  [(), (), (), (959.4838137158904,), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4091), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.04, 990), 'Bid_deep': (45.0, 15233.0)}
#
# s:  959.4838791900121
# Timestamps_this:  [(), (), (), (), (), (), (), (959.4838791900121,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 4091), 'Bid_touch': (45.01, 1917), 'Ask_deep': (45.04, 990), 'Bid_deep': (45.0, 15233.0)}
#
# s:  959.6128923730259
# Timestamps_this:  [(), (), (), (959.6128923730259,), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3991), 'Bid_touch': (45.01, 1917), 'Ask_deep': (45.04, 990), 'Bid_deep': (45.0, 15233.0)}
#
# s:  961.4362314641066
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (961.4362314641066,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3991), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.04, 990), 'Bid_deep': (45.0, 15233.0)}
#
# s:  961.4363340519594
# Timestamps_this:  [(), (), (), (961.4363340519594,), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3886), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.04, 990), 'Bid_deep': (45.0, 15233.0)}
#
# s:  961.4378801432516
# Timestamps_this:  [(), (), (961.4378801432516,), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3986), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.04, 990), 'Bid_deep': (45.0, 15233.0)}
#
# s:  966.646662633127
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (966.646662633127,), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3986), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.04, 990), 'Bid_deep': (45.0, 15133.0)}
#
# s:  966.6476990269708
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (966.6476990269708,)]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3986), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.04, 990), 'Bid_deep': (45.0, 15233.0)}
#
# s:  966.6477428338591
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (966.6477428338591,)]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3986), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.04, 990), 'Bid_deep': (45.0, 15333.0)}
#
# s:  966.6482362026909
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (966.6482362026909,)]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3986), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.04, 990), 'Bid_deep': (45.0, 15433.0)}
#
# s:  966.6488252218934
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (966.6488252218934,)]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3986), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.04, 990), 'Bid_deep': (45.0, 15533.0)}
#
# s:  966.6489389871067
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (966.6489389871067,)]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3986), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.04, 990), 'Bid_deep': (45.0, 15633.0)}
#
# s:  966.7111512189379
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (966.7111512189379,)]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3986), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.04, 990), 'Bid_deep': (45.0, 15799.0)}
#
# s:  972.6627671641958
# Timestamps_this:  [(972.6627671641958,), (), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3986), 'Bid_touch': (45.01, 2017), 'Ask_deep': (45.04, 1090), 'Bid_deep': (45.0, 15799.0)}
#
# s:  977.5277879392593
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (977.5277879392593,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3986), 'Bid_touch': (45.01, 2027), 'Ask_deep': (45.04, 1090), 'Bid_deep': (45.0, 15799.0)}
#
# s:  996.940687119645
# Timestamps_this:  [(), (), (), (996.940687119645,), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3886), 'Bid_touch': (45.01, 2027), 'Ask_deep': (45.04, 1090), 'Bid_deep': (45.0, 15799.0)}
#
# s:  997.6403746857591
# Timestamps_this:  [(), (), (), (997.6403746857591,), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3876), 'Bid_touch': (45.01, 2027), 'Ask_deep': (45.04, 1090), 'Bid_deep': (45.0, 15799.0)}
#
# s:  997.71456631085
# Timestamps_this:  [(), (), (), (997.71456631085,), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3776), 'Bid_touch': (45.01, 2027), 'Ask_deep': (45.04, 1090), 'Bid_deep': (45.0, 15799.0)}
#
# s:  998.1698550279325
# Timestamps_this:  [(), (), (), (), (), (), (), (998.1698550279325,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3776), 'Bid_touch': (45.01, 1827), 'Ask_deep': (45.04, 1090), 'Bid_deep': (45.0, 15799.0)}
#
# s:  998.1701140844689
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (998.1701140844689,), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3776), 'Bid_touch': (45.01, 1927), 'Ask_deep': (45.04, 1090), 'Bid_deep': (45.0, 15799.0)}
#
# s:  998.1702599564541
# Timestamps_this:  [(), (), (), (), (), (), (), (998.1702599564541,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3776), 'Bid_touch': (45.01, 1827), 'Ask_deep': (45.04, 1090), 'Bid_deep': (45.0, 15799.0)}
#
# s:  998.1718438949579
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (998.1718438949579,)]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3776), 'Bid_touch': (45.01, 1827), 'Ask_deep': (45.04, 1090), 'Bid_deep': (45.0, 15899.0)}
#
# s:  998.1720091568318
# Timestamps_this:  [(), (), (), (), (), (), (), (998.1720091568318,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3776), 'Bid_touch': (45.01, 1814), 'Ask_deep': (45.04, 1090), 'Bid_deep': (45.0, 15899.0)}
#
# s:  998.1722570725019
# Timestamps_this:  [(), (), (), (), (), (), (), (998.1722570725019,), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3776), 'Bid_touch': (45.01, 1714), 'Ask_deep': (45.04, 1090), 'Bid_deep': (45.0, 15899.0)}
#
# s:  998.1723946985875
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (998.1723946985875,)]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3776), 'Bid_touch': (45.01, 1714), 'Ask_deep': (45.04, 1090), 'Bid_deep': (45.0, 16548.0)}
#
# s:  998.1730084929311
# Timestamps_this:  [(), (), (), (), (), (), (), (), (), (), (), (998.1730084929311,)]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3776), 'Bid_touch': (45.01, 1714), 'Ask_deep': (45.04, 1090), 'Bid_deep': (45.0, 16648.0)}
#
# s:  1010.917766824321
# Timestamps_this:  [(), (1010.917766824321,), (), (), (), (), (), (), (), (), (), ()]
# Snapshot LOB0:  {'Ask_touch': (45.02, 3776), 'Bid_touch': (45.01, 1714), 'Ask_deep': (45.04, 990.0), 'Bid_deep': (45.0, 16648.0)}

# %%
# save as 12D 
paths = [i for i in os.listdir(os.getcwd()+"/simulated_data") if ("fake_simulated" in i)]
for p in paths:
    resPath = os.getcwd()+"/simulated_data//" + p
    with open(resPath, 'rb') as f:
        results = pickle.load(f)
    
    ask_t = []
    bid_t = []
    ask_d = []
    bid_d= []
    event = []
    time = []
    for r, j in zip(results[1][1:], results[0][1:]):
        ask_t.append(r['Ask_touch'][0])
        bid_t.append(r['Bid_touch'][0])
        ask_d.append(r['Ask_deep'][0])
        bid_d.append(r['Bid_deep'][0])
        event.append(j[0])
        time.append(j[1])
    df = pd.DataFrame({"Time" : time, "event" : event, "Ask Price 1" : ask_t, "Bid Price 1": bid_t, "Ask Price 2": ask_d, "Bid Price 2" : bid_d})
    df['BidDiff'] = df['Bid Price 1'].diff()
    df['AskDiff'] = df['Ask Price 1'].diff()
    df['BidDiff2']= df['Bid Price 2'].diff()
    df['AskDiff2']= df['Ask Price 2'].diff()
    id = (resPath.split("/")[-1]).split("_")[-1]
    df["Date"] = id
    df.to_csv("./simulated_data/fake_" + id +"_12D.csv")

# %%
paths

# %% [markdown]
# ## Bin to custom bins

# %%
#### WARNING: THIS PIECE OF CODE TAKES A LONG TIME ####
ric = "fake"
for d in range(10):
    l =  dataLoader.Loader(ric, d, d, dataPath = "./simulated_data/")
    df = pd.read_csv(l.dataPath+"fake_"+str(d)+"_12D.csv")
    data = {str(d) : list(df.groupby('event')['Time'].apply(np.array)[cols].values)}
    cls = fit.ConditionalLeastSquaresLogLin(data, loader = l) 
    cls.runTransformDate()

# %% [markdown]
# # Fit Fake Data

# %% [markdown]
# ## Hawkes Graph

# %%
# !git clone https://github.com/achab/nphc.git nphc2
# in line 1 of nphc2/nphc/cumulants.py, remove the autojit import and line 235 remove decorator

# %%
os.getcwd()+"/nphc2"

# %%
import sys
import os
sys.path.append(os.getcwd()+"/nphc2")
import matplotlib.pyplot as plt
from nphc.main import NPHC
import pandas as pd
import datetime as dt
import numpy as np

# %%
big_data = []
cols = ["lo_deep_Ask", "co_deep_Ask", "lo_top_Ask","co_top_Ask", "mo_Ask", "lo_inspread_Ask" ,
            "lo_inspread_Bid" , "mo_Bid", "co_top_Bid", "lo_top_Bid", "co_deep_Bid","lo_deep_Bid" ]
for d in range(10): #pd.date_range(dt.date(2019,1,2), dt.date(2019,1,4)):
    
    df = pd.read_csv("./simulated_data/fake_"+str(d)+"_12D.csv")
    
    timestamps = list(df.groupby('event')['Time'].apply(np.array)[cols].values)
    big_data.append(timestamps)

# %%
nphc = NPHC()
nphc.fit(big_data,half_width=1.,filtr="rectangular",method="parallel_by_day")
cumulants_list = [nphc.L, nphc.C, nphc.K_c]
from nphc.main import starting_point
start_point = starting_point(cumulants_list, random=True)
R_pred = nphc.solve(training_epochs=50000,display_step=500,learning_rate=1e-2,optimizer='adam')
d = len(nphc.L[0])
from scipy.linalg import inv
G_pred = np.eye(d) - inv(R_pred)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12,10)
plt.rcParams['xtick.labelsize'] = 26
plt.rcParams['ytick.labelsize'] = 26
dimensions = cols 
sns_plot = sns.heatmap(G_pred.T,cmap="RdBu_r",xticklabels=dimensions,yticklabels=dimensions)

# %%
boundsDict = {}
for i in range(12):
    for j in range(12):
        boundsDict[cols[i]+"->"+cols[j]] = np.sign(G_pred[i][j])
import pickle
with open(os.getcwd()+"/simulated_data/fake_2019-01-02_2019-03-31_graphDict", "wb") as f:
    pickle.dump(boundsDict, f)

# %% [markdown]
# ## 12D Hawkes Non-Parametric Fit:

# %%
ric = "fake"
dictIp = {}
d = 0
l =  dataLoader.Loader(ric, d, d, dataPath = "./simulated_data/")
for d in range(10):
    dictIp[str(d)] = []
cls = fit.ConditionalLeastSquaresLogLin(dictIp, loader = l, solver="osqp", path_dictTOD = "./fakeData_Params_sod_eod_dictTOD_constt")
thetas = cls.fitConditionalInSpread(spreadBeta = 1., avgSpread = 1.)
with open(l.dataPath + ric + "_Params_2019-01-02_2019-03-31_CLSLogLin_19" , "wb") as f:
    pickle.dump(thetas, f)

# %% [markdown]
# ## Infer power law params:

# %%
a, b = inference.run(dt.date(2019,1,2), dt.date(2019,3,31), ric = "fake" , avgSpread = 0.01, spreadBeta=1. , suffix = "_CLSLogLin_19")

# %% [markdown]
# # Simulate LOB from Fitted Fake Params

# %%
#### WARNING: THIS PIECE OF CODE TAKES A LONG TIME ####
for i in range(10):
    T, lob, lobL3=simulate.simulate(6.5*3600, "fake_ParamsInferredWCutoff_2019-01-02_2019-01-31_CLSLogLin_19", "fakeData_Params_sod_eod_dictTOD_constt", beta = 1., avgSpread = 0.01, spread0 = 5, price0 = 45)
    with open("./simulated_data/fake_simulated_CLSLogLinFit_sod_eod_"+ str(i) , "wb") as f:
        pickle.dump((T, lob, lobL3), f)
