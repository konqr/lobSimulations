# %%
import datetime as dt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from hawkes import dataLoader, fit

# %%
l = dataLoader.Loader("AAPL.OQ", dt.date(2019,1,7), dt.date(2019,1,7), nlevels = 2)

# %%
data = l.loadBinned(binLength = 60, filterTop = True)

# limitOrders = d.loc[d.Type == 1]
# limitOrders['count'] = 1
# bins = np.arange(limitOrders.Time.min() - 1e-3, limitOrders.Time.max(), 1)
# labels = np.arange(0, len(bins)-1, 1)
# limitOrders['second'] = pd.cut(limitOrders['Time'], bins=bins, labels=labels)
# binLimitOrders = limitOrders.groupby("second").sum()[['count','Size']]
# binLimitOrders.reset_index(inplace=True)

# %%
data['2019-01-07']['limit_bid']
# Out:
#     binIndex  count    Size
# 0          0    766  112395
# 1          1    772  103904
# 2          2    655  141402
# 3          3    619  106186
# 4          4    427   81395
# ..       ...    ...     ...
# 384      384    561  175384
# 385      385    998  215535
# 386      386    639  159378
# 387      387    529  117019
# 388      388    396   78033
#
# [389 rows x 3 columns]

# %%
dims = list(data['2019-01-07'].keys())

# %% [markdown]
# # Fit

# %% [markdown]
# ## 60 second bin size, lookback history (p) = 10 min = 10, fit window size (n) = 6.5 hr = 389

# %%
cls = fit.ConditionalLeastSquares(data, 10, 1, T = 389)
thetas = cls.fit()

# %%
thetas.keys()
# Out:
# dict_keys(['2019-01-07_0'])

# %%
# thetas shape - (d, dp+1) 
# thetas[-1] -> exo
# thetas[0, ..., d] = H^(n - 1) ...

# %%
key = '2019-01-07_0'
for i in range(thetas[key].shape[0]):
    print(dims[i])
    print("exogenous intensity : " + str(thetas[key][i][-1]))
    for j in range(thetas[key].shape[0]):
        print(dims[j] + " -> " + dims[i])
        iter = j +  thetas[key].shape[0] * np.arange((thetas[key].shape[1] - 1 )//thetas[key].shape[0])
        plt.figure()
        plt.plot(thetas[key][i][iter])
        plt.show()
# Out:
# limit_bid
# exogenous intensity : 33.152734513363754
# limit_bid -> limit_bid
# limit_ask -> limit_bid
# cancel_bid -> limit_bid
# cancel_ask -> limit_bid
# market_bid -> limit_bid
# market_ask -> limit_bid
# limit_ask
# exogenous intensity : 40.83977198276882
# limit_bid -> limit_ask
# limit_ask -> limit_ask
# cancel_bid -> limit_ask
# cancel_ask -> limit_ask
# market_bid -> limit_ask
# market_ask -> limit_ask
# cancel_bid
# exogenous intensity : 22.31367386579619
# limit_bid -> cancel_bid
# limit_ask -> cancel_bid
# cancel_bid -> cancel_bid
# cancel_ask -> cancel_bid
# market_bid -> cancel_bid
# market_ask -> cancel_bid
# cancel_ask
# exogenous intensity : 28.229246315717774
# limit_bid -> cancel_ask
# limit_ask -> cancel_ask
# cancel_bid -> cancel_ask
# cancel_ask -> cancel_ask
# market_bid -> cancel_ask
# market_ask -> cancel_ask
# market_bid
# exogenous intensity : 22.91447678885647
# limit_bid -> market_bid
# limit_ask -> market_bid
# cancel_bid -> market_bid
# cancel_ask -> market_bid
# market_bid -> market_bid
# market_ask -> market_bid
# market_ask
# exogenous intensity : 16.738667197373893
# limit_bid -> market_ask
# limit_ask -> market_ask
# cancel_bid -> market_ask
# cancel_ask -> market_ask
# market_bid -> market_ask
# market_ask -> market_ask

# %% [markdown]
# ## 1 second bin size, lookback history (p) = 10 min = 600, fit window size (n) = 6.5 hr = len(df)

# %%
data_1 = l.loadBinned(binLength = 1, filterTop = True)

# %%
cls = fit.ConditionalLeastSquares(data_1, 600, 1, T = len(data_1['2019-01-07']['limit_bid']))
thetas_1 = cls.fit()
# Out:
# D:\Work\PhD\Expt 1\lobSimulations\hawkes\dataLoader.py:69: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   theMessageBook = pd.read_csv(theMessageBookFileName,
# D:\Work\PhD\Expt 1\lobSimulations\hawkes\dataLoader.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   theOrderBookFiltered[theOrderBookFiltered.columns[i]]  = theOrderBookFiltered[theOrderBookFiltered.columns[i]]/10000
# D:\Work\PhD\Expt 1\lobSimulations\hawkes\dataLoader.py:129: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   binL = l.groupby("binIndex").sum()[['count','Size']]
# D:\Work\PhD\Expt 1\lobSimulations\hawkes\dataLoader.py:129: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   binL = l.groupby("binIndex").sum()[['count','Size']]
# D:\Work\PhD\Expt 1\lobSimulations\hawkes\dataLoader.py:129: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   binL = l.groupby("binIndex").sum()[['count','Size']]
# D:\Work\PhD\Expt 1\lobSimulations\hawkes\dataLoader.py:129: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   binL = l.groupby("binIndex").sum()[['count','Size']]
# D:\Work\PhD\Expt 1\lobSimulations\hawkes\dataLoader.py:129: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   binL = l.groupby("binIndex").sum()[['count','Size']]
# D:\Work\PhD\Expt 1\lobSimulations\hawkes\dataLoader.py:129: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   binL = l.groupby("binIndex").sum()[['count','Size']]

# %%
key = '2019-01-07_0'
for i in range(thetas_1[key].shape[0]):
    print(dims[i])
    print("exogenous intensity : " + str(thetas_1[key][i][-1]))
    for j in range(thetas_1[key].shape[0]):
        print(dims[j] + " -> " + dims[i])
        iter = j +  thetas_1[key].shape[0] * np.arange((thetas_1[key].shape[1] - 1 )//thetas_1[key].shape[0])
        plt.figure()
        plt.plot(thetas_1[key][i][iter])
        plt.show()
# Out:
# limit_bid
# exogenous intensity : -0.11650875556545592
# limit_bid -> limit_bid
# limit_ask -> limit_bid
# cancel_bid -> limit_bid
# cancel_ask -> limit_bid
# market_bid -> limit_bid
# market_ask -> limit_bid
# limit_ask
# exogenous intensity : 0.1627259977704919
# limit_bid -> limit_ask
# limit_ask -> limit_ask
# cancel_bid -> limit_ask
# cancel_ask -> limit_ask
# market_bid -> limit_ask
# market_ask -> limit_ask
# cancel_bid
# exogenous intensity : 0.019860109085081068
# limit_bid -> cancel_bid
# limit_ask -> cancel_bid
# cancel_bid -> cancel_bid
# cancel_ask -> cancel_bid
# market_bid -> cancel_bid
# market_ask -> cancel_bid
# cancel_ask
# exogenous intensity : 0.14324612062821007
# limit_bid -> cancel_ask
# limit_ask -> cancel_ask
# cancel_bid -> cancel_ask
# cancel_ask -> cancel_ask
# market_bid -> cancel_ask
# market_ask -> cancel_ask
# market_bid
# exogenous intensity : 0.054019092163643145
# limit_bid -> market_bid
# limit_ask -> market_bid
# cancel_bid -> market_bid
# cancel_ask -> market_bid
# market_bid -> market_bid
# market_ask -> market_bid
# market_ask
# exogenous intensity : 0.008873566971241809
# limit_bid -> market_ask
# limit_ask -> market_ask
# cancel_bid -> market_ask
# cancel_ask -> market_ask
# market_bid -> market_ask
# market_ask -> market_ask

# %% [markdown]
# ## 0.1 second bin size, lookback history (p) = 10 min = 6000, fit window size (n) = 6.5 hr = len(df)//2

# %%
data_01 = l.loadBinned(binLength = 0.1, filterTop = True)
# Out:
# D:\Work\PhD\Expt 1\lobSimulations\hawkes\dataLoader.py:69: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   theMessageBook = pd.read_csv(theMessageBookFileName,
# D:\Work\PhD\Expt 1\lobSimulations\hawkes\dataLoader.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   theOrderBookFiltered[theOrderBookFiltered.columns[i]]  = theOrderBookFiltered[theOrderBookFiltered.columns[i]]/10000
# D:\Work\PhD\Expt 1\lobSimulations\hawkes\dataLoader.py:129: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   binL = l.groupby("binIndex").sum()[['count','Size']]
# D:\Work\PhD\Expt 1\lobSimulations\hawkes\dataLoader.py:129: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   binL = l.groupby("binIndex").sum()[['count','Size']]
# D:\Work\PhD\Expt 1\lobSimulations\hawkes\dataLoader.py:129: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   binL = l.groupby("binIndex").sum()[['count','Size']]
# D:\Work\PhD\Expt 1\lobSimulations\hawkes\dataLoader.py:129: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   binL = l.groupby("binIndex").sum()[['count','Size']]
# D:\Work\PhD\Expt 1\lobSimulations\hawkes\dataLoader.py:129: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   binL = l.groupby("binIndex").sum()[['count','Size']]
# D:\Work\PhD\Expt 1\lobSimulations\hawkes\dataLoader.py:129: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   binL = l.groupby("binIndex").sum()[['count','Size']]

# %%
# %timeit
cls = fit.ConditionalLeastSquares(data_01, 6000, 1, T = len(data_01['2019-01-07']['limit_bid'])//16)
thetas_1 = cls.fit()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[5], line 3
#       1 get_ipython().run_line_magic('timeit', '')
#       2 cls = fit.ConditionalLeastSquares(data_01, 6000, 1, T = len(data_01['2019-01-07']['limit_bid'])//16)
# ----> 3 thetas_1 = cls.fit()
#
# File D:\Work\PhD\Expt 1\lobSimulations\hawkes\fit.py:87, in ConditionalLeastSquares.fit(self)
#      82 self.windowedData = self.getWindowedData()
#      83 # construct Z := design matrix
#      84 # Zs = self.constructDesignMatrices()
#      85 # Ys = self.constructYs()
#      86 # fit
# ---> 87 theta_cls = self.fitThetas()
#      89 return theta_cls
#
# File D:\Work\PhD\Expt 1\lobSimulations\hawkes\fit.py:68, in ConditionalLeastSquares.fitThetas(self)
#      66 Z = self.constructOneDesignMatrix(v)
#      67 Y = np.vstack(v.iloc[self.p:].values).T
# ---> 68 theta = Y.dot((Z.T).dot(np.linalg.inv(Z.dot(Z.T))))
#      70 thetas[k] = theta
#      71 i+=1
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\linalg\linalg.py:561, in inv(a)
#     559 signature = 'D->D' if isComplexType(t) else 'd->d'
#     560 extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 561 ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     562 return wrap(ainv.astype(result_t, copy=False))
#
# MemoryError: Unable to allocate 9.66 GiB for an array with shape (36001, 36001) and data type float64

# %%
key = '2019-01-07_0'
for i in range(thetas_1[key].shape[0]):
    print(dims[i])
    print("exogenous intensity : " + str(thetas_1[key][i][-1]))
    for j in range(thetas_1[key].shape[0]):
        print(dims[j] + " -> " + dims[i])
        iter = j +  thetas_1[key].shape[0] * np.arange((thetas_1[key].shape[1] - 1 )//thetas_1[key].shape[0])
        plt.figure()
        plt.plot(thetas_1[key][i][iter])
        plt.show()

# %% [markdown]
# # statsmodel instead

# %%
data_1 = l.loadBinned(binLength = 1, filterTop = True)
# Out:
# D:\Work\PhD\Expt 1\lobSimulations\hawkes\dataLoader.py:69: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   theMessageBook = pd.read_csv(theMessageBookFileName,
# D:\Work\PhD\Expt 1\lobSimulations\hawkes\dataLoader.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   theOrderBookFiltered[theOrderBookFiltered.columns[i]]  = theOrderBookFiltered[theOrderBookFiltered.columns[i]]/10000
# D:\Work\PhD\Expt 1\lobSimulations\hawkes\dataLoader.py:129: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   binL = l.groupby("binIndex").sum()[['count','Size']]
# D:\Work\PhD\Expt 1\lobSimulations\hawkes\dataLoader.py:129: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   binL = l.groupby("binIndex").sum()[['count','Size']]
# D:\Work\PhD\Expt 1\lobSimulations\hawkes\dataLoader.py:129: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   binL = l.groupby("binIndex").sum()[['count','Size']]
# D:\Work\PhD\Expt 1\lobSimulations\hawkes\dataLoader.py:129: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   binL = l.groupby("binIndex").sum()[['count','Size']]
# D:\Work\PhD\Expt 1\lobSimulations\hawkes\dataLoader.py:129: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   binL = l.groupby("binIndex").sum()[['count','Size']]
# D:\Work\PhD\Expt 1\lobSimulations\hawkes\dataLoader.py:129: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   binL = l.groupby("binIndex").sum()[['count','Size']]

# %%
l_df = []
for i in data_1['2019-01-07'].keys():
    df  = data_1['2019-01-07'][i]
    l_df += [df.rename(columns = {'count' : i})[i]]
bigDf = pd.concat(l_df, axis= 1)

# %%
bigDf
# Out:
#        limit_bid  limit_ask  cancel_bid  cancel_ask  market_bid  market_ask
# 0             64         47          27          17          49          56
# 1             63         19          25          16          51          18
# 2              1         10          11           3          46           5
# 3             12         12           3           5          20           8
# 4             14         11           3           5          41           9
# ...          ...        ...         ...         ...         ...         ...
# 23394         73         51          22          29          16          37
# 23395         27         18          17           5           5          10
# 23396         20         26          18           5           4           8
# 23397         37         44          17           9          15          11
# 23398        127         89          40          36          42         103
#
# [23399 rows x 6 columns]

# %%
from statsmodels.tsa.api import VAR

# %%
model = VAR(bigDf)
res = model.fit(10)
res.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Mon, 06, Nov, 2023
# Time:                     16:49:44
# --------------------------------------------------------------------
# No. of Equations:         6.00000    BIC:                    16.4892
# Nobs:                     23389.0    HQIC:                   16.4040
# Log likelihood:          -390117.    FPE:                1.27758e+07
# AIC:                      16.3631    Det(Omega_mle):     1.25777e+07
# --------------------------------------------------------------------
# Results for equation limit_bid
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  1.784905         0.093467           19.097           0.000
# L1.limit_bid           0.165100         0.013628           12.115           0.000
# L1.limit_ask           0.031653         0.012328            2.568           0.010
# L1.cancel_bid          0.003716         0.017930            0.207           0.836
# L1.cancel_ask         -0.080738         0.018365           -4.396           0.000
# L1.market_bid          0.014375         0.007640            1.881           0.060
# L1.market_ask          0.041100         0.017102            2.403           0.016
# L9.cancel_ask          0.024722         0.019742            1.252           0.210
# L9.market_bid         -0.003991         0.008102           -0.493           0.622
# L9.market_ask         -0.004013         0.018371           -0.218           0.827
# L10.limit_bid          0.000378         0.014695            0.026           0.979
# L10.limit_ask          0.009070         0.013296            0.682           0.495
# L10.cancel_bid         0.031089         0.019262            1.614           0.107
# L10.cancel_ask         0.030307         0.019568            1.549           0.121
# L10.market_bid         0.011894         0.008089            1.470           0.141
# L10.market_ask         0.016916         0.018203            0.929           0.353
# =================================================================================
#
# Results for equation cancel_bid
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  1.272023         0.063078           20.166           0.000
# L1.limit_bid           0.101357         0.009197           11.020           0.000
# L1.limit_ask           0.044541         0.008320            5.354           0.000
# L1.cancel_bid          0.027248         0.012100            2.252           0.024
# L1.cancel_ask         -0.064928         0.012394           -5.239           0.000
# L1.market_bid          0.006166         0.005156            1.196           0.232
# L1.market_ask          0.035255         0.011542            3.055           0.002
# L2.limit_bid           0.050387         0.009230            5.459           0.000
# L2.limit_ask           0.034663         0.008359            4.147           0.000
# L2.cancel_bid          0.020562         0.012115            1.697           0.090
# L2.cancel_ask         -0.047807         0.012434           -3.845           0.000
# L2.market_bid          0.010677         0.005161            2.069           0.039
# L2.market_ask         -0.016901         0.011576           -1.460           0.144
# L3.limit_bid           0.022125         0.009247            2.393           0.017
# L3.limit_ask           0.019810         0.008365            2.368           0.018
# L3.cancel_bid          0.014417         0.012126            1.189           0.234
# L3.cancel_ask         -0.015197         0.012451           -1.221           0.222
# L3.market_bid         -0.007482         0.005145           -1.454           0.146
# L3.market_ask         -0.005983         0.011597           -0.516           0.606
# L4.limit_bid           0.002218         0.009236            0.240           0.810
# L4.limit_ask           0.010014         0.008369            1.197           0.231
# L4.cancel_bid          0.036826         0.012128            3.037           0.002
# L4.cancel_ask          0.010869         0.012458            0.872           0.383
# L4.market_bid         -0.008100         0.005147           -1.574           0.116
# L4.market_ask         -0.011362         0.011594           -0.980           0.327
# L5.limit_bid           0.009016         0.009262            0.973           0.330
# L5.limit_ask           0.025928         0.008387            3.091           0.002
# L5.cancel_bid          0.042130         0.012208            3.451           0.001
# L5.cancel_ask         -0.018599         0.012465           -1.492           0.136
# L5.market_bid         -0.006822         0.005147           -1.326           0.185
# L5.market_ask         -0.010906         0.011595           -0.941           0.347
# L6.limit_bid          -0.005571         0.009271           -0.601           0.548
# L6.limit_ask           0.006221         0.008397            0.741           0.459
# L6.cancel_bid          0.036755         0.012215            3.009           0.003
# L6.cancel_ask          0.004863         0.012467            0.390           0.696
# L6.market_bid          0.012616         0.005141            2.454           0.014
# L6.market_ask          0.013225         0.011597            1.140           0.254
# L7.limit_bid          -0.018022         0.009281           -1.942           0.052
# L7.limit_ask          -0.015005         0.008406           -1.785           0.074
# L7.cancel_bid          0.040942         0.012221            3.350           0.001
# L7.cancel_ask          0.010959         0.012471            0.879           0.380
# L7.market_bid          0.024493         0.005120            4.784           0.000
# L7.market_ask          0.014840         0.011601            1.279           0.201
# L8.limit_bid           0.000381         0.009267            0.041           0.967
# L6.market_ask          0.008995         0.011717            0.768           0.443
# L7.limit_bid          -0.013098         0.009377           -1.397           0.162
# L7.limit_ask          -0.008596         0.008493           -1.012           0.311
# L7.cancel_bid          0.005265         0.012348            0.426           0.670
# L7.cancel_ask          0.033460         0.012600            2.656           0.008
# L7.market_bid          0.015054         0.005173            2.910           0.004
# L7.market_ask          0.009285         0.011721            0.792           0.428
# L8.limit_bid           0.012608         0.009363            1.347           0.178
# L8.limit_ask          -0.007633         0.008486           -0.900           0.368
# L8.cancel_bid          0.019122         0.012336            1.550           0.121
# L8.cancel_ask          0.021441         0.012586            1.704           0.088
# L8.market_bid          0.001639         0.005166            0.317           0.751
# L8.market_ask         -0.027378         0.011720           -2.336           0.019
# L9.limit_bid           0.024543         0.009360            2.622           0.009
# L9.limit_ask          -0.000096         0.008480           -0.011           0.991
# L9.cancel_bid         -0.024399         0.012336           -1.978           0.048
# L9.cancel_ask          0.036151         0.012575            2.875           0.004
# L9.market_bid         -0.002322         0.005161           -0.450           0.653
# L9.market_ask         -0.012211         0.011701           -1.044           0.297
# L10.limit_bid         -0.007664         0.009360           -0.819           0.413
# L10.limit_ask         -0.007665         0.008469           -0.905           0.365
# L10.cancel_bid         0.035624         0.012269            2.904           0.004
# L10.cancel_ask         0.027867         0.012464            2.236           0.025
# L10.market_bid         0.023132         0.005152            4.490           0.000
# L10.market_ask         0.013911         0.011595            1.200           0.230
# =================================================================================
#
# Results for equation market_bid
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  0.645342         0.094887            6.801           0.000
# L1.limit_bid           0.010887         0.013835            0.787           0.431
# L1.limit_ask           0.057856         0.012515            4.623           0.000
# L1.cancel_bid         -0.012580         0.018202           -0.691           0.489
# L1.cancel_ask         -0.048588         0.018644           -2.606           0.009
# L1.market_bid          0.056067         0.007756            7.229           0.000
# L1.market_ask         -0.020168         0.017362           -1.162           0.245
# L2.limit_bid           0.064445         0.013884            4.642           0.000
# L2.limit_ask           0.005366         0.012574            0.427           0.670
# L2.cancel_bid         -0.070044         0.018225           -3.843           0.000
# L2.cancel_ask         -0.005761         0.018704           -0.308           0.758
# L2.market_bid          0.061373         0.007763            7.906           0.000
# L2.market_ask         -0.026527         0.017413           -1.523           0.128
# L3.limit_bid           0.025142         0.013910            1.807           0.071
# L3.limit_ask           0.018915         0.012583            1.503           0.133
# L3.cancel_bid         -0.067457         0.018241           -3.698           0.000
# L3.cancel_ask          0.030174         0.018729            1.611           0.107
# L3.market_bid          0.036301         0.007740            4.690           0.000
# L3.market_ask          0.023328         0.017445            1.337           0.181
# L4.limit_bid          -0.094331         0.013893           -6.790           0.000
# L4.limit_ask          -0.065611         0.012589           -5.212           0.000
# L4.cancel_bid          0.234903         0.018243           12.876           0.000
# L4.cancel_ask          0.032768         0.018740            1.749           0.080
# L4.market_bid          0.013136         0.007742            1.697           0.090
# L4.market_ask          0.006232         0.017440            0.357           0.721
# L5.limit_bid           0.023692         0.013932            1.701           0.089
# L5.limit_ask           0.048450         0.012616            3.840           0.000
# L5.cancel_bid         -0.051508         0.018365           -2.805           0.005
# L5.cancel_ask         -0.030100         0.018751           -1.605           0.108
# L5.market_bid          0.001013         0.007742            0.131           0.896
# L5.market_ask         -0.007712         0.017442           -0.442           0.658
# L6.limit_bid           0.024893         0.013946            1.785           0.074
# L6.limit_ask          -0.006254         0.012631           -0.495           0.621
# L6.cancel_bid          0.019730         0.018374            1.074           0.283
# L6.cancel_ask          0.013775         0.018753            0.735           0.463
# L6.market_bid          0.014848         0.007734            1.920           0.055
# L6.market_ask         -0.024465         0.017445           -1.402           0.161
# L7.limit_bid           0.014377         0.013960            1.030           0.303
# L7.limit_ask          -0.002715         0.012644           -0.215           0.830
# L7.cancel_bid         -0.045632         0.018384           -2.482           0.013
# L7.cancel_ask          0.013071         0.018759            0.697           0.486
# L7.market_bid          0.004120         0.007701            0.535           0.593
# L7.market_ask          0.009178         0.017451            0.526           0.599
# L8.limit_bid           0.125809         0.013940            9.025           0.000
# L8.limit_ask           0.026955         0.012634            2.134           0.033
# L8.cancel_bid         -0.104871         0.018367           -5.710           0.000
# L8.cancel_ask         -0.072943         0.018739           -3.893           0.000
# L8.market_bid          0.050373         0.007692            6.549           0.000
# L8.market_ask         -0.064478         0.017449           -3.695           0.000
# L9.limit_bid           0.020245         0.013936            1.453           0.146
# L9.limit_ask          -0.000998         0.012625           -0.079           0.937
# L9.cancel_bid         -0.047587         0.018367           -2.591           0.010
# L9.cancel_ask          0.041045         0.018722            2.192           0.028
# L9.market_bid          0.023413         0.007683            3.047           0.002
# L9.market_ask         -0.005913         0.017421           -0.339           0.734
# L10.limit_bid         -0.005956         0.013936           -0.427           0.669
# L10.limit_ask         -0.029348         0.012609           -2.328           0.020
# L10.cancel_bid         0.022449         0.018267            1.229           0.219
# L10.cancel_ask         0.019492         0.018557            1.050           0.294
# L10.market_bid         0.048168         0.007671            6.279           0.000
# L10.market_ask         0.001488         0.017263            0.086           0.931
# =================================================================================
#
# Results for equation market_ask
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  0.572197         0.049646           11.526           0.000
# L1.limit_bid           0.044975         0.007239            6.213           0.000
# L1.limit_ask           0.034240         0.006548            5.229           0.000
# L1.cancel_bid         -0.049793         0.009523           -5.228           0.000
# L1.cancel_ask         -0.071275         0.009755           -7.307           0.000
# L1.market_bid          0.009188         0.004058            2.264           0.024
# L1.market_ask          0.090112         0.009084            9.920           0.000
# L2.limit_bid           0.032015         0.007264            4.407           0.000
# L2.limit_ask           0.029164         0.006579            4.433           0.000
# L2.cancel_bid         -0.035052         0.009535           -3.676           0.000
# L2.cancel_ask         -0.042767         0.009786           -4.370           0.000
# L2.market_bid          0.021025         0.004062            5.176           0.000
# L2.market_ask          0.037010         0.009111            4.062           0.000
# L3.limit_bid           0.017540         0.007278            2.410           0.016
# L3.limit_ask           0.010531         0.006584            1.600           0.110
# L3.cancel_bid         -0.014838         0.009544           -1.555           0.120
# L3.cancel_ask         -0.010285         0.009799           -1.050           0.294
# L3.market_bid          0.003551         0.004049            0.877           0.380
# L3.market_ask          0.010723         0.009127            1.175           0.240
# L4.limit_bid           0.004602         0.007269            0.633           0.527
# L4.limit_ask           0.018582         0.006587            2.821           0.005
# L4.cancel_bid         -0.003521         0.009545           -0.369           0.712
# L4.cancel_ask         -0.010108         0.009805           -1.031           0.303
# L4.market_bid         -0.005659         0.004051           -1.397           0.162
# L4.market_ask          0.025165         0.009125            2.758           0.006
# L5.limit_bid           0.015090         0.007289            2.070           0.038
# L5.limit_ask           0.031201         0.006601            4.727           0.000
# L5.cancel_bid         -0.014919         0.009609           -1.553           0.120
# L5.cancel_ask         -0.021095         0.009811           -2.150           0.032
# L5.market_bid         -0.003469         0.004051           -0.856           0.392
# L5.market_ask          0.007934         0.009126            0.869           0.385
# L6.limit_bid           0.011503         0.007296            1.577           0.115
# L6.limit_ask           0.020684         0.006609            3.130           0.002
# L6.cancel_bid         -0.012908         0.009614           -1.343           0.179
# L6.cancel_ask         -0.027501         0.009812           -2.803           0.005
# L6.market_bid          0.012873         0.004047            3.181           0.001
# L6.market_ask          0.032512         0.009128            3.562           0.000
# L7.limit_bid          -0.015116         0.007304           -2.069           0.038
# L7.limit_ask          -0.003735         0.006616           -0.565           0.572
# L7.cancel_bid          0.018398         0.009618            1.913           0.056
# L7.cancel_ask          0.008502         0.009815            0.866           0.386
# L7.market_bid          0.008694         0.004029            2.158           0.031
# L7.market_ask          0.019746         0.009131            2.163           0.031
# L8.limit_bid          -0.011017         0.007294           -1.511           0.131
# L8.limit_ask          -0.004540         0.006610           -0.687           0.492
# L8.cancel_bid          0.014203         0.009610            1.478           0.139
# L8.cancel_ask          0.017348         0.009804            1.769           0.077
# L8.market_bid          0.004574         0.004025            1.137           0.256
# L8.market_ask          0.021998         0.009129            2.410           0.016
# L9.limit_bid           0.006957         0.007292            0.954           0.340
# L9.limit_ask          -0.005578         0.006606           -0.844           0.398
# L9.cancel_bid         -0.002729         0.009610           -0.284           0.776
# L9.cancel_ask          0.019998         0.009796            2.042           0.041
# L9.market_bid          0.001782         0.004020            0.443           0.658
# L9.market_ask          0.028980         0.009115            3.179           0.001
# L10.limit_bid         -0.012259         0.007291           -1.681           0.093
# L10.limit_ask         -0.002455         0.006597           -0.372           0.710
# L10.cancel_bid         0.043092         0.009558            4.509           0.000
# L10.cancel_ask        -0.007817         0.009709           -0.805           0.421
# L10.market_bid         0.012293         0.004013            3.063           0.002
# L10.market_ask         0.022955         0.009032            2.542           0.011
# =================================================================================
#
# Correlation matrix of residuals
#               limit_bid  limit_ask  cancel_bid  cancel_ask  market_bid  market_ask
# limit_bid      1.000000   0.297293    0.773643    0.525343    0.173793    0.680734
# limit_ask      0.297293   1.000000    0.532043    0.788123    0.537548    0.242176
# cancel_bid     0.773643   0.532043    1.000000    0.571224    0.290696    0.523149
# cancel_ask     0.525343   0.788123    0.571224    1.000000    0.399037    0.341101
# market_bid     0.173793   0.537548    0.290696    0.399037    1.000000    0.148033
# market_ask     0.680734   0.242176    0.523149    0.341101    0.148033    1.000000

# %%
res.plot_acorr()

# %%
import numpy as np
a = np.array([np.array([1,2,3]),np.array([1,2,3])])

# %%
a[:,0]
# Out:
# array([1, 1])
