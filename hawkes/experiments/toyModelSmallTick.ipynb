# %%
# %matplotlib inline
import datetime as dt
import pandas as pd
from matplotlib import pyplot as plt
import os
import sys
sys.path.append("/home/konajain/code/lobSimulations")
from hawkes import simulate_smalltick # dataLoader #, fit, inference, simulate
import numpy as np
import time

# %%
T, lob , _ = simulate_smalltick.simulate_smallTick(400, "/SAN/fca/Konark_PhD_Experiments/extracted/AMZN.OQ_ParamsInferredWCutoffEyeMu_Symm_2019-01-02_2019-12-31_CLSLogLin_10","/SAN/fca/Konark_PhD_Experiments/extracted/AMZN.OQ_Params_2019-01-02_2019-12-30_dictTOD_symmetric" , beta = 0.6, avgSpread = .95, spread0 = 110, price0 = 1700, M_med = 50, verbose= True)
# Out:
# initial spread:  1.099999999999909
#
# Sizes is:  {'lo_deep_Bid': [35]}
# Snapshot LOB0:  {'mid': 1700, 'Ask_touch': (1700.55, 19), 'Bid_touch': (1699.45, 79), 'Ask_m_T': 6, 'Ask_m_D': 3, 'Bid_m_T': 3, 'Bid_m_D': 8, 'Ask_deep': (1700.61, 159), 'Bid_deep': (1699.42, 299)}
#
# Sizes is:  {'lo_deep_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700, 'Ask_touch': (1700.55, 19), 'Bid_touch': (1699.45, 79), 'Ask_m_T': 6, 'Ask_m_D': 3, 'Bid_m_T': 3, 'Bid_m_D': 8, 'Ask_deep': (1700.61, 159), 'Bid_deep': (1699.42, 399)}
#
# Sizes is:  {'lo_deep_Bid': [7]}
# Snapshot LOB0:  {'mid': 1700, 'Ask_touch': (1700.55, 19), 'Bid_touch': (1699.45, 79), 'Ask_m_T': 6, 'Ask_m_D': 3, 'Bid_m_T': 3, 'Bid_m_D': 8, 'Ask_deep': (1700.61, 159), 'Bid_deep': (1699.42, 406)}
#
# Sizes is:  {'co_top_Bid': [1]}
# Snapshot LOB0:  {'mid': 1700, 'Ask_touch': (1700.55, 19), 'Bid_touch': (1699.45, 78), 'Ask_m_T': 6, 'Ask_m_D': 3, 'Bid_m_T': 3, 'Bid_m_D': 8, 'Ask_deep': (1700.61, 159), 'Bid_deep': (1699.42, 406)}
#
# Sizes is:  {'mo_Bid': [25]}
# Snapshot LOB0:  {'mid': 1700, 'Ask_touch': (1700.55, 19), 'Bid_touch': (1699.45, 53), 'Ask_m_T': 6, 'Ask_m_D': 3, 'Bid_m_T': 3, 'Bid_m_D': 8, 'Ask_deep': (1700.61, 159), 'Bid_deep': (1699.42, 406)}
#
# Sizes is:  {'lo_top_Bid': [1]}
# Snapshot LOB0:  {'mid': 1700, 'Ask_touch': (1700.55, 19), 'Bid_touch': (1699.45, 54), 'Ask_m_T': 6, 'Ask_m_D': 3, 'Bid_m_T': 3, 'Bid_m_D': 8, 'Ask_deep': (1700.61, 159), 'Bid_deep': (1699.42, 406)}
#
# Sizes is:  {'mo_Bid': [1]}
# Snapshot LOB0:  {'mid': 1700, 'Ask_touch': (1700.55, 19), 'Bid_touch': (1699.45, 53), 'Ask_m_T': 6, 'Ask_m_D': 3, 'Bid_m_T': 3, 'Bid_m_D': 8, 'Ask_deep': (1700.61, 159), 'Bid_deep': (1699.42, 406)}
#
# Sizes is:  {'mo_Bid': [92]}
# Snapshot LOB0:  {'mid': 1699.98, 'Ask_touch': (1700.55, 19), 'Bid_touch': (1699.42, 12.0), 'Ask_m_T': 6, 'Ask_m_D': 3, 'Bid_m_T': 1, 'Bid_m_D': 7, 'Ask_deep': (1700.61, 159), 'Bid_deep': (1699.41, 355.0)}
#
# Sizes is:  {'mo_Bid': [26]}
# Snapshot LOB0:  {'mid': 1699.98, 'Ask_touch': (1700.55, 19), 'Bid_touch': (1699.41, 37.0), 'Ask_m_T': 6, 'Ask_m_D': 3, 'Bid_m_T': 1, 'Bid_m_D': 6, 'Ask_deep': (1700.61, 159), 'Bid_deep': (1699.4, 304.0)}
#
# Sizes is:  {'mo_Bid': [32]}
# Snapshot LOB0:  {'mid': 1699.98, 'Ask_touch': (1700.55, 19), 'Bid_touch': (1699.41, 5.0), 'Ask_m_T': 6, 'Ask_m_D': 3, 'Bid_m_T': 1, 'Bid_m_D': 6, 'Ask_deep': (1700.61, 159), 'Bid_deep': (1699.4, 304.0)}
#
# Sizes is:  {'lo_top_Bid': [1]}
# Snapshot LOB0:  {'mid': 1699.98, 'Ask_touch': (1700.55, 19), 'Bid_touch': (1699.41, 6.0), 'Ask_m_T': 6, 'Ask_m_D': 3, 'Bid_m_T': 1, 'Bid_m_D': 6, 'Ask_deep': (1700.61, 159), 'Bid_deep': (1699.4, 304.0)}
#
# Sizes is:  {'mo_Bid': [55]}
# Snapshot LOB0:  {'mid': 1699.98, 'Ask_touch': (1700.55, 19), 'Bid_touch': (1699.4, 2.0), 'Ask_m_T': 6, 'Ask_m_D': 3, 'Bid_m_T': 1, 'Bid_m_D': 5, 'Ask_deep': (1700.61, 159), 'Bid_deep': (1699.39, 253.0)}
#
# Sizes is:  {'co_top_Bid': [10]}
# Snapshot LOB0:  {'mid': 1699.97, 'Ask_touch': (1700.55, 19), 'Bid_touch': (1699.39, 51.0), 'Ask_m_T': 6, 'Ask_m_D': 3, 'Bid_m_T': 1, 'Bid_m_D': 4, 'Ask_deep': (1700.61, 159), 'Bid_deep': (1699.38, 202.0)}
#
# Sizes is:  {'co_deep_Bid': [81]}
# Snapshot LOB0:  {'mid': 1699.97, 'Ask_touch': (1700.55, 19), 'Bid_touch': (1699.39, 51.0), 'Ask_m_T': 6, 'Ask_m_D': 3, 'Bid_m_T': 1, 'Bid_m_D': 4, 'Ask_deep': (1700.61, 159), 'Bid_deep': (1699.38, 121.0)}
#
# Sizes is:  {'lo_top_Bid': [16]}
# Snapshot LOB0:  {'mid': 1699.97, 'Ask_touch': (1700.55, 19), 'Bid_touch': (1699.39, 67.0), 'Ask_m_T': 6, 'Ask_m_D': 3, 'Bid_m_T': 1, 'Bid_m_D': 4, 'Ask_deep': (1700.61, 159), 'Bid_deep': (1699.38, 121.0)}
#
# Sizes is:  {'lo_inspread_Bid': [30]}
# Snapshot LOB0:  {'mid': 1699.98, 'Ask_touch': (1700.55, 19), 'Bid_touch': (1699.4, 30), 'Ask_m_T': 6, 'Ask_m_D': 3, 'Bid_m_T': 1, 'Bid_m_D': -9.0, 'Ask_deep': (1700.61, 159), 'Bid_deep': (1699.39, 67.0)}
#
# Sizes is:  {'lo_top_Bid': [1]}
# Snapshot LOB0:  {'mid': 1699.98, 'Ask_touch': (1700.55, 19), 'Bid_touch': (1699.4, 31), 'Ask_m_T': 6, 'Ask_m_D': 3, 'Bid_m_T': 1, 'Bid_m_D': -9.0, 'Ask_deep': (1700.61, 159), 'Bid_deep': (1699.39, 67.0)}
#
# Sizes is:  {'co_top_Bid': [23]}
# Snapshot LOB0:  {'mid': 1699.98, 'Ask_touch': (1700.55, 19), 'Bid_touch': (1699.4, 8), 'Ask_m_T': 6, 'Ask_m_D': 3, 'Bid_m_T': 1, 'Bid_m_D': -9.0, 'Ask_deep': (1700.61, 159), 'Bid_deep': (1699.39, 67.0)}
#
# Sizes is:  {'mo_Ask': [50]}
# Snapshot LOB0:  {'mid': 1700.0, 'Ask_touch': (1700.61, 22.0), 'Bid_touch': (1699.4, 8), 'Ask_m_T': 1, 'Ask_m_D': 2, 'Bid_m_T': 1, 'Bid_m_D': -9.0, 'Ask_deep': (1700.62, 106.0), 'Bid_deep': (1699.39, 67.0)}
#
# Sizes is:  {'co_top_Bid': [15]}
# Snapshot LOB0:  {'mid': 1700.0, 'Ask_touch': (1700.61, 22.0), 'Bid_touch': (1699.39, 67.0), 'Ask_m_T': 1, 'Ask_m_D': 2, 'Bid_m_T': -9.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.62, 106.0), 'Bid_deep': (1699.48, 0.0)}
#
# Sizes is:  {'co_top_Bid': [7]}
# Snapshot LOB0:  {'mid': 1700.0, 'Ask_touch': (1700.61, 22.0), 'Bid_touch': (1699.39, 60.0), 'Ask_m_T': 1, 'Ask_m_D': 2, 'Bid_m_T': -9.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.62, 106.0), 'Bid_deep': (1699.48, 0.0)}
#
# Sizes is:  {'co_top_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.04, 'Ask_touch': (1700.61, 22.0), 'Bid_touch': (1699.48, nan), 'Ask_m_T': 1, 'Ask_m_D': 2, 'Bid_m_T': 0.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.62, 106.0), 'Bid_deep': (1699.48, nan)}
#
# Sizes is:  {'lo_inspread_Bid': [33]}
# Snapshot LOB0:  {'mid': 1700.05, 'Ask_touch': (1700.61, 22.0), 'Bid_touch': (1699.49, 33), 'Ask_m_T': 1, 'Ask_m_D': 2, 'Bid_m_T': 1, 'Bid_m_D': -7.0, 'Ask_deep': (1700.62, 106.0), 'Bid_deep': (1699.48, nan)}
#
# Sizes is:  {'lo_inspread_Bid': [4]}
# Snapshot LOB0:  {'mid': 1700.05, 'Ask_touch': (1700.61, 22.0), 'Bid_touch': (1699.5, 4), 'Ask_m_T': 1, 'Ask_m_D': 2, 'Bid_m_T': 1, 'Bid_m_D': -7.0, 'Ask_deep': (1700.62, 106.0), 'Bid_deep': (1699.49, nan)}
#
# Sizes is:  {'lo_deep_Bid': [12]}
# Snapshot LOB0:  {'mid': 1700.05, 'Ask_touch': (1700.61, 22.0), 'Bid_touch': (1699.5, 4), 'Ask_m_T': 1, 'Ask_m_D': 2, 'Bid_m_T': 1, 'Bid_m_D': -7.0, 'Ask_deep': (1700.62, 106.0), 'Bid_deep': (1699.49, nan)}
#
# Sizes is:  {'mo_Ask': [117]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.63, 11.0), 'Bid_touch': (1699.5, 4), 'Ask_m_T': 1, 'Ask_m_D': 0, 'Bid_m_T': 1, 'Bid_m_D': -7.0, 'Ask_deep': (1700.64, 0.0), 'Bid_deep': (1699.49, nan)}
#
# Sizes is:  {'co_top_Bid': [8]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.63, 11.0), 'Bid_touch': (1699.49, nan), 'Ask_m_T': 1, 'Ask_m_D': 0, 'Bid_m_T': -7.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.64, 0.0), 'Bid_deep': (1699.56, nan)}
#
# Sizes is:  {'mo_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.63, 11.0), 'Bid_touch': (1699.49, nan), 'Ask_m_T': 1, 'Ask_m_D': 0, 'Bid_m_T': -7.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.64, 0.0), 'Bid_deep': (1699.56, nan)}
#
# Sizes is:  {'lo_inspread_Bid': [50]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.63, 11.0), 'Bid_touch': (1699.5, 50), 'Ask_m_T': 1, 'Ask_m_D': 0, 'Bid_m_T': 1, 'Bid_m_D': -7.0, 'Ask_deep': (1700.64, 0.0), 'Bid_deep': (1699.49, nan)}
#
# Sizes is:  {'lo_inspread_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.63, 11.0), 'Bid_touch': (1699.51, 100), 'Ask_m_T': 1, 'Ask_m_D': 0, 'Bid_m_T': 1, 'Bid_m_D': -7.0, 'Ask_deep': (1700.64, 0.0), 'Bid_deep': (1699.5, nan)}
#
# Sizes is:  {'mo_Ask': [2]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.63, 9.0), 'Bid_touch': (1699.51, 100), 'Ask_m_T': 1, 'Ask_m_D': 0, 'Bid_m_T': 1, 'Bid_m_D': -7.0, 'Ask_deep': (1700.64, 0.0), 'Bid_deep': (1699.5, nan)}
#
# Sizes is:  {'mo_Ask': [26]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.64, nan), 'Bid_touch': (1699.51, 100), 'Ask_m_T': 0, 'Ask_m_D': 0, 'Bid_m_T': 1, 'Bid_m_D': -7.0, 'Ask_deep': (1700.64, nan), 'Bid_deep': (1699.5, nan)}
#
# Sizes is:  {'lo_deep_Bid': [31]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.64, nan), 'Bid_touch': (1699.51, 100), 'Ask_m_T': 0, 'Ask_m_D': 0, 'Bid_m_T': 1, 'Bid_m_D': -7.0, 'Ask_deep': (1700.64, nan), 'Bid_deep': (1699.5, nan)}
#
# Sizes is:  {'mo_Ask': [17]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.64, nan), 'Bid_touch': (1699.51, 100), 'Ask_m_T': 0, 'Ask_m_D': 0, 'Bid_m_T': 1, 'Bid_m_D': -7.0, 'Ask_deep': (1700.64, nan), 'Bid_deep': (1699.5, nan)}
#
# Sizes is:  {'mo_Ask': [10]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.64, nan), 'Bid_touch': (1699.51, 100), 'Ask_m_T': 0, 'Ask_m_D': 0, 'Bid_m_T': 1, 'Bid_m_D': -7.0, 'Ask_deep': (1700.64, nan), 'Bid_deep': (1699.5, nan)}
#
# Sizes is:  {'lo_inspread_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.64, nan), 'Bid_touch': (1699.52, 100), 'Ask_m_T': 0, 'Ask_m_D': 0, 'Bid_m_T': 1, 'Bid_m_D': -7.0, 'Ask_deep': (1700.64, nan), 'Bid_deep': (1699.51, nan)}
#
# Sizes is:  {'lo_inspread_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.09, 'Ask_touch': (1700.64, nan), 'Bid_touch': (1699.54, 100), 'Ask_m_T': 0, 'Ask_m_D': 0, 'Bid_m_T': 2, 'Bid_m_D': -7.0, 'Ask_deep': (1700.64, nan), 'Bid_deep': (1699.52, nan)}
#
# Sizes is:  {'lo_deep_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.09, 'Ask_touch': (1700.64, nan), 'Bid_touch': (1699.54, 100), 'Ask_m_T': 0, 'Ask_m_D': 0, 'Bid_m_T': 2, 'Bid_m_D': -7.0, 'Ask_deep': (1700.64, nan), 'Bid_deep': (1699.52, nan)}
#
# Sizes is:  {'lo_deep_Bid': [44]}
# Snapshot LOB0:  {'mid': 1700.09, 'Ask_touch': (1700.64, nan), 'Bid_touch': (1699.54, 100), 'Ask_m_T': 0, 'Ask_m_D': 0, 'Bid_m_T': 2, 'Bid_m_D': -7.0, 'Ask_deep': (1700.64, nan), 'Bid_deep': (1699.52, nan)}
#
# Sizes is:  {'lo_inspread_Bid': [11]}
# Snapshot LOB0:  {'mid': 1700.1, 'Ask_touch': (1700.64, nan), 'Bid_touch': (1699.55, 11), 'Ask_m_T': 0, 'Ask_m_D': 0, 'Bid_m_T': 1, 'Bid_m_D': -5.0, 'Ask_deep': (1700.64, nan), 'Bid_deep': (1699.54, nan)}
#
# Sizes is:  {'co_deep_Bid': [19]}
# Snapshot LOB0:  {'mid': 1700.1, 'Ask_touch': (1700.64, nan), 'Bid_touch': (1699.55, 11), 'Ask_m_T': 0, 'Ask_m_D': 0, 'Bid_m_T': 1, 'Bid_m_D': 0.0, 'Ask_deep': (1700.64, nan), 'Bid_deep': (1699.54, 0.0)}
#
# Sizes is:  {'co_top_Bid': [12]}
# Snapshot LOB0:  {'mid': 1700.09, 'Ask_touch': (1700.64, nan), 'Bid_touch': (1699.54, nan), 'Ask_m_T': 0, 'Ask_m_D': 0, 'Bid_m_T': 0.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.64, nan), 'Bid_deep': (1699.54, nan)}
#
# Sizes is:  {'co_top_Bid': [19]}
# Snapshot LOB0:  {'mid': 1700.09, 'Ask_touch': (1700.64, nan), 'Bid_touch': (1699.54, nan), 'Ask_m_T': 0, 'Ask_m_D': 0, 'Bid_m_T': 0.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.64, nan), 'Bid_deep': (1699.54, nan)}
#
# Sizes is:  {'lo_inspread_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.1, 'Ask_touch': (1700.64, nan), 'Bid_touch': (1699.55, 100), 'Ask_m_T': 0, 'Ask_m_D': 0, 'Bid_m_T': 1, 'Bid_m_D': -5.0, 'Ask_deep': (1700.64, nan), 'Bid_deep': (1699.54, nan)}
#
# Sizes is:  {'lo_inspread_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.1, 'Ask_touch': (1700.64, nan), 'Bid_touch': (1699.56, 100), 'Ask_m_T': 0, 'Ask_m_D': 0, 'Bid_m_T': 1, 'Bid_m_D': -5.0, 'Ask_deep': (1700.64, nan), 'Bid_deep': (1699.55, nan)}
#
# Sizes is:  {'lo_deep_Bid': [1]}
# Snapshot LOB0:  {'mid': 1700.1, 'Ask_touch': (1700.64, nan), 'Bid_touch': (1699.56, 100), 'Ask_m_T': 0, 'Ask_m_D': 0, 'Bid_m_T': 1, 'Bid_m_D': -5.0, 'Ask_deep': (1700.64, nan), 'Bid_deep': (1699.55, nan)}
#
# Sizes is:  {'lo_deep_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.1, 'Ask_touch': (1700.64, nan), 'Bid_touch': (1699.56, 100), 'Ask_m_T': 0, 'Ask_m_D': 0, 'Bid_m_T': 1, 'Bid_m_D': -5.0, 'Ask_deep': (1700.64, nan), 'Bid_deep': (1699.55, nan)}
#
# Sizes is:  {'mo_Ask': [1]}
# Snapshot LOB0:  {'mid': 1700.1, 'Ask_touch': (1700.64, nan), 'Bid_touch': (1699.56, 100), 'Ask_m_T': 0, 'Ask_m_D': 0, 'Bid_m_T': 1, 'Bid_m_D': -5.0, 'Ask_deep': (1700.64, nan), 'Bid_deep': (1699.55, nan)}
#
# Sizes is:  {'co_top_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.1, 'Ask_touch': (1700.64, nan), 'Bid_touch': (1699.55, nan), 'Ask_m_T': 0, 'Ask_m_D': 0, 'Bid_m_T': -5.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.64, nan), 'Bid_deep': (1699.6, nan)}
#
# Sizes is:  {'mo_Ask': [3]}
# Snapshot LOB0:  {'mid': 1700.1, 'Ask_touch': (1700.64, nan), 'Bid_touch': (1699.55, nan), 'Ask_m_T': 0, 'Ask_m_D': 0, 'Bid_m_T': -5.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.64, nan), 'Bid_deep': (1699.6, nan)}
#
# Sizes is:  {'co_top_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.1, 'Ask_touch': (1700.64, nan), 'Bid_touch': (1699.55, nan), 'Ask_m_T': 0, 'Ask_m_D': 0, 'Bid_m_T': -5.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.64, nan), 'Bid_deep': (1699.6, nan)}
#
# Sizes is:  {'lo_inspread_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.1, 'Ask_touch': (1700.64, nan), 'Bid_touch': (1699.57, 100), 'Ask_m_T': 0, 'Ask_m_D': 0, 'Bid_m_T': 2, 'Bid_m_D': -6.0, 'Ask_deep': (1700.64, nan), 'Bid_deep': (1699.55, nan)}
#
# Sizes is:  {'lo_deep_Ask': [22]}
# Snapshot LOB0:  {'mid': 1700.1, 'Ask_touch': (1700.64, nan), 'Bid_touch': (1699.57, 100), 'Ask_m_T': 0, 'Ask_m_D': 0, 'Bid_m_T': 2, 'Bid_m_D': -6.0, 'Ask_deep': (1700.64, nan), 'Bid_deep': (1699.55, nan)}
#
# Sizes is:  {'lo_inspread_Ask': [2]}
# Snapshot LOB0:  {'mid': 1700.1, 'Ask_touch': (1700.63, 2), 'Bid_touch': (1699.57, 100), 'Ask_m_T': 1, 'Ask_m_D': -4.0, 'Bid_m_T': 2, 'Bid_m_D': -6.0, 'Ask_deep': (1700.64, nan), 'Bid_deep': (1699.55, nan)}
#
# Sizes is:  {'lo_deep_Ask': [18]}
# Snapshot LOB0:  {'mid': 1700.1, 'Ask_touch': (1700.63, 2), 'Bid_touch': (1699.57, 100), 'Ask_m_T': 1, 'Ask_m_D': -4.0, 'Bid_m_T': 2, 'Bid_m_D': -6.0, 'Ask_deep': (1700.64, nan), 'Bid_deep': (1699.55, nan)}
#
# Sizes is:  {'mo_Bid': [1]}
# Snapshot LOB0:  {'mid': 1700.1, 'Ask_touch': (1700.63, 2), 'Bid_touch': (1699.57, 99), 'Ask_m_T': 1, 'Ask_m_D': -4.0, 'Bid_m_T': 2, 'Bid_m_D': -6.0, 'Ask_deep': (1700.64, nan), 'Bid_deep': (1699.55, nan)}
#
# Sizes is:  {'lo_deep_Ask': [17]}
# Snapshot LOB0:  {'mid': 1700.1, 'Ask_touch': (1700.63, 2), 'Bid_touch': (1699.57, 99), 'Ask_m_T': 1, 'Ask_m_D': -4.0, 'Bid_m_T': 2, 'Bid_m_D': -6.0, 'Ask_deep': (1700.64, nan), 'Bid_deep': (1699.55, nan)}
#
# Sizes is:  {'lo_inspread_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.1, 'Ask_touch': (1700.62, 100), 'Bid_touch': (1699.57, 99), 'Ask_m_T': 1, 'Ask_m_D': -3.0, 'Bid_m_T': 2, 'Bid_m_D': -6.0, 'Ask_deep': (1700.63, nan), 'Bid_deep': (1699.55, nan)}
#
# Sizes is:  {'lo_deep_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.1, 'Ask_touch': (1700.62, 100), 'Bid_touch': (1699.57, 99), 'Ask_m_T': 1, 'Ask_m_D': -3.0, 'Bid_m_T': 2, 'Bid_m_D': -6.0, 'Ask_deep': (1700.63, nan), 'Bid_deep': (1699.55, nan)}
#
# Sizes is:  {'lo_inspread_Ask': [143]}
# Snapshot LOB0:  {'mid': 1700.09, 'Ask_touch': (1700.61, 143), 'Bid_touch': (1699.57, 99), 'Ask_m_T': 1, 'Ask_m_D': -3.0, 'Bid_m_T': 2, 'Bid_m_D': -6.0, 'Ask_deep': (1700.62, nan), 'Bid_deep': (1699.55, nan)}
#
# Sizes is:  {'mo_Bid': [24]}
# Snapshot LOB0:  {'mid': 1700.09, 'Ask_touch': (1700.61, 143), 'Bid_touch': (1699.57, 75), 'Ask_m_T': 1, 'Ask_m_D': -3.0, 'Bid_m_T': 2, 'Bid_m_D': -6.0, 'Ask_deep': (1700.62, nan), 'Bid_deep': (1699.55, nan)}
#
# Sizes is:  {'lo_inspread_Bid': [17]}
# Snapshot LOB0:  {'mid': 1700.09, 'Ask_touch': (1700.61, 143), 'Bid_touch': (1699.58, 17), 'Ask_m_T': 1, 'Ask_m_D': -3.0, 'Bid_m_T': 1, 'Bid_m_D': -4.0, 'Ask_deep': (1700.62, nan), 'Bid_deep': (1699.57, nan)}
#
# Sizes is:  {'co_top_Bid': [5]}
# Snapshot LOB0:  {'mid': 1700.09, 'Ask_touch': (1700.61, 143), 'Bid_touch': (1699.58, 12), 'Ask_m_T': 1, 'Ask_m_D': -3.0, 'Bid_m_T': 1, 'Bid_m_D': -4.0, 'Ask_deep': (1700.62, nan), 'Bid_deep': (1699.57, nan)}
#
# Sizes is:  {'co_top_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.09, 'Ask_touch': (1700.61, 143), 'Bid_touch': (1699.57, nan), 'Ask_m_T': 1, 'Ask_m_D': -3.0, 'Bid_m_T': -4.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.62, nan), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'co_top_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.09, 'Ask_touch': (1700.61, 143), 'Bid_touch': (1699.57, nan), 'Ask_m_T': 1, 'Ask_m_D': -3.0, 'Bid_m_T': -4.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.62, nan), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'lo_inspread_Ask': [26]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.6, 26), 'Bid_touch': (1699.57, nan), 'Ask_m_T': 1, 'Ask_m_D': -3.0, 'Bid_m_T': -4.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.61, nan), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'lo_inspread_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.58, 100), 'Bid_touch': (1699.57, nan), 'Ask_m_T': 2, 'Ask_m_D': -2.0, 'Bid_m_T': -4.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.6, nan), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'lo_inspread_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.58, 100), 'Bid_touch': (1699.58, 100), 'Ask_m_T': 2, 'Ask_m_D': -2.0, 'Bid_m_T': 1, 'Bid_m_D': -4.0, 'Ask_deep': (1700.6, nan), 'Bid_deep': (1699.57, nan)}
#
# Sizes is:  {'co_top_Bid': [5]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.58, 100), 'Bid_touch': (1699.58, 95), 'Ask_m_T': 2, 'Ask_m_D': -2.0, 'Bid_m_T': 1, 'Bid_m_D': -4.0, 'Ask_deep': (1700.6, nan), 'Bid_deep': (1699.57, nan)}
#
# Sizes is:  {'lo_inspread_Bid': [1]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.58, 100), 'Bid_touch': (1699.59, 1), 'Ask_m_T': 2, 'Ask_m_D': -2.0, 'Bid_m_T': 1, 'Bid_m_D': -3.0, 'Ask_deep': (1700.6, nan), 'Bid_deep': (1699.58, nan)}
#
# Sizes is:  {'co_top_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.58, 100), 'Bid_touch': (1699.58, nan), 'Ask_m_T': 2, 'Ask_m_D': -2.0, 'Bid_m_T': -3.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.6, nan), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'lo_top_Bid': [1]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.58, 100), 'Bid_touch': (1699.58, nan), 'Ask_m_T': 2, 'Ask_m_D': -2.0, 'Bid_m_T': -4.0, 'Bid_m_D': 1.0, 'Ask_deep': (1700.6, nan), 'Bid_deep': (1699.62, nan)}
#
# Sizes is:  {'co_top_Bid': [1]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.58, 100), 'Bid_touch': (1699.58, nan), 'Ask_m_T': 2, 'Ask_m_D': -2.0, 'Bid_m_T': -4.0, 'Bid_m_D': 1.0, 'Ask_deep': (1700.6, nan), 'Bid_deep': (1699.62, nan)}
#
# Sizes is:  {'co_deep_Bid': [18]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.58, 100), 'Bid_touch': (1699.58, nan), 'Ask_m_T': 2, 'Ask_m_D': -2.0, 'Bid_m_T': -4.0, 'Bid_m_D': 1, 'Ask_deep': (1700.6, nan), 'Bid_deep': (1699.62, 100)}
#
# Sizes is:  {'lo_top_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.58, 100), 'Bid_touch': (1699.58, nan), 'Ask_m_T': 2, 'Ask_m_D': -2.0, 'Bid_m_T': -5.0, 'Bid_m_D': 2.0, 'Ask_deep': (1700.6, nan), 'Bid_deep': (1699.63, 200)}
#
# Sizes is:  {'lo_deep_Ask': [39]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.58, 100), 'Bid_touch': (1699.58, nan), 'Ask_m_T': 2, 'Ask_m_D': -2.0, 'Bid_m_T': -5.0, 'Bid_m_D': 2.0, 'Ask_deep': (1700.6, nan), 'Bid_deep': (1699.63, 200)}
#
# Sizes is:  {'mo_Bid': [12]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.58, 100), 'Bid_touch': (1699.58, nan), 'Ask_m_T': 2, 'Ask_m_D': -2.0, 'Bid_m_T': -5.0, 'Bid_m_D': 2.0, 'Ask_deep': (1700.6, nan), 'Bid_deep': (1699.63, 200)}
#
# Sizes is:  {'mo_Bid': [65]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.58, 100), 'Bid_touch': (1699.58, nan), 'Ask_m_T': 2, 'Ask_m_D': -2.0, 'Bid_m_T': -5.0, 'Bid_m_D': 2.0, 'Ask_deep': (1700.6, nan), 'Bid_deep': (1699.63, 200)}
#
# Sizes is:  {'mo_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.58, 100), 'Bid_touch': (1699.58, nan), 'Ask_m_T': 2, 'Ask_m_D': -2.0, 'Bid_m_T': -5.0, 'Bid_m_D': 2.0, 'Ask_deep': (1700.6, nan), 'Bid_deep': (1699.63, 200)}
#
# Sizes is:  {'lo_inspread_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.57, 100), 'Bid_touch': (1699.58, nan), 'Ask_m_T': 1, 'Ask_m_D': -1.0, 'Bid_m_T': -5.0, 'Bid_m_D': 2.0, 'Ask_deep': (1700.58, nan), 'Bid_deep': (1699.63, 200)}
#
# Sizes is:  {'lo_deep_Bid': [11]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.57, 100), 'Bid_touch': (1699.58, nan), 'Ask_m_T': 1, 'Ask_m_D': -1.0, 'Bid_m_T': -5.0, 'Bid_m_D': 2.0, 'Ask_deep': (1700.58, nan), 'Bid_deep': (1699.63, 211)}
#
# Sizes is:  {'co_top_Ask': [52]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.57, 48), 'Bid_touch': (1699.58, nan), 'Ask_m_T': 1, 'Ask_m_D': -1.0, 'Bid_m_T': -5.0, 'Bid_m_D': 2.0, 'Ask_deep': (1700.58, nan), 'Bid_deep': (1699.63, 211)}
#
# Sizes is:  {'co_top_Ask': [16]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.57, 32), 'Bid_touch': (1699.58, nan), 'Ask_m_T': 1, 'Ask_m_D': -1.0, 'Bid_m_T': -5.0, 'Bid_m_D': 2.0, 'Ask_deep': (1700.58, nan), 'Bid_deep': (1699.63, 211)}
#
# Sizes is:  {'lo_inspread_Ask': [9]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.56, 9), 'Bid_touch': (1699.58, nan), 'Ask_m_T': 1, 'Ask_m_D': 0.0, 'Bid_m_T': -5.0, 'Bid_m_D': 2.0, 'Ask_deep': (1700.57, nan), 'Bid_deep': (1699.63, 211)}
#
# Sizes is:  {'co_top_Ask': [4]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.56, 5), 'Bid_touch': (1699.58, nan), 'Ask_m_T': 1, 'Ask_m_D': 0.0, 'Bid_m_T': -5.0, 'Bid_m_D': 2.0, 'Ask_deep': (1700.57, nan), 'Bid_deep': (1699.63, 211)}
#
# Sizes is:  {'lo_inspread_Ask': [50]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.55, 50), 'Bid_touch': (1699.58, nan), 'Ask_m_T': 1, 'Ask_m_D': 1.0, 'Bid_m_T': -5.0, 'Bid_m_D': 2.0, 'Ask_deep': (1700.56, nan), 'Bid_deep': (1699.63, 211)}
#
# Sizes is:  {'lo_inspread_Ask': [69]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.54, 69), 'Bid_touch': (1699.58, nan), 'Ask_m_T': 1, 'Ask_m_D': 1.0, 'Bid_m_T': -5.0, 'Bid_m_D': 2.0, 'Ask_deep': (1700.55, nan), 'Bid_deep': (1699.63, 211)}
#
# Sizes is:  {'co_top_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.58, nan), 'Ask_m_T': 1.0, 'Ask_m_D': 0.0, 'Bid_m_T': -5.0, 'Bid_m_D': 2.0, 'Ask_deep': (1700.56, nan), 'Bid_deep': (1699.63, 211)}
#
# Sizes is:  {'co_top_Ask': [7]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.58, nan), 'Ask_m_T': 1.0, 'Ask_m_D': 0.0, 'Bid_m_T': -5.0, 'Bid_m_D': 2.0, 'Ask_deep': (1700.56, nan), 'Bid_deep': (1699.63, 211)}
#
# Sizes is:  {'co_top_Ask': [4]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.58, nan), 'Ask_m_T': 1.0, 'Ask_m_D': 0.0, 'Bid_m_T': -5.0, 'Bid_m_D': 2.0, 'Ask_deep': (1700.56, nan), 'Bid_deep': (1699.63, 211)}
#
# Sizes is:  {'co_top_Ask': [1]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.58, nan), 'Ask_m_T': 1.0, 'Ask_m_D': 0.0, 'Bid_m_T': -5.0, 'Bid_m_D': 2.0, 'Ask_deep': (1700.56, nan), 'Bid_deep': (1699.63, 211)}
#
# Sizes is:  {'co_top_Ask': [35]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.58, nan), 'Ask_m_T': 1.0, 'Ask_m_D': 0.0, 'Bid_m_T': -5.0, 'Bid_m_D': 2.0, 'Ask_deep': (1700.56, nan), 'Bid_deep': (1699.63, 211)}
#
# Sizes is:  {'mo_Ask': [11]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.58, nan), 'Ask_m_T': 1.0, 'Ask_m_D': 0.0, 'Bid_m_T': -5.0, 'Bid_m_D': 2.0, 'Ask_deep': (1700.56, nan), 'Bid_deep': (1699.63, 211)}
#
# Sizes is:  {'mo_Ask': [1]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.58, nan), 'Ask_m_T': 1.0, 'Ask_m_D': 0.0, 'Bid_m_T': -5.0, 'Bid_m_D': 2.0, 'Ask_deep': (1700.56, nan), 'Bid_deep': (1699.63, 211)}
#
# Sizes is:  {'mo_Ask': [44]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.58, nan), 'Ask_m_T': 1.0, 'Ask_m_D': 0.0, 'Bid_m_T': -5.0, 'Bid_m_D': 2.0, 'Ask_deep': (1700.56, nan), 'Bid_deep': (1699.63, 211)}
#
# Sizes is:  {'lo_inspread_Bid': [1]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.59, 1), 'Ask_m_T': 1.0, 'Ask_m_D': 0.0, 'Bid_m_T': 1, 'Bid_m_D': -3.0, 'Ask_deep': (1700.56, nan), 'Bid_deep': (1699.58, nan)}
#
# Sizes is:  {'mo_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.59, 1), 'Ask_m_T': 1.0, 'Ask_m_D': 0.0, 'Bid_m_T': 1, 'Bid_m_D': -3.0, 'Ask_deep': (1700.56, nan), 'Bid_deep': (1699.58, nan)}
#
# Sizes is:  {'lo_top_Ask': [15]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.59, 1), 'Ask_m_T': 1.0, 'Ask_m_D': 0.0, 'Bid_m_T': 1, 'Bid_m_D': -3.0, 'Ask_deep': (1700.56, nan), 'Bid_deep': (1699.58, nan)}
#
# Sizes is:  {'mo_Ask': [50]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.59, 1), 'Ask_m_T': 1.0, 'Ask_m_D': 0.0, 'Bid_m_T': 1, 'Bid_m_D': -3.0, 'Ask_deep': (1700.56, nan), 'Bid_deep': (1699.58, nan)}
#
# Sizes is:  {'mo_Ask': [63]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.59, 1), 'Ask_m_T': 1.0, 'Ask_m_D': 0.0, 'Bid_m_T': 1, 'Bid_m_D': -3.0, 'Ask_deep': (1700.56, nan), 'Bid_deep': (1699.58, nan)}
#
# Sizes is:  {'mo_Ask': [69]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.59, 1), 'Ask_m_T': 1.0, 'Ask_m_D': 0.0, 'Bid_m_T': 1, 'Bid_m_D': -3.0, 'Ask_deep': (1700.56, nan), 'Bid_deep': (1699.58, nan)}
#
# Sizes is:  {'lo_inspread_Bid': [85]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.6, 85), 'Ask_m_T': 1.0, 'Ask_m_D': 0.0, 'Bid_m_T': 1, 'Bid_m_D': -2.0, 'Ask_deep': (1700.56, nan), 'Bid_deep': (1699.59, nan)}
#
# Sizes is:  {'lo_inspread_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.61, 100), 'Ask_m_T': 1.0, 'Ask_m_D': 0.0, 'Bid_m_T': 1, 'Bid_m_D': -1.0, 'Ask_deep': (1700.56, nan), 'Bid_deep': (1699.6, nan)}
#
# Sizes is:  {'co_top_Bid': [19]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.61, 81), 'Ask_m_T': 1.0, 'Ask_m_D': 0.0, 'Bid_m_T': 1, 'Bid_m_D': -1.0, 'Ask_deep': (1700.56, nan), 'Bid_deep': (1699.6, nan)}
#
# Sizes is:  {'lo_deep_Bid': [5]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.61, 81), 'Ask_m_T': 1.0, 'Ask_m_D': 0.0, 'Bid_m_T': 1, 'Bid_m_D': -1.0, 'Ask_deep': (1700.56, nan), 'Bid_deep': (1699.6, nan)}
#
# Sizes is:  {'lo_deep_Bid': [2]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.61, 81), 'Ask_m_T': 1.0, 'Ask_m_D': 0.0, 'Bid_m_T': 1, 'Bid_m_D': -1.0, 'Ask_deep': (1700.56, nan), 'Bid_deep': (1699.6, nan)}
#
# Sizes is:  {'mo_Ask': [4]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.61, 81), 'Ask_m_T': 1.0, 'Ask_m_D': 0.0, 'Bid_m_T': 1, 'Bid_m_D': -1.0, 'Ask_deep': (1700.56, nan), 'Bid_deep': (1699.6, nan)}
#
# Sizes is:  {'lo_deep_Ask': [7]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.61, 81), 'Ask_m_T': 1.0, 'Ask_m_D': 0.0, 'Bid_m_T': 1, 'Bid_m_D': -1.0, 'Ask_deep': (1700.56, nan), 'Bid_deep': (1699.6, nan)}
#
# Sizes is:  {'lo_inspread_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.54, 100), 'Bid_touch': (1699.61, 81), 'Ask_m_T': 1, 'Ask_m_D': 1.0, 'Bid_m_T': 1, 'Bid_m_D': -1.0, 'Ask_deep': (1700.55, nan), 'Bid_deep': (1699.6, nan)}
#
# Sizes is:  {'lo_deep_Ask': [17]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.54, 100), 'Bid_touch': (1699.61, 81), 'Ask_m_T': 1, 'Ask_m_D': 1.0, 'Bid_m_T': 1, 'Bid_m_D': -1.0, 'Ask_deep': (1700.55, nan), 'Bid_deep': (1699.6, nan)}
#
# Sizes is:  {'lo_top_Bid': [1]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.54, 100), 'Bid_touch': (1699.61, 82), 'Ask_m_T': 1, 'Ask_m_D': 1.0, 'Bid_m_T': 1, 'Bid_m_D': -1.0, 'Ask_deep': (1700.55, nan), 'Bid_deep': (1699.6, nan)}
#
# Sizes is:  {'co_top_Bid': [24]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.54, 100), 'Bid_touch': (1699.61, 58), 'Ask_m_T': 1, 'Ask_m_D': 1.0, 'Bid_m_T': 1, 'Bid_m_D': -1.0, 'Ask_deep': (1700.55, nan), 'Bid_deep': (1699.6, nan)}
#
# Sizes is:  {'lo_top_Bid': [11]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.54, 100), 'Bid_touch': (1699.61, 69), 'Ask_m_T': 1, 'Ask_m_D': 1.0, 'Bid_m_T': 1, 'Bid_m_D': -1.0, 'Ask_deep': (1700.55, nan), 'Bid_deep': (1699.6, nan)}
#
# Sizes is:  {'mo_Bid': [43]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.54, 100), 'Bid_touch': (1699.61, 26), 'Ask_m_T': 1, 'Ask_m_D': 1.0, 'Bid_m_T': 1, 'Bid_m_D': -1.0, 'Ask_deep': (1700.55, nan), 'Bid_deep': (1699.6, nan)}
#
# Sizes is:  {'lo_inspread_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.54, 100), 'Bid_touch': (1699.62, 100), 'Ask_m_T': 1, 'Ask_m_D': 1.0, 'Bid_m_T': 1, 'Bid_m_D': 0.0, 'Ask_deep': (1700.55, nan), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'mo_Ask': [15]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.54, 85), 'Bid_touch': (1699.62, 100), 'Ask_m_T': 1, 'Ask_m_D': 1.0, 'Bid_m_T': 1, 'Bid_m_D': 0.0, 'Ask_deep': (1700.55, nan), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'lo_deep_Bid': [34]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.54, 85), 'Bid_touch': (1699.62, 100), 'Ask_m_T': 1, 'Ask_m_D': 1.0, 'Bid_m_T': 1, 'Bid_m_D': 0.0, 'Ask_deep': (1700.55, nan), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'mo_Ask': [7]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.54, 78), 'Bid_touch': (1699.62, 100), 'Ask_m_T': 1, 'Ask_m_D': 1.0, 'Bid_m_T': 1, 'Bid_m_D': 0.0, 'Ask_deep': (1700.55, nan), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'mo_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.62, 100), 'Ask_m_T': 1.0, 'Ask_m_D': 0.0, 'Bid_m_T': 1, 'Bid_m_D': 0.0, 'Ask_deep': (1700.56, nan), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'lo_deep_Bid': [19]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.62, 100), 'Ask_m_T': 1.0, 'Ask_m_D': 0.0, 'Bid_m_T': 1, 'Bid_m_D': 0.0, 'Ask_deep': (1700.56, nan), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'co_deep_Ask': [12]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.62, 100), 'Ask_m_T': 1.0, 'Ask_m_D': 1, 'Bid_m_T': 1, 'Bid_m_D': 0.0, 'Ask_deep': (1700.56, 80), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'lo_top_Bid': [11]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.62, 111), 'Ask_m_T': 1.0, 'Ask_m_D': 1, 'Bid_m_T': 1, 'Bid_m_D': 0.0, 'Ask_deep': (1700.56, 80), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'co_top_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.62, 11), 'Ask_m_T': 1.0, 'Ask_m_D': 1, 'Bid_m_T': 1, 'Bid_m_D': 0.0, 'Ask_deep': (1700.56, 80), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'lo_top_Bid': [9]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.62, 20), 'Ask_m_T': 1.0, 'Ask_m_D': 1, 'Bid_m_T': 1, 'Bid_m_D': 0.0, 'Ask_deep': (1700.56, 80), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'co_top_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.61, nan), 'Ask_m_T': 1.0, 'Ask_m_D': 1, 'Bid_m_T': 0.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.56, 80), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'lo_deep_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.61, nan), 'Ask_m_T': 1.0, 'Ask_m_D': 1, 'Bid_m_T': 0.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.56, 180), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'co_top_Bid': [3]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.61, nan), 'Ask_m_T': 1.0, 'Ask_m_D': 1, 'Bid_m_T': 0.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.56, 180), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'co_top_Bid': [1]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.61, nan), 'Ask_m_T': 1.0, 'Ask_m_D': 1, 'Bid_m_T': 0.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.56, 180), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'co_top_Bid': [8]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.61, nan), 'Ask_m_T': 1.0, 'Ask_m_D': 1, 'Bid_m_T': 0.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.56, 180), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'mo_Bid': [24]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.55, nan), 'Bid_touch': (1699.61, nan), 'Ask_m_T': 1.0, 'Ask_m_D': 1, 'Bid_m_T': 0.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.56, 180), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'lo_inspread_Ask': [9]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.54, 9), 'Bid_touch': (1699.61, nan), 'Ask_m_T': 1, 'Ask_m_D': 2.0, 'Bid_m_T': 0.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.55, nan), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'co_top_Bid': [50]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.54, 9), 'Bid_touch': (1699.61, nan), 'Ask_m_T': 1, 'Ask_m_D': 2.0, 'Bid_m_T': 0.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.55, nan), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'lo_inspread_Bid': [20]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.54, 9), 'Bid_touch': (1699.62, 20), 'Ask_m_T': 1, 'Ask_m_D': 2.0, 'Bid_m_T': 1, 'Bid_m_D': 0.0, 'Ask_deep': (1700.55, nan), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'lo_deep_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.54, 9), 'Bid_touch': (1699.62, 20), 'Ask_m_T': 1, 'Ask_m_D': 2.0, 'Bid_m_T': 1, 'Bid_m_D': 0.0, 'Ask_deep': (1700.55, nan), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'lo_inspread_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.53, 100), 'Bid_touch': (1699.62, 20), 'Ask_m_T': 1, 'Ask_m_D': 3.0, 'Bid_m_T': 1, 'Bid_m_D': 0.0, 'Ask_deep': (1700.54, nan), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'lo_deep_Ask': [21]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.53, 100), 'Bid_touch': (1699.62, 20), 'Ask_m_T': 1, 'Ask_m_D': 3.0, 'Bid_m_T': 1, 'Bid_m_D': 0.0, 'Ask_deep': (1700.54, nan), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'mo_Bid': [50]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.53, 100), 'Bid_touch': (1699.61, nan), 'Ask_m_T': 1, 'Ask_m_D': 3.0, 'Bid_m_T': 0.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.54, nan), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'mo_Bid': [31]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.53, 100), 'Bid_touch': (1699.61, nan), 'Ask_m_T': 1, 'Ask_m_D': 3.0, 'Bid_m_T': 0.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.54, nan), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'mo_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.53, 100), 'Bid_touch': (1699.61, nan), 'Ask_m_T': 1, 'Ask_m_D': 3.0, 'Bid_m_T': 0.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.54, nan), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'mo_Bid': [1]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.53, 100), 'Bid_touch': (1699.61, nan), 'Ask_m_T': 1, 'Ask_m_D': 3.0, 'Bid_m_T': 0.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.54, nan), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'lo_inspread_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.52, 100), 'Bid_touch': (1699.61, nan), 'Ask_m_T': 1, 'Ask_m_D': 3.0, 'Bid_m_T': 0.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.53, nan), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'lo_inspread_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.51, 100), 'Bid_touch': (1699.61, nan), 'Ask_m_T': 1, 'Ask_m_D': 4.0, 'Bid_m_T': 0.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.52, nan), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'lo_deep_Ask': [11]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.51, 100), 'Bid_touch': (1699.61, nan), 'Ask_m_T': 1, 'Ask_m_D': 4.0, 'Bid_m_T': 0.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.52, nan), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'lo_deep_Ask': [1]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.51, 100), 'Bid_touch': (1699.61, nan), 'Ask_m_T': 1, 'Ask_m_D': 4.0, 'Bid_m_T': 0.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.52, nan), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'co_top_Bid': [22]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.51, 100), 'Bid_touch': (1699.61, nan), 'Ask_m_T': 1, 'Ask_m_D': 4.0, 'Bid_m_T': 0.0, 'Bid_m_D': 0.0, 'Ask_deep': (1700.52, nan), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'lo_top_Bid': [42]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.51, 100), 'Bid_touch': (1699.61, nan), 'Ask_m_T': 1, 'Ask_m_D': 4.0, 'Bid_m_T': -1.0, 'Bid_m_D': 1.0, 'Ask_deep': (1700.52, nan), 'Bid_deep': (1699.62, nan)}
#
# Sizes is:  {'co_top_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.51, 100), 'Bid_touch': (1699.61, nan), 'Ask_m_T': 1, 'Ask_m_D': 4.0, 'Bid_m_T': -1.0, 'Bid_m_D': 1.0, 'Ask_deep': (1700.52, nan), 'Bid_deep': (1699.62, nan)}
#
# Sizes is:  {'lo_deep_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.51, 100), 'Bid_touch': (1699.61, nan), 'Ask_m_T': 1, 'Ask_m_D': 4.0, 'Bid_m_T': -1.0, 'Bid_m_D': 1.0, 'Ask_deep': (1700.52, nan), 'Bid_deep': (1699.62, nan)}
#
# Sizes is:  {'mo_Bid': [1]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.51, 100), 'Bid_touch': (1699.61, nan), 'Ask_m_T': 1, 'Ask_m_D': 4.0, 'Bid_m_T': -1.0, 'Bid_m_D': 1.0, 'Ask_deep': (1700.52, nan), 'Bid_deep': (1699.62, nan)}
#
# Sizes is:  {'mo_Bid': [1]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.51, 100), 'Bid_touch': (1699.61, nan), 'Ask_m_T': 1, 'Ask_m_D': 4.0, 'Bid_m_T': -1.0, 'Bid_m_D': 1.0, 'Ask_deep': (1700.52, nan), 'Bid_deep': (1699.62, nan)}
#
# Sizes is:  {'lo_top_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.51, 100), 'Bid_touch': (1699.61, nan), 'Ask_m_T': 1, 'Ask_m_D': 4.0, 'Bid_m_T': -2.0, 'Bid_m_D': 2.0, 'Ask_deep': (1700.52, nan), 'Bid_deep': (1699.63, nan)}
#
# Sizes is:  {'lo_deep_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.51, 100), 'Bid_touch': (1699.61, nan), 'Ask_m_T': 1, 'Ask_m_D': 4.0, 'Bid_m_T': -2.0, 'Bid_m_D': 2.0, 'Ask_deep': (1700.52, nan), 'Bid_deep': (1699.63, nan)}
#
# Sizes is:  {'lo_deep_Ask': [69]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.51, 100), 'Bid_touch': (1699.61, nan), 'Ask_m_T': 1, 'Ask_m_D': 4.0, 'Bid_m_T': -2.0, 'Bid_m_D': 2.0, 'Ask_deep': (1700.52, nan), 'Bid_deep': (1699.63, nan)}
#
# Sizes is:  {'co_top_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.51, 100), 'Bid_touch': (1699.61, nan), 'Ask_m_T': 1, 'Ask_m_D': 4.0, 'Bid_m_T': -2.0, 'Bid_m_D': 2.0, 'Ask_deep': (1700.52, nan), 'Bid_deep': (1699.63, nan)}
#
# Sizes is:  {'co_top_Bid': [9]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.51, 100), 'Bid_touch': (1699.61, nan), 'Ask_m_T': 1, 'Ask_m_D': 4.0, 'Bid_m_T': -2.0, 'Bid_m_D': 2.0, 'Ask_deep': (1700.52, nan), 'Bid_deep': (1699.63, nan)}
#
# Sizes is:  {'co_top_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.51, 100), 'Bid_touch': (1699.61, nan), 'Ask_m_T': 1, 'Ask_m_D': 4.0, 'Bid_m_T': -2.0, 'Bid_m_D': 2.0, 'Ask_deep': (1700.52, nan), 'Bid_deep': (1699.63, nan)}
#
# Sizes is:  {'lo_inspread_Bid': [3]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.51, 100), 'Bid_touch': (1699.62, 3), 'Ask_m_T': 1, 'Ask_m_D': 4.0, 'Bid_m_T': 1, 'Bid_m_D': 0.0, 'Ask_deep': (1700.52, nan), 'Bid_deep': (1699.61, nan)}
#
# Sizes is:  {'co_deep_Bid': [28]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.51, 100), 'Bid_touch': (1699.62, 3), 'Ask_m_T': 1, 'Ask_m_D': 4.0, 'Bid_m_T': 1, 'Bid_m_D': 1, 'Ask_deep': (1700.52, nan), 'Bid_deep': (1699.61, 249)}
#
# Sizes is:  {'lo_inspread_Ask': [50]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.5, 50), 'Bid_touch': (1699.62, 3), 'Ask_m_T': 1, 'Ask_m_D': 5.0, 'Bid_m_T': 1, 'Bid_m_D': 1, 'Ask_deep': (1700.51, nan), 'Bid_deep': (1699.61, 249)}
#
# Sizes is:  {'co_top_Ask': [19]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.5, 31), 'Bid_touch': (1699.62, 3), 'Ask_m_T': 1, 'Ask_m_D': 5.0, 'Bid_m_T': 1, 'Bid_m_D': 1, 'Ask_deep': (1700.51, nan), 'Bid_deep': (1699.61, 249)}
#
# Sizes is:  {'mo_Bid': [171]}
# Snapshot LOB0:  {'mid': 1700.05, 'Ask_touch': (1700.5, 31), 'Bid_touch': (1699.61, 81.0), 'Ask_m_T': 1, 'Ask_m_D': 5.0, 'Bid_m_T': 1, 'Bid_m_D': 2, 'Ask_deep': (1700.51, nan), 'Bid_deep': (1699.6, 24)}
#
# Sizes is:  {'mo_Bid': [19]}
# Snapshot LOB0:  {'mid': 1700.05, 'Ask_touch': (1700.5, 31), 'Bid_touch': (1699.61, 62.0), 'Ask_m_T': 1, 'Ask_m_D': 5.0, 'Bid_m_T': 1, 'Bid_m_D': 2, 'Ask_deep': (1700.51, nan), 'Bid_deep': (1699.6, 24)}
#
# Sizes is:  {'mo_Bid': [5]}
# Snapshot LOB0:  {'mid': 1700.05, 'Ask_touch': (1700.5, 31), 'Bid_touch': (1699.61, 57.0), 'Ask_m_T': 1, 'Ask_m_D': 5.0, 'Bid_m_T': 1, 'Bid_m_D': 2, 'Ask_deep': (1700.51, nan), 'Bid_deep': (1699.6, 24)}
#
# Sizes is:  {'mo_Bid': [10]}
# Snapshot LOB0:  {'mid': 1700.05, 'Ask_touch': (1700.5, 31), 'Bid_touch': (1699.61, 47.0), 'Ask_m_T': 1, 'Ask_m_D': 5.0, 'Bid_m_T': 1, 'Bid_m_D': 2, 'Ask_deep': (1700.51, nan), 'Bid_deep': (1699.6, 24)}
#
# Sizes is:  {'lo_inspread_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.05, 'Ask_touch': (1700.49, 100), 'Bid_touch': (1699.61, 47.0), 'Ask_m_T': 1, 'Ask_m_D': 5.0, 'Bid_m_T': 1, 'Bid_m_D': 2, 'Ask_deep': (1700.5, nan), 'Bid_deep': (1699.6, 24)}
#
# Sizes is:  {'mo_Bid': [10]}
# Snapshot LOB0:  {'mid': 1700.05, 'Ask_touch': (1700.49, 100), 'Bid_touch': (1699.61, 37.0), 'Ask_m_T': 1, 'Ask_m_D': 5.0, 'Bid_m_T': 1, 'Bid_m_D': 2, 'Ask_deep': (1700.5, nan), 'Bid_deep': (1699.6, 24)}
#
# Sizes is:  {'mo_Bid': [50]}
# Snapshot LOB0:  {'mid': 1700.04, 'Ask_touch': (1700.49, 100), 'Bid_touch': (1699.59, 11.0), 'Ask_m_T': 1, 'Ask_m_D': 5.0, 'Bid_m_T': 1, 'Bid_m_D': 4.0, 'Ask_deep': (1700.5, nan), 'Bid_deep': (1699.58, 1012.0)}
#
# Sizes is:  {'mo_Bid': [4]}
# Snapshot LOB0:  {'mid': 1700.04, 'Ask_touch': (1700.49, 100), 'Bid_touch': (1699.59, 7.0), 'Ask_m_T': 1, 'Ask_m_D': 5.0, 'Bid_m_T': 1, 'Bid_m_D': 4.0, 'Ask_deep': (1700.5, nan), 'Bid_deep': (1699.58, 1012.0)}
#
# Sizes is:  {'mo_Bid': [1]}
# Snapshot LOB0:  {'mid': 1700.04, 'Ask_touch': (1700.49, 100), 'Bid_touch': (1699.59, 6.0), 'Ask_m_T': 1, 'Ask_m_D': 5.0, 'Bid_m_T': 1, 'Bid_m_D': 4.0, 'Ask_deep': (1700.5, nan), 'Bid_deep': (1699.58, 1012.0)}
#
# Sizes is:  {'mo_Bid': [11]}
# Snapshot LOB0:  {'mid': 1700.04, 'Ask_touch': (1700.49, 100), 'Bid_touch': (1699.58, 248.0), 'Ask_m_T': 1, 'Ask_m_D': 5.0, 'Bid_m_T': 1, 'Bid_m_D': 3.0, 'Ask_deep': (1700.5, nan), 'Bid_deep': (1699.57, 759.0)}
#
# Sizes is:  {'lo_deep_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.04, 'Ask_touch': (1700.49, 100), 'Bid_touch': (1699.58, 248.0), 'Ask_m_T': 1, 'Ask_m_D': 5.0, 'Bid_m_T': 1, 'Bid_m_D': 3.0, 'Ask_deep': (1700.5, nan), 'Bid_deep': (1699.57, 759.0)}
#
# Sizes is:  {'co_deep_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.04, 'Ask_touch': (1700.49, 100), 'Bid_touch': (1699.58, 248.0), 'Ask_m_T': 1, 'Ask_m_D': 5.0, 'Bid_m_T': 1, 'Bid_m_D': 3.0, 'Ask_deep': (1700.5, nan), 'Bid_deep': (1699.57, 659.0)}
#
# Sizes is:  {'lo_inspread_Ask': [21]}
# Snapshot LOB0:  {'mid': 1700.03, 'Ask_touch': (1700.48, 21), 'Bid_touch': (1699.58, 248.0), 'Ask_m_T': 1, 'Ask_m_D': 4.0, 'Bid_m_T': 1, 'Bid_m_D': 3.0, 'Ask_deep': (1700.49, nan), 'Bid_deep': (1699.57, 659.0)}
#
# Sizes is:  {'lo_inspread_Ask': [10]}
# Snapshot LOB0:  {'mid': 1700.02, 'Ask_touch': (1700.46, 10), 'Bid_touch': (1699.58, 248.0), 'Ask_m_T': 2, 'Ask_m_D': 4.0, 'Bid_m_T': 1, 'Bid_m_D': 3.0, 'Ask_deep': (1700.48, nan), 'Bid_deep': (1699.57, 659.0)}
#
# Sizes is:  {'co_deep_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.02, 'Ask_touch': (1700.46, 10), 'Bid_touch': (1699.58, 248.0), 'Ask_m_T': 2, 'Ask_m_D': 0.0, 'Bid_m_T': 1, 'Bid_m_D': 3.0, 'Ask_deep': (1700.48, 0.0), 'Bid_deep': (1699.57, 659.0)}
#
# Sizes is:  {'co_deep_Ask': [1]}
# Snapshot LOB0:  {'mid': 1700.02, 'Ask_touch': (1700.46, 10), 'Bid_touch': (1699.58, 248.0), 'Ask_m_T': 2, 'Ask_m_D': 4.0, 'Bid_m_T': 1, 'Bid_m_D': 3.0, 'Ask_deep': (1700.48, 4.0), 'Bid_deep': (1699.57, 659.0)}
#
# Sizes is:  {'mo_Bid': [17]}
# Snapshot LOB0:  {'mid': 1700.02, 'Ask_touch': (1700.46, 10), 'Bid_touch': (1699.58, 231.0), 'Ask_m_T': 2, 'Ask_m_D': 4.0, 'Bid_m_T': 1, 'Bid_m_D': 3.0, 'Ask_deep': (1700.48, 4.0), 'Bid_deep': (1699.57, 659.0)}
#
# Sizes is:  {'mo_Bid': [1]}
# Snapshot LOB0:  {'mid': 1700.02, 'Ask_touch': (1700.46, 10), 'Bid_touch': (1699.58, 230.0), 'Ask_m_T': 2, 'Ask_m_D': 4.0, 'Bid_m_T': 1, 'Bid_m_D': 3.0, 'Ask_deep': (1700.48, 4.0), 'Bid_deep': (1699.57, 659.0)}
#
# Sizes is:  {'lo_deep_Bid': [36]}
# Snapshot LOB0:  {'mid': 1700.02, 'Ask_touch': (1700.46, 10), 'Bid_touch': (1699.58, 230.0), 'Ask_m_T': 2, 'Ask_m_D': 4.0, 'Bid_m_T': 1, 'Bid_m_D': 3.0, 'Ask_deep': (1700.48, 4.0), 'Bid_deep': (1699.57, 695.0)}
#
# Sizes is:  {'lo_deep_Bid': [15]}
# Snapshot LOB0:  {'mid': 1700.02, 'Ask_touch': (1700.46, 10), 'Bid_touch': (1699.58, 230.0), 'Ask_m_T': 2, 'Ask_m_D': 4.0, 'Bid_m_T': 1, 'Bid_m_D': 3.0, 'Ask_deep': (1700.48, 4.0), 'Bid_deep': (1699.57, 710.0)}
#
# Sizes is:  {'mo_Ask': [3]}
# Snapshot LOB0:  {'mid': 1700.02, 'Ask_touch': (1700.46, 7), 'Bid_touch': (1699.58, 230.0), 'Ask_m_T': 2, 'Ask_m_D': 4.0, 'Bid_m_T': 1, 'Bid_m_D': 3.0, 'Ask_deep': (1700.48, 4.0), 'Bid_deep': (1699.57, 710.0)}
#
# Sizes is:  {'mo_Ask': [24]}
# Snapshot LOB0:  {'mid': 1700.05, 'Ask_touch': (1700.53, 11.0), 'Bid_touch': (1699.58, 230.0), 'Ask_m_T': 1, 'Ask_m_D': 1.0, 'Bid_m_T': 1, 'Bid_m_D': 3.0, 'Ask_deep': (1700.54, 12.0), 'Bid_deep': (1699.57, 710.0)}
#
# Sizes is:  {'lo_inspread_Bid': [11]}
# Snapshot LOB0:  {'mid': 1700.06, 'Ask_touch': (1700.53, 11.0), 'Bid_touch': (1699.59, 11), 'Ask_m_T': 1, 'Ask_m_D': 1.0, 'Bid_m_T': 1, 'Bid_m_D': 2.0, 'Ask_deep': (1700.54, 12.0), 'Bid_deep': (1699.58, 467.0)}
#
# Sizes is:  {'lo_inspread_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.53, 11.0), 'Bid_touch': (1699.61, 100), 'Ask_m_T': 1, 'Ask_m_D': 1.0, 'Bid_m_T': 2, 'Bid_m_D': 2.0, 'Ask_deep': (1700.54, 12.0), 'Bid_deep': (1699.59, 244.0)}
#
# Sizes is:  {'lo_inspread_Bid': [50]}
# Snapshot LOB0:  {'mid': 1700.07, 'Ask_touch': (1700.53, 11.0), 'Bid_touch': (1699.62, 50), 'Ask_m_T': 1, 'Ask_m_D': 1.0, 'Bid_m_T': 1, 'Bid_m_D': 3.0, 'Ask_deep': (1700.54, 12.0), 'Bid_deep': (1699.61, 222.0)}
#
# Sizes is:  {'mo_Ask': [18]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.54, 5.0), 'Bid_touch': (1699.62, 50), 'Ask_m_T': 1.0, 'Ask_m_D': 3.0, 'Bid_m_T': 1, 'Bid_m_D': 3.0, 'Ask_deep': (1700.55, 96.0), 'Bid_deep': (1699.61, 222.0)}
#
# Sizes is:  {'lo_inspread_Bid': [10]}
# Snapshot LOB0:  {'mid': 1700.08, 'Ask_touch': (1700.54, 5.0), 'Bid_touch': (1699.63, 10), 'Ask_m_T': 1.0, 'Ask_m_D': 3.0, 'Bid_m_T': 1, 'Bid_m_D': 3.0, 'Ask_deep': (1700.55, 96.0), 'Bid_deep': (1699.62, 198.0)}
#
# Sizes is:  {'mo_Ask': [48]}
# Snapshot LOB0:  {'mid': 1700.1, 'Ask_touch': (1700.56, 21.0), 'Bid_touch': (1699.63, 10), 'Ask_m_T': 1, 'Ask_m_D': 1.0, 'Bid_m_T': 1, 'Bid_m_D': 3.0, 'Ask_deep': (1700.57, 32.0), 'Bid_deep': (1699.62, 198.0)}
#
# Sizes is:  {'co_top_Bid': [7]}
# Snapshot LOB0:  {'mid': 1700.1, 'Ask_touch': (1700.56, 21.0), 'Bid_touch': (1699.63, 3), 'Ask_m_T': 1, 'Ask_m_D': 1.0, 'Bid_m_T': 1, 'Bid_m_D': 3.0, 'Ask_deep': (1700.57, 32.0), 'Bid_deep': (1699.62, 198.0)}
#
# Sizes is:  {'co_top_Bid': [19]}
# Snapshot LOB0:  {'mid': 1700.09, 'Ask_touch': (1700.56, 21.0), 'Bid_touch': (1699.62, 66.0), 'Ask_m_T': 1, 'Ask_m_D': 1.0, 'Bid_m_T': 1, 'Bid_m_D': 2.0, 'Ask_deep': (1700.57, 32.0), 'Bid_deep': (1699.61, 132.0)}
#
# Sizes is:  {'mo_Ask': [10]}
# Snapshot LOB0:  {'mid': 1700.09, 'Ask_touch': (1700.56, 11.0), 'Bid_touch': (1699.62, 66.0), 'Ask_m_T': 1, 'Ask_m_D': 1.0, 'Bid_m_T': 1, 'Bid_m_D': 2.0, 'Ask_deep': (1700.57, 32.0), 'Bid_deep': (1699.61, 132.0)}
#
# Sizes is:  {'lo_deep_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.09, 'Ask_touch': (1700.56, 11.0), 'Bid_touch': (1699.62, 66.0), 'Ask_m_T': 1, 'Ask_m_D': 1.0, 'Bid_m_T': 1, 'Bid_m_D': 2.0, 'Ask_deep': (1700.57, 32.0), 'Bid_deep': (1699.61, 232.0)}
#
# Sizes is:  {'lo_deep_Bid': [70]}
# Snapshot LOB0:  {'mid': 1700.09, 'Ask_touch': (1700.56, 11.0), 'Bid_touch': (1699.62, 66.0), 'Ask_m_T': 1, 'Ask_m_D': 1.0, 'Bid_m_T': 1, 'Bid_m_D': 2.0, 'Ask_deep': (1700.57, 32.0), 'Bid_deep': (1699.61, 302.0)}
#
# Sizes is:  {'lo_deep_Bid': [1]}
# Snapshot LOB0:  {'mid': 1700.09, 'Ask_touch': (1700.56, 11.0), 'Bid_touch': (1699.62, 66.0), 'Ask_m_T': 1, 'Ask_m_D': 1.0, 'Bid_m_T': 1, 'Bid_m_D': 2.0, 'Ask_deep': (1700.57, 32.0), 'Bid_deep': (1699.61, 303.0)}
#
# Sizes is:  {'lo_deep_Ask': [30]}
# Snapshot LOB0:  {'mid': 1700.09, 'Ask_touch': (1700.56, 11.0), 'Bid_touch': (1699.62, 66.0), 'Ask_m_T': 1, 'Ask_m_D': 1.0, 'Bid_m_T': 1, 'Bid_m_D': 2.0, 'Ask_deep': (1700.57, 62.0), 'Bid_deep': (1699.61, 303.0)}
#
# Sizes is:  {'lo_deep_Ask': [2]}
# Snapshot LOB0:  {'mid': 1700.09, 'Ask_touch': (1700.56, 11.0), 'Bid_touch': (1699.62, 66.0), 'Ask_m_T': 1, 'Ask_m_D': 1.0, 'Bid_m_T': 1, 'Bid_m_D': 2.0, 'Ask_deep': (1700.57, 64.0), 'Bid_deep': (1699.61, 303.0)}
#
# Sizes is:  {'co_top_Ask': [26]}
# Snapshot LOB0:  {'mid': 1700.09, 'Ask_touch': (1700.57, 64.0), 'Bid_touch': (1699.62, 66.0), 'Ask_m_T': 1.0, 'Ask_m_D': 1.0, 'Bid_m_T': 1, 'Bid_m_D': 2.0, 'Ask_deep': (1700.58, 154.0), 'Bid_deep': (1699.61, 303.0)}
#
# Sizes is:  {'co_deep_Bid': [45]}
# Snapshot LOB0:  {'mid': 1700.09, 'Ask_touch': (1700.57, 64.0), 'Bid_touch': (1699.62, 66.0), 'Ask_m_T': 1.0, 'Ask_m_D': 1.0, 'Bid_m_T': 1, 'Bid_m_D': 2.0, 'Ask_deep': (1700.58, 154.0), 'Bid_deep': (1699.61, 258.0)}
#
# Sizes is:  {'lo_deep_Bid': [73]}
# ...
#
# Sizes is:  {'co_deep_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.54, 'Ask_touch': (1700.77, 14.0), 'Bid_touch': (1700.32, 22.0), 'Ask_m_T': 1, 'Ask_m_D': 19, 'Bid_m_T': 1, 'Bid_m_D': 14.0, 'Ask_deep': (1700.78, 2978.0), 'Bid_deep': (1700.31, 1760.0)}
#
# Sizes is:  {'co_deep_Bid': [7]}
# Snapshot LOB0:  {'mid': 1700.54, 'Ask_touch': (1700.77, 14.0), 'Bid_touch': (1700.32, 22.0), 'Ask_m_T': 1, 'Ask_m_D': 19, 'Bid_m_T': 1, 'Bid_m_D': 14.0, 'Ask_deep': (1700.78, 2978.0), 'Bid_deep': (1700.31, 1753.0)}
#
# Sizes is:  {'lo_deep_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.54, 'Ask_touch': (1700.77, 14.0), 'Bid_touch': (1700.32, 22.0), 'Ask_m_T': 1, 'Ask_m_D': 19, 'Bid_m_T': 1, 'Bid_m_D': 14.0, 'Ask_deep': (1700.78, 3078.0), 'Bid_deep': (1700.31, 1753.0)}
#
# Sizes is:  {'lo_deep_Ask': [11]}
# Snapshot LOB0:  {'mid': 1700.54, 'Ask_touch': (1700.77, 14.0), 'Bid_touch': (1700.32, 22.0), 'Ask_m_T': 1, 'Ask_m_D': 19, 'Bid_m_T': 1, 'Bid_m_D': 14.0, 'Ask_deep': (1700.78, 3089.0), 'Bid_deep': (1700.31, 1753.0)}
#
# Sizes is:  {'lo_deep_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.54, 'Ask_touch': (1700.77, 14.0), 'Bid_touch': (1700.32, 22.0), 'Ask_m_T': 1, 'Ask_m_D': 19, 'Bid_m_T': 1, 'Bid_m_D': 14.0, 'Ask_deep': (1700.78, 3189.0), 'Bid_deep': (1700.31, 1753.0)}
#
# Sizes is:  {'lo_deep_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.54, 'Ask_touch': (1700.77, 14.0), 'Bid_touch': (1700.32, 22.0), 'Ask_m_T': 1, 'Ask_m_D': 19, 'Bid_m_T': 1, 'Bid_m_D': 14.0, 'Ask_deep': (1700.78, 3289.0), 'Bid_deep': (1700.31, 1753.0)}
#
# Sizes is:  {'lo_deep_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.54, 'Ask_touch': (1700.77, 14.0), 'Bid_touch': (1700.32, 22.0), 'Ask_m_T': 1, 'Ask_m_D': 19, 'Bid_m_T': 1, 'Bid_m_D': 14.0, 'Ask_deep': (1700.78, 3389.0), 'Bid_deep': (1700.31, 1753.0)}
#
# Sizes is:  {'lo_deep_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.54, 'Ask_touch': (1700.77, 14.0), 'Bid_touch': (1700.32, 22.0), 'Ask_m_T': 1, 'Ask_m_D': 19, 'Bid_m_T': 1, 'Bid_m_D': 14.0, 'Ask_deep': (1700.78, 3489.0), 'Bid_deep': (1700.31, 1753.0)}
#
# Sizes is:  {'co_top_Ask': [2]}
# Snapshot LOB0:  {'mid': 1700.54, 'Ask_touch': (1700.77, 12.0), 'Bid_touch': (1700.32, 22.0), 'Ask_m_T': 1, 'Ask_m_D': 19, 'Bid_m_T': 1, 'Bid_m_D': 14.0, 'Ask_deep': (1700.78, 3489.0), 'Bid_deep': (1700.31, 1753.0)}
#
# Sizes is:  {'co_top_Ask': [61]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 184.0), 'Bid_touch': (1700.32, 22.0), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 14.0, 'Ask_deep': (1700.79, 3305.0), 'Bid_deep': (1700.31, 1753.0)}
#
# Sizes is:  {'lo_inspread_Ask': [46]}
# Snapshot LOB0:  {'mid': 1700.54, 'Ask_touch': (1700.77, 46), 'Bid_touch': (1700.32, 22.0), 'Ask_m_T': 1, 'Ask_m_D': 19, 'Bid_m_T': 1, 'Bid_m_D': 14.0, 'Ask_deep': (1700.78, 3489.0), 'Bid_deep': (1700.31, 1753.0)}
#
# Sizes is:  {'lo_top_Ask': [5]}
# Snapshot LOB0:  {'mid': 1700.54, 'Ask_touch': (1700.77, 51), 'Bid_touch': (1700.32, 22.0), 'Ask_m_T': 1, 'Ask_m_D': 19, 'Bid_m_T': 1, 'Bid_m_D': 14.0, 'Ask_deep': (1700.78, 3489.0), 'Bid_deep': (1700.31, 1753.0)}
#
# Sizes is:  {'co_top_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 184.0), 'Bid_touch': (1700.32, 22.0), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 14.0, 'Ask_deep': (1700.79, 3305.0), 'Bid_deep': (1700.31, 1753.0)}
#
# Sizes is:  {'co_top_Ask': [10]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 174.0), 'Bid_touch': (1700.32, 22.0), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 14.0, 'Ask_deep': (1700.79, 3305.0), 'Bid_deep': (1700.31, 1753.0)}
#
# Sizes is:  {'lo_top_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 274.0), 'Bid_touch': (1700.32, 22.0), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 14.0, 'Ask_deep': (1700.79, 3305.0), 'Bid_deep': (1700.31, 1753.0)}
#
# Sizes is:  {'co_top_Ask': [15]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 259.0), 'Bid_touch': (1700.32, 22.0), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 14.0, 'Ask_deep': (1700.79, 3305.0), 'Bid_deep': (1700.31, 1753.0)}
#
# Sizes is:  {'lo_top_Ask': [1]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 260.0), 'Bid_touch': (1700.32, 22.0), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 14.0, 'Ask_deep': (1700.79, 3305.0), 'Bid_deep': (1700.31, 1753.0)}
#
# Sizes is:  {'lo_top_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 360.0), 'Bid_touch': (1700.32, 22.0), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 14.0, 'Ask_deep': (1700.79, 3305.0), 'Bid_deep': (1700.31, 1753.0)}
#
# Sizes is:  {'lo_top_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 460.0), 'Bid_touch': (1700.32, 22.0), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 14.0, 'Ask_deep': (1700.79, 3305.0), 'Bid_deep': (1700.31, 1753.0)}
#
# Sizes is:  {'lo_top_Ask': [19]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 479.0), 'Bid_touch': (1700.32, 22.0), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 14.0, 'Ask_deep': (1700.79, 3305.0), 'Bid_deep': (1700.31, 1753.0)}
#
# Sizes is:  {'lo_top_Ask': [35]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 514.0), 'Bid_touch': (1700.32, 22.0), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 14.0, 'Ask_deep': (1700.79, 3305.0), 'Bid_deep': (1700.31, 1753.0)}
#
# Sizes is:  {'mo_Ask': [7]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 507.0), 'Bid_touch': (1700.32, 22.0), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 14.0, 'Ask_deep': (1700.79, 3305.0), 'Bid_deep': (1700.31, 1753.0)}
#
# Sizes is:  {'lo_top_Ask': [10]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 517.0), 'Bid_touch': (1700.32, 22.0), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 14.0, 'Ask_deep': (1700.79, 3305.0), 'Bid_deep': (1700.31, 1753.0)}
#
# Sizes is:  {'co_deep_Ask': [14]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 517.0), 'Bid_touch': (1700.32, 22.0), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 14.0, 'Ask_deep': (1700.79, 3291.0), 'Bid_deep': (1700.31, 1753.0)}
#
# Sizes is:  {'lo_top_Ask': [12]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 529.0), 'Bid_touch': (1700.32, 22.0), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 14.0, 'Ask_deep': (1700.79, 3291.0), 'Bid_deep': (1700.31, 1753.0)}
#
# Sizes is:  {'mo_Ask': [24]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 505.0), 'Bid_touch': (1700.32, 22.0), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 14.0, 'Ask_deep': (1700.79, 3291.0), 'Bid_deep': (1700.31, 1753.0)}
#
# Sizes is:  {'mo_Ask': [1]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 504.0), 'Bid_touch': (1700.32, 22.0), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 14.0, 'Ask_deep': (1700.79, 3291.0), 'Bid_deep': (1700.31, 1753.0)}
#
# Sizes is:  {'lo_deep_Bid': [44]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 504.0), 'Bid_touch': (1700.32, 22.0), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 14.0, 'Ask_deep': (1700.79, 3291.0), 'Bid_deep': (1700.31, 1797.0)}
#
# Sizes is:  {'mo_Ask': [55]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 449.0), 'Bid_touch': (1700.32, 22.0), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 14.0, 'Ask_deep': (1700.79, 3291.0), 'Bid_deep': (1700.31, 1797.0)}
#
# Sizes is:  {'lo_inspread_Bid': [50]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 449.0), 'Bid_touch': (1700.33, 50), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 15.0, 'Ask_deep': (1700.79, 3291.0), 'Bid_deep': (1700.32, 1819.0)}
#
# Sizes is:  {'co_deep_Ask': [3]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 449.0), 'Bid_touch': (1700.33, 50), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 15.0, 'Ask_deep': (1700.79, 3288.0), 'Bid_deep': (1700.32, 1819.0)}
#
# Sizes is:  {'co_deep_Ask': [21]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 449.0), 'Bid_touch': (1700.33, 50), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 15.0, 'Ask_deep': (1700.79, 3267.0), 'Bid_deep': (1700.32, 1819.0)}
#
# Sizes is:  {'mo_Ask': [63]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 386.0), 'Bid_touch': (1700.33, 50), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 15.0, 'Ask_deep': (1700.79, 3267.0), 'Bid_deep': (1700.32, 1819.0)}
#
# Sizes is:  {'mo_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 286.0), 'Bid_touch': (1700.33, 50), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 15.0, 'Ask_deep': (1700.79, 3267.0), 'Bid_deep': (1700.32, 1819.0)}
#
# Sizes is:  {'mo_Ask': [1]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 285.0), 'Bid_touch': (1700.33, 50), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 15.0, 'Ask_deep': (1700.79, 3267.0), 'Bid_deep': (1700.32, 1819.0)}
#
# Sizes is:  {'mo_Ask': [12]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 273.0), 'Bid_touch': (1700.33, 50), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 15.0, 'Ask_deep': (1700.79, 3267.0), 'Bid_deep': (1700.32, 1819.0)}
#
# Sizes is:  {'co_deep_Ask': [22]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 273.0), 'Bid_touch': (1700.33, 50), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 15.0, 'Ask_deep': (1700.79, 3245.0), 'Bid_deep': (1700.32, 1819.0)}
#
# Sizes is:  {'mo_Ask': [11]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 262.0), 'Bid_touch': (1700.33, 50), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 15.0, 'Ask_deep': (1700.79, 3245.0), 'Bid_deep': (1700.32, 1819.0)}
#
# Sizes is:  {'co_deep_Ask': [19]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 262.0), 'Bid_touch': (1700.33, 50), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 15.0, 'Ask_deep': (1700.79, 3226.0), 'Bid_deep': (1700.32, 1819.0)}
#
# Sizes is:  {'mo_Ask': [5]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 257.0), 'Bid_touch': (1700.33, 50), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 15.0, 'Ask_deep': (1700.79, 3226.0), 'Bid_deep': (1700.32, 1819.0)}
#
# Sizes is:  {'mo_Ask': [1]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 256.0), 'Bid_touch': (1700.33, 50), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 15.0, 'Ask_deep': (1700.79, 3226.0), 'Bid_deep': (1700.32, 1819.0)}
#
# Sizes is:  {'mo_Ask': [9]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 247.0), 'Bid_touch': (1700.33, 50), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 15.0, 'Ask_deep': (1700.79, 3226.0), 'Bid_deep': (1700.32, 1819.0)}
#
# Sizes is:  {'mo_Ask': [4]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 243.0), 'Bid_touch': (1700.33, 50), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 15.0, 'Ask_deep': (1700.79, 3226.0), 'Bid_deep': (1700.32, 1819.0)}
#
# Sizes is:  {'mo_Ask': [13]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 230.0), 'Bid_touch': (1700.33, 50), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 15.0, 'Ask_deep': (1700.79, 3226.0), 'Bid_deep': (1700.32, 1819.0)}
#
# Sizes is:  {'mo_Ask': [18]}
# Snapshot LOB0:  {'mid': 1700.55, 'Ask_touch': (1700.78, 212.0), 'Bid_touch': (1700.33, 50), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 15.0, 'Ask_deep': (1700.79, 3226.0), 'Bid_deep': (1700.32, 1819.0)}
#
# Sizes is:  {'lo_inspread_Bid': [10]}
# Snapshot LOB0:  {'mid': 1700.56, 'Ask_touch': (1700.78, 212.0), 'Bid_touch': (1700.34, 10), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 16.0, 'Ask_deep': (1700.79, 3226.0), 'Bid_deep': (1700.33, 1869.0)}
#
# Sizes is:  {'mo_Ask': [5]}
# Snapshot LOB0:  {'mid': 1700.56, 'Ask_touch': (1700.78, 207.0), 'Bid_touch': (1700.34, 10), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 16.0, 'Ask_deep': (1700.79, 3226.0), 'Bid_deep': (1700.33, 1869.0)}
#
# Sizes is:  {'mo_Ask': [1]}
# Snapshot LOB0:  {'mid': 1700.56, 'Ask_touch': (1700.78, 206.0), 'Bid_touch': (1700.34, 10), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 16.0, 'Ask_deep': (1700.79, 3226.0), 'Bid_deep': (1700.33, 1869.0)}
#
# Sizes is:  {'mo_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.56, 'Ask_touch': (1700.78, 106.0), 'Bid_touch': (1700.34, 10), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 16.0, 'Ask_deep': (1700.79, 3226.0), 'Bid_deep': (1700.33, 1869.0)}
#
# Sizes is:  {'mo_Ask': [13]}
# Snapshot LOB0:  {'mid': 1700.56, 'Ask_touch': (1700.78, 93.0), 'Bid_touch': (1700.34, 10), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 16.0, 'Ask_deep': (1700.79, 3226.0), 'Bid_deep': (1700.33, 1869.0)}
#
# Sizes is:  {'mo_Ask': [11]}
# Snapshot LOB0:  {'mid': 1700.56, 'Ask_touch': (1700.78, 82.0), 'Bid_touch': (1700.34, 10), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 16.0, 'Ask_deep': (1700.79, 3226.0), 'Bid_deep': (1700.33, 1869.0)}
#
# Sizes is:  {'lo_inspread_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.56, 'Ask_touch': (1700.78, 82.0), 'Bid_touch': (1700.35, 100), 'Ask_m_T': 1, 'Ask_m_D': 18, 'Bid_m_T': 1, 'Bid_m_D': 17.0, 'Ask_deep': (1700.79, 3226.0), 'Bid_deep': (1700.34, 1879.0)}
#
# Sizes is:  {'mo_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.57, 'Ask_touch': (1700.79, 161.0), 'Bid_touch': (1700.35, 100), 'Ask_m_T': 1, 'Ask_m_D': 17, 'Bid_m_T': 1, 'Bid_m_D': 17.0, 'Ask_deep': (1700.8, 3047.0), 'Bid_deep': (1700.34, 1879.0)}
#
# Sizes is:  {'mo_Ask': [1]}
# Snapshot LOB0:  {'mid': 1700.57, 'Ask_touch': (1700.79, 160.0), 'Bid_touch': (1700.35, 100), 'Ask_m_T': 1, 'Ask_m_D': 17, 'Bid_m_T': 1, 'Bid_m_D': 17.0, 'Ask_deep': (1700.8, 3047.0), 'Bid_deep': (1700.34, 1879.0)}
#
# Sizes is:  {'lo_deep_Bid': [100]}
# Snapshot LOB0:  {'mid': 1700.57, 'Ask_touch': (1700.79, 160.0), 'Bid_touch': (1700.35, 100), 'Ask_m_T': 1, 'Ask_m_D': 17, 'Bid_m_T': 1, 'Bid_m_D': 17.0, 'Ask_deep': (1700.8, 3047.0), 'Bid_deep': (1700.34, 1979.0)}
#
# Sizes is:  {'co_deep_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.57, 'Ask_touch': (1700.79, 160.0), 'Bid_touch': (1700.35, 100), 'Ask_m_T': 1, 'Ask_m_D': 17, 'Bid_m_T': 1, 'Bid_m_D': 17.0, 'Ask_deep': (1700.8, 2947.0), 'Bid_deep': (1700.34, 1979.0)}
#
# Sizes is:  {'co_deep_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.57, 'Ask_touch': (1700.79, 160.0), 'Bid_touch': (1700.35, 100), 'Ask_m_T': 1, 'Ask_m_D': 17, 'Bid_m_T': 1, 'Bid_m_D': 17.0, 'Ask_deep': (1700.8, 2847.0), 'Bid_deep': (1700.34, 1979.0)}
#
# Sizes is:  {'mo_Ask': [17]}
# Snapshot LOB0:  {'mid': 1700.57, 'Ask_touch': (1700.79, 143.0), 'Bid_touch': (1700.35, 100), 'Ask_m_T': 1, 'Ask_m_D': 17, 'Bid_m_T': 1, 'Bid_m_D': 17.0, 'Ask_deep': (1700.8, 2847.0), 'Bid_deep': (1700.34, 1979.0)}
#
# Sizes is:  {'mo_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.57, 'Ask_touch': (1700.79, 43.0), 'Bid_touch': (1700.35, 100), 'Ask_m_T': 1, 'Ask_m_D': 17, 'Bid_m_T': 1, 'Bid_m_D': 17.0, 'Ask_deep': (1700.8, 2847.0), 'Bid_deep': (1700.34, 1979.0)}
#
# Sizes is:  {'co_deep_Ask': [100]}
# Snapshot LOB0:  {'mid': 1700.57, 'Ask_touch': (1700.79, 43.0), 'Bid_touch': (1700.35, 100), 'Ask_m_T': 1, 'Ask_m_D': 17, 'Bid_m_T': 1, 'Bid_m_D': 17.0, 'Ask_deep': (1700.8, 2747.0), 'Bid_deep': (1700.34, 1979.0)}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 T, lob , _ = simulate_smalltick.simulate_smallTick(400, "/SAN/fca/Konark_PhD_Experiments/extracted/AMZN.OQ_ParamsInferredWCutoffEyeMu_Symm_2019-01-02_2019-12-31_CLSLogLin_10","/SAN/fca/Konark_PhD_Experiments/extracted/AMZN.OQ_Params_2019-01-02_2019-12-30_dictTOD_symmetric" , beta = 0.6, avgSpread = .95, spread0 = 110, price0 = 1700, M_med = 50, verbose= True)
#
# File ~/code/lobSimulations/hawkes/simulate_smalltick.py:210, in simulate_smallTick(T, paramsPath, todPath, s0, filePathName, Pis, Pi_Q0, Pi_M0, Pi_eta, beta, avgSpread, spread0, price0, M_med, verbose)
#     208 sizes = {}
#     209 dictTimestamps = {}
# --> 210 for t, col in zip(timestamps_this, cols):
#     211     if len(t) == 0: continue
#     213     pi = Pis[col] #geometric + dirac deltas; pi = (p, diracdeltas(i,p_i))
#
# KeyboardInterrupt:

# %%
lob[0]
# Out:
# {'mid': 1700,
#  'Ask_touch': (1700.55, 100),
#  'Bid_touch': (1699.45, 53),
#  'Ask_m_T': 7,
#  'Ask_m_D': 7,
#  'Bid_m_T': 27,
#  'Bid_m_D': 13,
#  'Ask_deep': (1700.62, 70),
#  'Bid_deep': (1699.18, 13)}

# %%
ask_t = []
bid_t = []
ask_d = []
bid_d= []
ask_m_D = []
bid_m_D = []
spread = []
for r in lob:
    ask_t.append(r['Ask_touch'][0])
    bid_t.append(r['Bid_touch'][0])
    ask_d.append(r['Ask_deep'][0])
    bid_d.append(r['Bid_deep'][0])
    bid_m_D.append(r['Bid_deep'][0] - 0.01*r['Bid_m_D'])
    ask_m_D.append(r['Ask_deep'][0] + 0.01*r['Ask_m_D'])
    spread.append(100*(r['Ask_touch'][0] - r['Bid_touch'][0]))
t = np.append([0], np.array(T[1:])[:,1])
t = t.astype(float) + 9.5*3600

fig, ax = plt.subplots()
ax.plot(t, ask_t, color = "r", alpha =0.5)
ax.plot(t, ask_d, color="r", alpha = 0.2)
ax.plot(t, ask_m_D, color="r", alpha = 0.2)
ax.plot(t, bid_t, color="g", alpha =0.5)
ax.plot(t, bid_d, color="g", alpha = 0.2)
ax.plot(t, bid_m_D, color="g", alpha = 0.2)
ax.fill_between(t, bid_d, bid_m_D, color="g", alpha = 0.05)
ax.fill_between(t, ask_d, ask_m_D, color="r", alpha = 0.05)
count = int((max(t) - min(t))/10)
ax.ticklabel_format(useOffset=False)
ax.set_xticks(ticks = np.arange(min(t), max(t), count), labels = [time.strftime('%H:%M:%S', time.gmtime(x)) for x in np.arange(min(t), max(t), count)], rotation = 20)
plt.show()

# %%
plt.plot(t, spread)

# %%
plt.hist(spread, density=True,bins=100)
plt.yscale('log')
plt.xscale('log')

# %%
mid = (np.array(ask_t) + np.array(bid_t))/2
tau = 1
sample_x = np.linspace(0, 23400, int(23400/tau))
idxs = np.searchsorted(np.array(t) - 34200, sample_x)[1:-1] - 1
sample_y = mid[idxs]
rets = np.exp(np.diff(np.log(mid))) - 1
plt.hist(rets, bins = 100, alpha = 0.5, density = True)
